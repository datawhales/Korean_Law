# %%
import pandas as pd

filepath = '../merged_contracts.csv'

df = pd.read_csv(filepath)
df.head()
# Out:
#       항목                                                 원본     수정본   사유 조항구분  \
# 0    NaN                          음식물류폐기물  처리  위․수탁  계약서(안)  _GOOD_  NaN  NaN
# 1    NaN  [회사명1](이하 “갑”이라 한다)와 [회사명2](이하 “을”이라 한다)은 음식물류...  _GOOD_  NaN  NaN
# 2     1조                                            목적 및 대상  _GOOD_  NaN  NaN
# 3  1조 1항  본 계약은 음식물류 폐기물의 자원화를 효율적으로 추진하기 위하여 필요한 사항을 약정...  _GOOD_  NaN  NaN
# 4  1조 2항              위탁처리대상은 [지역명1]군에서 분리 수거한 음식물류폐기물로 한다.  _GOOD_  NaN  NaN
#
#                                             파일명
# 0  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 1  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 2  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 3  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 4  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx

# %%
df[df['조항구분'] == '필수조항1']
# Out:
#                항목                               원본     수정본   사유   조항구분  \
# 43          3조 1항                계약기간은 [기간]까지로 한다.  _GOOD_  NaN  필수조항1
# 121      1장 2조 1항                             [기간]  _GOOD_  NaN  필수조항1
# 546      7장 8조 1항     이 계약은 체결일로부터 [날짜] 그 효력을 가진다.  _GOOD_  NaN  필수조항1
# 565      1장 2조 1항                             [기간]  _GOOD_  NaN  필수조항1
# 974      7장 8조 1항     이 계약은 체결일로부터 [날짜] 그 효력을 가진다.  _GOOD_  NaN  필수조항1
# ...           ...                              ...     ...  ...    ...
# 74023       3조 1항         본 계약에 의한 용역기간은 [기간]로 한다.  _GOOD_  NaN  필수조항1
# 74074     8조 1항-1              본 계약기간은 [기간]까지로 하며   _GOOD_  NaN  필수조항1
# 74111    11조 1항-1  본 계약의 유효기간은 계약체결일부터 [기간]으로 하고,   _GOOD_  NaN  필수조항1
# 74144     5조 1항-1         이 계약은 본  계약 체결일로부터 [기간]   _GOOD_  NaN  필수조항1
# 74157  2장 3조 1항-1               본 계약은 [기간]까지로 하며,   _GOOD_  NaN  필수조항1
#
#                                                   파일명
# 43                           체크10. PC유지보수계약서_ID3.xlsx
# 121               체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# 546               체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# 565    체크101. 디자인업종(디지털) 표준하도급계약서(2017.12.27.개정).xlsx
# 974    체크101. 디자인업종(디지털) 표준하도급계약서(2017.12.27.개정).xlsx
# ...                                               ...
# 74023                            체크731. 창업컨설팅계약서.xlsx
# 74074                             체크732. 청소용역계약서.xlsx
# 74111                              체크733. 컨설팅계약서.xlsx
# 74144                            체크734. 컨설팅업무계약서.xlsx
# 74157                       체크735. 프리랜서와기업간업무계약서.xlsx
#
# [859 rows x 6 columns]

# %%
df['조항구분'].unique()
# Out:
# array([nan, '\xa0필수조항1', '\xa0옵션조항3', '필수조항8', '\xa0옵션조항7', '필수조항10 유사조항',
#        '필수조항11', '필수조항1', '\xa0필수조항3', '\xa0옵션조항1', '\xa0옵션조항2',
#        '\xa0필수조항4', '\xa0필수조항9', '\xa0필수조항6', '\xa0필수조항12', '옵션조항3',
#        '필수조항3', '필수조항2', '필수조항4', '옵션조항2', '필수조항7', '필수조항6', '필수조항12',
#        '필수조항13', '필수조항5', '필수조항10.1 유사조항', '옵션조항10', '필수조항9', '옵션조항6',
#        '필수조항10.1', '옵션조항5', '옵션조항8', '옵션조항1', '옵션조항7', '필수조항10',
#        '\xa0필수조항8', '\xa0필수조항5', '\xa0옵션조항8', '\xa0필수조항11', '\xa0필수조항2',
#        '\xa0필수조항7', '\xa0필수조항10 유사조항', '\xa0필수조항13', '\xa0옵션조항10',
#        '\xa0 필수조항12', '\xa0필수조항10', '\xa0필수조항10.1', ' 옵션조항2', ' 옵션조항8',
#        ' 필수조항12', '\xa0 필수조항2', '\xa0 필수조항7', ' 필수조항5', '옵션조항12',
#        '\xa0필수조항17', '\xa0옵션조항5', ' \xa0필수조항1', ' 필수조항11', ' 필수조항10',
#        '팔수조항11', '필수정보6', '필수조항8 ', '필수조항1 ', '옵션조항4',
#        '필수조항5, 필수조항10 유사조항', '  ', '옵션조항9', '필수조11', '필수조항101 유사조항',
#        '필수조항10 ', '필수조항10.1 ', '                        ', '조항구분'],
#       dtype=object)

# %%
def cleaning(x):
    if str(x).find('\xa0') != -1:
        return str(x).split('\xa0')[1]
    return str(x)

# %%
cleaning('\xa0필수조항1')
# Out:
# '필수조항1'

# %%
df['조항구분'] = df['조항구분'].apply(cleaning)

# %%
df['조항구분'].unique()
# Out:
# array(['nan', '필수조항1', '옵션조항3', '필수조항8', '옵션조항7', '필수조항10 유사조항', '필수조항11',
#        '필수조항3', '옵션조항1', '옵션조항2', '필수조항4', '필수조항9', '필수조항6', '필수조항12',
#        '필수조항2', '필수조항7', '필수조항13', '필수조항5', '필수조항10.1 유사조항', '옵션조항10',
#        '옵션조항6', '필수조항10.1', '옵션조항5', '옵션조항8', '필수조항10', ' 필수조항12',
#        ' 옵션조항2', ' 옵션조항8', ' 필수조항2', ' 필수조항7', ' 필수조항5', '옵션조항12',
#        '필수조항17', ' 필수조항11', ' 필수조항10', '팔수조항11', '필수정보6', '필수조항8 ',
#        '필수조항1 ', '옵션조항4', '필수조항5, 필수조항10 유사조항', '  ', '옵션조항9', '필수조11',
#        '필수조항101 유사조항', '필수조항10 ', '필수조항10.1 ', '                        ',
#        '조항구분'], dtype=object)

# %%
df[df['조항구분'] == '조항구분']
# Out:
#        항목  원본   수정본  사유  조항구분                        파일명
# 49861  항목  원본  수정사항  사유  조항구분  체크519. [붙임2] 용역표준계약서.xlsx

# %%
sorted(list(df['조항구분'].unique()))
# Out:
# ['  ',
#  '                        ',
#  ' 옵션조항2',
#  ' 옵션조항8',
#  ' 필수조항10',
#  ' 필수조항11',
#  ' 필수조항12',
#  ' 필수조항2',
#  ' 필수조항5',
#  ' 필수조항7',
#  'nan',
#  '옵션조항1',
#  '옵션조항10',
#  '옵션조항12',
#  '옵션조항2',
#  '옵션조항3',
#  '옵션조항4',
#  '옵션조항5',
#  '옵션조항6',
#  '옵션조항7',
#  '옵션조항8',
#  '옵션조항9',
#  '조항구분',
#  '팔수조항11',
#  '필수정보6',
#  '필수조11',
#  '필수조항1',
#  '필수조항1 ',
#  '필수조항10',
#  '필수조항10 ',
#  '필수조항10 유사조항',
#  '필수조항10.1',
#  '필수조항10.1 ',
#  '필수조항10.1 유사조항',
#  '필수조항101 유사조항',
#  '필수조항11',
#  '필수조항12',
#  '필수조항13',
#  '필수조항17',
#  '필수조항2',
#  '필수조항3',
#  '필수조항4',
#  '필수조항5',
#  '필수조항5, 필수조항10 유사조항',
#  '필수조항6',
#  '필수조항7',
#  '필수조항8',
#  '필수조항8 ',
#  '필수조항9']

# %%
df[df['조항구분'] == '필수조항5, 필수조항10 유사조항']
# Out:
#            항목                                                 원본     수정본   사유  \
# 19826  12조 1항  을은 자신이 수행하는 개발의 수행방법 또는 개발제품에 적용한 기술이 제3자의 특허권...  _GOOD_  NaN
#
#                      조항구분                              파일명
# 19826  필수조항5, 필수조항10 유사조항  체크765. Nizform_계약서예문_27853.xlsx

# %%
def cleaning_2(x):
    return str(x).strip()

# %%
df[df['조항구분'] == '  ']
# Out:
#            항목                                                 원본     수정본   사유  \
# 23367  12조 2항  불가항력이란 “갑”또는 “을”의 제어한계를 벗어나고 “갑”또는 “을”의 과실이나 태...  _GOOD_  NaN
#
#       조항구분                              파일명
# 23367       체크818. Nizform_계약서예문_42265.xlsx

# %%
df[df['조항구분'] == '                        ']
# Out:
#                 항목                              원본     수정본   사유  \
# 48008  1장 4조 2항 2호  (은행 계좌번호:                    )  _GOOD_  NaN
#
#                            조항구분                      파일명
# 48008                            체크499. 디자인 기술용역계약서.xlsx

# %%
df[df['조항구분'] == '조항구분']
# Out:
#        항목  원본   수정본  사유  조항구분                        파일명
# 49861  항목  원본  수정사항  사유  조항구분  체크519. [붙임2] 용역표준계약서.xlsx

# %%
df[df['조항구분'] == '필수조항10 유사조항']
# Out:
#               항목                                                 원본     수정본  \
# 24         8조 1항  “을”은 음식물류폐기물 수탁처리업무 수행 중 발생하는 모든 사고에 대하여 민,형사상...  _GOOD_
# 98        12조 4항                “을”은 전항의 위반으로 인한 민·형사상의 모든 책임을 진다.   _GOOD_
# 7839    16조 1항-2  “계약대상2”는 공사 중 발생한 재해 및 인사 사고에 대하여도 민형사상의 모든 책임...  _GOOD_
# 7843    17조 1항-2                         더불어 공사 전반에 대한 감리의 책임을 진다.   _GOOD_
# 7990       7조 1항  "을"이 작업 중 발생한 모든 안전사고 (대기실 등의 부주의로 인한 화재 등 포함)...  _GOOD_
# ...          ...                                                ...     ...
# 68199      7조 4항  계약상대자”는 제1항의 모든 자료를 “공단”의 이익에 반하는 일체의 영업 행위에 사...  _GOOD_
# 71601  5장 17조 2항  1항의 경우 “계약상대자”는 선량한 괸리자의 의무를 지며, 이를 위반하여 하자가 발...  _GOOD_
# 71608  5장 19조 1항  “계약상대자”의 소유재산은 “계약상대자”의 책임 하에 관리하여야 하며, 담당 구역 ...  _GOOD_
# 71631  5장 25조 1항  “계약상대자”는 종업원의 생명, 신체 또는 재산상에 발생한 사고와 근로기준법 등 일...  _GOOD_
# 73100    4조 1항-2  계약기간중 발생하는 일체의 사고에 대한 민  형사상의 일체의 문제는 을이 책임지고 ...  _GOOD_
#
#         사유         조항구분                                           파일명
# 24     NaN  필수조항10 유사조항  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 98     NaN  필수조항10 유사조항                      체크10. PC유지보수계약서_ID3.xlsx
# 7839   NaN  필수조항10 유사조항                     체크14. 건물관리_건물도장공사계약서.xlsx
# 7843   NaN  필수조항10 유사조항                     체크14. 건물관리_건물도장공사계약서.xlsx
# 7990   NaN  필수조항10 유사조항                       체크17. 건물관리_청소용역계약서.xlsx
# ...    ...          ...                                           ...
# 68199  NaN  필수조항10 유사조항                        체크665. 용역계약서 (31).xlsx
# 71601  NaN  필수조항10 유사조항              체크689. [첨부2]사옥종합시설관리용역계약서_2.xlsx
# 71608  NaN  필수조항10 유사조항              체크689. [첨부2]사옥종합시설관리용역계약서_2.xlsx
# 71631  NaN  필수조항10 유사조항              체크689. [첨부2]사옥종합시설관리용역계약서_2.xlsx
# 73100  NaN  필수조항10 유사조항                       체크717. 용역계약서(배달사원).xlsx
#
# [226 rows x 6 columns]

# %%
df[df['조항구분'] == '필수조항10.1 유사조항']
# Out:
#                  항목                                                 원본  \
# 239       3장 14조 3항  수급사업자는 다음 각 호의 어느 하나에 해당한 경우 제2항에 따른 책임을 지지 아니...
# 240    3장 14조 3항 1호                수급사업자 및 제3자에게 고의 또는 과실이 없음을 증명한 경우
# 241    3장 14조 3항 2호  원사업자의 지명에 따라 수급사업자가 제3자를 선임한 경우에 수급사업자가 제3자의 부...
# 665       3장 10조 3항  수급사업자는 다음 각 호의 어느 하나에 해당한 경우 제2항에 따른 책임을 지지 않는다.
# 666    3장 10조 3항 1호                수급사업자 및 제3자에게 고의 또는 과실이 없음을 증명한 경우
# ...             ...                                                ...
# 73833  2장 21조 1항 3호  공사업자가 제8조의 규정에 의한 “을”의 요청에 응하지 아니하고 임의로 공사를 계속...
# 73834  2장 21조 1항 4호  공사업자가 제9조의 규정에 의한 현장확인지도를 받지 아니하고 공사를 진행하여 손해가...
# 74046        10조 1항  을은 본 계약에 의한 용역의 결과로 인하여 갑이 입은 손해에 대해 그 손해가 을의 ...
# 74072         7조 1항  을이 작업중 발생한 모든 안전사고 (대기실 등의 부주의로 인한 화재 등 포함)는 "...
# 74096       6조 1항-2  을이 요청한 정보 및 자료의 제공을 지연하여 용역결과물 제출이 늦어질 경우, 이는 ...
#
#           수정본   사유           조항구분  \
# 239    _GOOD_  NaN  필수조항10.1 유사조항
# 240    _GOOD_  NaN  필수조항10.1 유사조항
# 241    _GOOD_  NaN  필수조항10.1 유사조항
# 665    _GOOD_  NaN  필수조항10.1 유사조항
# 666    _GOOD_  NaN  필수조항10.1 유사조항
# ...       ...  ...            ...
# 73833  _GOOD_  NaN  필수조항10.1 유사조항
# 73834  _GOOD_  NaN  필수조항10.1 유사조항
# 74046  _GOOD_  NaN  필수조항10.1 유사조항
# 74072  _GOOD_  NaN  필수조항10.1 유사조항
# 74096  _GOOD_  NaN  필수조항10.1 유사조항
#
#                                                   파일명
# 239               체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# 240               체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# 241               체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# 665    체크101. 디자인업종(디지털) 표준하도급계약서(2017.12.27.개정).xlsx
# 666    체크101. 디자인업종(디지털) 표준하도급계약서(2017.12.27.개정).xlsx
# ...                                               ...
# 73833                   체크726. 전력시설물의공사감리용역표준계약서.xlsx
# 73834                   체크726. 전력시설물의공사감리용역표준계약서.xlsx
# 74046                            체크731. 창업컨설팅계약서.xlsx
# 74072                             체크732. 청소용역계약서.xlsx
# 74096                              체크733. 컨설팅계약서.xlsx
#
# [368 rows x 6 columns]

# %%
df['조항구분'] = df['조항구분'].apply(cleaning_2)

# %%
df['조항구분'].unique()
# Out:
# array(['nan', '필수조항1', '옵션조항3', '필수조항8', '옵션조항7', '필수조항10 유사조항', '필수조항11',
#        '필수조항3', '옵션조항1', '옵션조항2', '필수조항4', '필수조항9', '필수조항6', '필수조항12',
#        '필수조항2', '필수조항7', '필수조항13', '필수조항5', '필수조항10.1 유사조항', '옵션조항10',
#        '옵션조항6', '필수조항10.1', '옵션조항5', '옵션조항8', '필수조항10', '옵션조항12',
#        '필수조항17', '팔수조항11', '필수정보6', '옵션조항4', '필수조항5, 필수조항10 유사조항', '',
#        '옵션조항9', '필수조11', '필수조항101 유사조항', '조항구분'], dtype=object)

# %%
sorted(list(df['조항구분'].unique()))
# Out:
# ['',
#  'nan',
#  '옵션조항1',
#  '옵션조항10',
#  '옵션조항12',
#  '옵션조항2',
#  '옵션조항3',
#  '옵션조항4',
#  '옵션조항5',
#  '옵션조항6',
#  '옵션조항7',
#  '옵션조항8',
#  '옵션조항9',
#  '조항구분',
#  '팔수조항11',
#  '필수정보6',
#  '필수조11',
#  '필수조항1',
#  '필수조항10',
#  '필수조항10 유사조항',
#  '필수조항10.1',
#  '필수조항10.1 유사조항',
#  '필수조항101 유사조항',
#  '필수조항11',
#  '필수조항12',
#  '필수조항13',
#  '필수조항17',
#  '필수조항2',
#  '필수조항3',
#  '필수조항4',
#  '필수조항5',
#  '필수조항5, 필수조항10 유사조항',
#  '필수조항6',
#  '필수조항7',
#  '필수조항8',
#  '필수조항9']

# %%
find_by_option(df, '필수조항17')
# Out:
#                 항목                                                 원본     수정본  \
# 10678  1장 21조 1항-3  을 준공검사후 그 공사의 대가를 지급할 때까지 현금 또는 다음 각호의 증서로서 갑에...  _GOOD_
#
#         사유    조항구분                         파일명
# 10678  NaN  필수조항17  체크39. 민간 전기공사 표준도급계약서.xlsx

# %%
def cleaning_3(x):
    if str(x) == '필수정보6':
        return '필수조항6'
    elif str(x) == '필수조11':
        return '필수조항11'
    elif str(x) == '필수조항101 유사조항':
        return '필수조항10.1 유사조항'
    return str(x)

# %%
def cleaning_4(x):
    if str(x) == '필수조항10.1 유사조항':
        return '필수조항10.1'
    elif str(x) == '필수조항10 유사조항':
        return '필수조항10'
    elif str(x) == '필수조항5, 필수조항10 유사조항':
        return '필수조항10'
    elif str(x) == '팔수조항11':
        return '필수조항11'
    elif str(x) == '조항구분':
        return 'nan'
    elif str(x) == '':
        return 'nan'
    elif str(x) == '필수조항17':
        return '필수조항7'
    return str(x)

# %%
df['조항구분'] = df['조항구분'].apply(cleaning_4)
df['조항구분'].unique()
# Out:
# array(['nan', '필수조항1', '옵션조항3', '필수조항8', '옵션조항7', '필수조항10', '필수조항11',
#        '필수조항3', '옵션조항1', '옵션조항2', '필수조항4', '필수조항9', '필수조항6', '필수조항12',
#        '필수조항2', '필수조항7', '필수조항13', '필수조항5', '필수조항10.1', '옵션조항10', '옵션조항6',
#        '옵션조항5', '옵션조항8', '옵션조항12', '옵션조항4', '옵션조항9'], dtype=object)

# %%
sorted(list(df['조항구분'].unique()))
# Out:
# ['nan',
#  '옵션조항1',
#  '옵션조항10',
#  '옵션조항12',
#  '옵션조항2',
#  '옵션조항3',
#  '옵션조항4',
#  '옵션조항5',
#  '옵션조항6',
#  '옵션조항7',
#  '옵션조항8',
#  '옵션조항9',
#  '필수조항1',
#  '필수조항10',
#  '필수조항10.1',
#  '필수조항11',
#  '필수조항12',
#  '필수조항13',
#  '필수조항2',
#  '필수조항3',
#  '필수조항4',
#  '필수조항5',
#  '필수조항6',
#  '필수조항7',
#  '필수조항8',
#  '필수조항9']

# %%
df['조항구분'].unique()
# Out:
# array(['nan', '필수조항1', '옵션조항3', '필수조항8', '옵션조항7', '필수조항10 유사조항', '필수조항11',
#        '필수조항3', '옵션조항1', '옵션조항2', '필수조항4', '필수조항9', '필수조항6', '필수조항12',
#        '필수조항2', '필수조항7', '필수조항13', '필수조항5', '필수조항10.1 유사조항', '옵션조항10',
#        '옵션조항6', '필수조항10.1', '옵션조항5', '옵션조항8', '필수조항10', '옵션조항12',
#        '필수조항17', '팔수조항11', '옵션조항4', '필수조항5, 필수조항10 유사조항', '', '옵션조항9',
#        '조항구분'], dtype=object)

# %%
find_by_option(df, '필수조항10')
# Out:
#                항목                                                 원본     수정본  \
# 3157       11조 8항  원사업자는 조사결과 제1항부터 제5항까지의 규정을 위반한 사실이 있는 경우에는 그에...  _GOOD_
# 4014    2장 19조 8항  수급사업자가 계약상 의무를 이행하지 아니하여 원사업자가 제33조 제1항 및 제2항에...  _GOOD_
# 8013        5조 4항   “을” 은 본 계약의 개발과 관련하여 관계법령을 위반하거나 제 3 자의 권리(지적...  _GOOD_
# 8206       13조 1항  “갑”은 계약금액 결정상 명백한 하자로 인하여 부당이득을 취한 사실이 발견될 경우,...  _GOOD_
# 8207       13조 2항  계약종결 후에 전항의 규정에 의한 환수사유가 발생하였을 때에는 “을”에게 지급할 다...  _GOOD_
# ...           ...                                                ...     ...
# 73215    2장 9조 1항  계약상대자가 정당한 이유없이 계약상의 의무를 이행하지 아니한 때에는 계약보증금을 당...  _GOOD_
# 73676  8조 1항 1호-2  2) 이런 문제로 발생한 모든 비용(각종 소송을 위한 조사비용 및 변호비용을 포함합...  _GOOD_
# 73838   2장 22조 3항  “을”의 귀책사유로 인하여 공사감리용역의 전부 또는 일부가 중단된 경우에는 “갑”이...  _GOOD_
# 74044     9조 3항-2      이 경우 을은 갑으로부터 지급 받은 착수금 및 용역대행 수수료를 갑에게 반환한다.  _GOOD_
# 74070       6조 1항  제5조에 대한 변상은 "을"이 신속히 이행하지 아니할 경우에는 용역대금 중에서 동 ...  _GOOD_
#
#         사유    조항구분                                      파일명
# 3157   NaN  필수조항10    체크107. 전자업종표준하도급계약서(14.12.31.개정).xlsx
# 4014   NaN  필수조항10  체크109. 전기공사업종표준하도급계약서(14.12.31.개정).xlsx
# 8013   NaN  필수조항10            체크18. 광학엔진 개발 계약서 샘플_ID8.xlsx
# 8206   NaN  필수조항10        체크2. (붙임4) 계약특수조건 1부(160314).xlsx
# 8207   NaN  필수조항10        체크2. (붙임4) 계약특수조건 1부(160314).xlsx
# ...    ...     ...                                      ...
# 73215  NaN  필수조항10                      체크719. 용역도급계약서.xlsx
# 73676  NaN  필수조항10                    체크725. 재무용역자문계약서.xlsx
# 73838  NaN  필수조항10            체크726. 전력시설물의공사감리용역표준계약서.xlsx
# 74044  NaN  필수조항10                     체크731. 창업컨설팅계약서.xlsx
# 74070  NaN  필수조항10                      체크732. 청소용역계약서.xlsx
#
# [219 rows x 6 columns]

# %%
sorted(list(df['조항구분'].unique()))
# Out:
# ['',
#  'nan',
#  '옵션조항1',
#  '옵션조항10',
#  '옵션조항12',
#  '옵션조항2',
#  '옵션조항3',
#  '옵션조항4',
#  '옵션조항5',
#  '옵션조항6',
#  '옵션조항7',
#  '옵션조항8',
#  '옵션조항9',
#  '조항구분',
#  '팔수조항11',
#  '필수조항1',
#  '필수조항10',
#  '필수조항10 유사조항',
#  '필수조항10.1',
#  '필수조항10.1 유사조항',
#  '필수조항11',
#  '필수조항12',
#  '필수조항13',
#  '필수조항17',
#  '필수조항2',
#  '필수조항3',
#  '필수조항4',
#  '필수조항5',
#  '필수조항5, 필수조항10 유사조항',
#  '필수조항6',
#  '필수조항7',
#  '필수조항8',
#  '필수조항9']

# %%
df['조항구분'] = df['조항구분'].apply(cleaning_3)
df['조항구분'].unique()
# Out:
# array(['nan', '필수조항1', '옵션조항3', '필수조항8', '옵션조항7', '필수조항10 유사조항', '필수조항11',
#        '필수조항3', '옵션조항1', '옵션조항2', '필수조항4', '필수조항9', '필수조항6', '필수조항12',
#        '필수조항2', '필수조항7', '필수조항13', '필수조항5', '필수조항10.1 유사조항', '옵션조항10',
#        '옵션조항6', '필수조항10.1', '옵션조항5', '옵션조항8', '필수조항10', '옵션조항12',
#        '필수조항17', '팔수조항11', '옵션조항4', '필수조항5, 필수조항10 유사조항', '', '옵션조항9',
#        '조항구분'], dtype=object)

# %%
sorted(list(df['조항구분'].unique()))
# Out:
# ['',
#  'nan',
#  '옵션조항1',
#  '옵션조항10',
#  '옵션조항12',
#  '옵션조항2',
#  '옵션조항3',
#  '옵션조항4',
#  '옵션조항5',
#  '옵션조항6',
#  '옵션조항7',
#  '옵션조항8',
#  '옵션조항9',
#  '조항구분',
#  '팔수조항11',
#  '필수조항1',
#  '필수조항10',
#  '필수조항10 유사조항',
#  '필수조항10.1',
#  '필수조항10.1 유사조항',
#  '필수조항11',
#  '필수조항12',
#  '필수조항13',
#  '필수조항17',
#  '필수조항2',
#  '필수조항3',
#  '필수조항4',
#  '필수조항5',
#  '필수조항5, 필수조항10 유사조항',
#  '필수조항6',
#  '필수조항7',
#  '필수조항8',
#  '필수조항9']

# %%
df[df['조항구분'] == '']
# Out:
#                 항목                                                 원본     수정본  \
# 23367       12조 2항  불가항력이란 “갑”또는 “을”의 제어한계를 벗어나고 “갑”또는 “을”의 과실이나 태...  _GOOD_
# 48008  1장 4조 2항 2호                     (은행 계좌번호:                    )  _GOOD_
#
#         사유 조항구분                              파일명
# 23367  NaN       체크818. Nizform_계약서예문_42265.xlsx
# 48008  NaN               체크499. 디자인 기술용역계약서.xlsx

# %%
df
# Out:
#               항목                                                 원본     수정본  \
# 0            NaN                          음식물류폐기물  처리  위․수탁  계약서(안)  _GOOD_
# 1            NaN  [회사명1](이하 “갑”이라 한다)와 [회사명2](이하 “을”이라 한다)은 음식물류...  _GOOD_
# 2             1조                                            목적 및 대상  _GOOD_
# 3          1조 1항  본 계약은 음식물류 폐기물의 자원화를 효율적으로 추진하기 위하여 필요한 사항을 약정...  _GOOD_
# 4          1조 2항              위탁처리대상은 [지역명1]군에서 분리 수거한 음식물류폐기물로 한다.  _GOOD_
# ...          ...                                                ...     ...
# 74175     2장 10조                                                 해석  _GOOD_
# 74176  2장 10조 1항  본 계약에 명기하지 아니한 사항 및 본 계약의 해석상의 이의가 있을 때에는 쌍방의 ...  _GOOD_
# 74177     2장 11조                                               소송관할  _GOOD_
# 74178  2장 11조 1항                 본 계약으로 발생되는 분쟁은 서울지방법원을 관할법원으로 한다.  _GOOD_
# 74179        NaN  본 계약을 증명하기 위하여 계약서 2통을 작성하여 쌍방이 서명 날인하고 각각 1통씩...  _GOOD_
#
#         사유   조항구분                                           파일명
# 0      NaN    nan  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 1      NaN    nan  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 2      NaN    nan  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 3      NaN    nan  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 4      NaN    nan  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# ...    ...    ...                                           ...
# 74175  NaN    nan                     체크735. 프리랜서와기업간업무계약서.xlsx
# 74176  NaN    nan                     체크735. 프리랜서와기업간업무계약서.xlsx
# 74177  NaN    nan                     체크735. 프리랜서와기업간업무계약서.xlsx
# 74178  NaN  옵션조항8                     체크735. 프리랜서와기업간업무계약서.xlsx
# 74179  NaN    nan                     체크735. 프리랜서와기업간업무계약서.xlsx
#
# [74180 rows x 6 columns]

# %%
df.loc[0]['원본']
# Out:
# '음식물류폐기물  처리  위․수탁  계약서(안)'

# %%
from collections import Counter

def similar_options(df):
    pair_dict = dict()
    for i in range(len(df) - 1):
        if df.loc[i]['항목'] == df.loc[i+1]['항목'] and df.loc[i]['원본'] == df.loc[i+1]['원본']:
            pair_dict[(i, i+1)] = tuple(sorted((df.loc[i]['조항구분'], df.loc[i+1]['조항구분'])))

    counter = Counter(pair_dict.values())
    return pair_dict, counter.most_common()

# %%
from collections import Counter

def similar_options_three(df):
    pair_dict = dict()
    try:
        for i in range(len(df) - 2):
            if df.loc[i]['항목'] == df.loc[i+1]['항목'] and df.loc[i] == df.loc[i+2]['항목'] and df.loc[i]['원본'] == df.loc[i+1]['원본'] and df.loc[i]['원본'] == df.loc[i+2]['원본']:
                pair_dict[(i, i+1, i+2)] = tuple(sorted((df.loc[i]['조항구분'], df.loc[i+1]['조항구분'], df.loc[i+2]['조항구분'])))
    except:
        pass
    counter = Counter(pair_dict.values())
    return pair_dict, counter.most_common()

# %%
three_pair_dict, three_count_list = similar_options_three(df)
three_pair_dict
# Out:
# {}

# %%
pair_dict, count_list = similar_options(df)

# %%
pair_dict
# Out:
# {(97, 98): ('필수조항10', '필수조항6'),
#  (210, 211): ('옵션조항2', '필수조항5'),
#  (213, 214): ('옵션조항2', '필수조항5'),
#  (249, 250): ('필수조항12', '필수조항4'),
#  (278, 279): ('옵션조항6', '필수조항12'),
#  (283, 284): ('옵션조항10', '필수조항12'),
#  (302, 303): ('필수조항12', '필수조항5'),
#  (305, 306): ('옵션조항2', '필수조항5'),
#  (344, 345): ('옵션조항2', '필수조항10.1'),
#  (353, 354): ('옵션조항3', '필수조항10.1'),
#  (503, 504): ('필수조항11', '필수조항12'),
#  (505, 506): ('필수조항11', '필수조항12'),
#  (641, 642): ('옵션조항2', '필수조항5'),
#  (644, 645): ('옵션조항2', '필수조항5'),
#  (674, 675): ('필수조항12', '필수조항4'),
#  (695, 696): ('옵션조항6', '필수조항12'),
#  (700, 701): ('옵션조항10', '필수조항12'),
#  (702, 703): ('옵션조항10', '필수조항12'),
#  (762, 763): ('옵션조항3', '필수조항10.1'),
#  (793, 794): ('옵션조항2', '필수조항10.1'),
#  (931, 932): ('필수조항11', '필수조항12'),
#  (933, 934): ('필수조항11', '필수조항12'),
#  (1074, 1075): ('필수조항12', '필수조항13'),
#  (1090, 1091): ('옵션조항2', '필수조항10.1'),
#  (1219, 1220): ('필수조항11', '필수조항12'),
#  (1223, 1224): ('옵션조항2', '필수조항4'),
#  (1330, 1331): ('필수조항10.1', '필수조항7'),
#  (1332, 1333): ('필수조항10.1', '필수조항7'),
#  (1355, 1356): ('옵션조항2', '필수조항5'),
#  (1358, 1359): ('옵션조항2', '필수조항5'),
#  (1395, 1396): ('필수조항12', '필수조항4'),
#  (1424, 1425): ('옵션조항6', '필수조항12'),
#  (1429, 1430): ('옵션조항10', '필수조항12'),
#  (1448, 1449): ('필수조항12', '필수조항5'),
#  (1451, 1452): ('옵션조항2', '필수조항5'),
#  (1490, 1491): ('옵션조항2', '필수조항10.1'),
#  (1499, 1500): ('옵션조항3', '필수조항10.1'),
#  (1649, 1650): ('필수조항11', '필수조항12'),
#  (1651, 1652): ('필수조항11', '필수조항12'),
#  (1800, 1801): ('옵션조항2', '필수조항5'),
#  (1803, 1804): ('옵션조항2', '필수조항5'),
#  (1848, 1849): ('옵션조항2', '필수조항9'),
#  (1981, 1982): ('옵션조항2', '필수조항10.1'),
#  (2000, 2001): ('옵션조항3', '필수조항10.1'),
#  (2086, 2087): ('옵션조항2', '필수조항5'),
#  (2091, 2092): ('옵션조항2', '필수조항5'),
#  (2136, 2137): ('옵션조항2', '필수조항4'),
#  (2168, 2169): ('옵션조항2', '필수조항7'),
#  (2198, 2199): ('필수조항11', '필수조항12'),
#  (2200, 2201): ('필수조항11', '필수조항12'),
#  (2328, 2329): ('옵션조항2', '필수조항5'),
#  (2333, 2334): ('옵션조항2', '필수조항5'),
#  (2423, 2424): ('옵션조항2', '필수조항10.1'),
#  (2432, 2433): ('옵션조항3', '필수조항10.1'),
#  (2557, 2558): ('필수조항12', '필수조항7'),
#  (2563, 2564): ('옵션조항2', '필수조항11'),
#  (2581, 2582): ('필수조항11', '필수조항12'),
#  (2583, 2584): ('필수조항11', '필수조항12'),
#  (2727, 2728): ('옵션조항2', '필수조항5'),
#  (2730, 2731): ('옵션조항2', '필수조항5'),
#  (2770, 2771): ('필수조항12', '필수조항4'),
#  (2799, 2800): ('옵션조항6', '필수조항12'),
#  (2804, 2805): ('옵션조항10', '필수조항12'),
#  (2823, 2824): ('필수조항12', '필수조항5'),
#  (2826, 2827): ('옵션조항2', '필수조항5'),
#  (2865, 2866): ('옵션조항2', '필수조항10.1'),
#  (2874, 2875): ('옵션조항3', '필수조항10.1'),
#  (3018, 3019): ('필수조항11', '필수조항12'),
#  (3020, 3021): ('필수조항11', '필수조항12'),
#  (3118, 3119): ('옵션조항2', '필수조항6'),
#  (3162, 3163): ('필수조항12', '필수조항7'),
#  (3191, 3192): ('옵션조항3', '필수조항10.1'),
#  (3194, 3195): ('옵션조항2', '옵션조항3'),
#  (3223, 3224): ('필수조항12', '필수조항4'),
#  (3281, 3282): ('옵션조항2', '필수조항4'),
#  (3308, 3309): ('필수조항11', '필수조항12'),
#  (3325, 3326): ('옵션조항2', '필수조항5'),
#  (3329, 3330): ('필수조항12', '필수조항5'),
#  (3337, 3338): ('옵션조항2', '필수조항5'),
#  (3585, 3586): ('옵션조항3', '필수조항10.1'),
#  (3607, 3608): ('옵션조항6', '필수조항12'),
#  (3644, 3645): ('필수조항12', '필수조항7'),
#  (3721, 3722): ('필수조항12', '필수조항7'),
#  (3736, 3737): ('옵션조항2', '필수조항5'),
#  (3741, 3742): ('옵션조항2', '필수조항5'),
#  (3774, 3775): ('필수조항12', '필수조항6'),
#  (3806, 3807): ('필수조항11', '필수조항12'),
#  (3832, 3833): ('옵션조항2', '필수조항4'),
#  (4014, 4015): ('필수조항10', '필수조항11'),
#  (4036, 4037): ('옵션조항2', '옵션조항3'),
#  (4100, 4101): ('옵션조항2', '필수조항4'),
#  (4123, 4124): ('옵션조항2', '필수조항7'),
#  (4154, 4155): ('필수조항11', '필수조항12'),
#  (4160, 4161): ('필수조항11', '필수조항12'),
#  (4162, 4163): ('필수조항11', '필수조항12'),
#  (4221, 4222): ('옵션조항2', '필수조항5'),
#  (4227, 4228): ('옵션조항2', '필수조항5'),
#  (4281, 4282): ('옵션조항3', '필수조항12'),
#  (4378, 4379): ('옵션조항2', '옵션조항3'),
#  (4407, 4408): ('필수조항12', '필수조항4'),
#  (4463, 4464): ('옵션조항2', '필수조항4'),
#  (4492, 4493): ('필수조항11', '필수조항12'),
#  (4508, 4509): ('옵션조항2', '필수조항5'),
#  (4519, 4520): ('옵션조항2', '필수조항5'),
#  (4686, 4687): ('필수조항10.1', '필수조항7'),
#  (4704, 4705): ('옵션조항2', '필수조항5'),
#  (4707, 4708): ('옵션조항2', '필수조항5'),
#  (4778, 4779): ('필수조항12', '필수조항4'),
#  (4808, 4809): ('옵션조항6', '필수조항12'),
#  (4813, 4814): ('옵션조항10', '필수조항12'),
#  (4832, 4833): ('필수조항12', '필수조항5'),
#  (4835, 4836): ('옵션조항2', '필수조항5'),
#  (4874, 4875): ('옵션조항2', '필수조항10.1'),
#  (4883, 4884): ('옵션조항3', '필수조항10.1'),
#  (5034, 5035): ('필수조항11', '필수조항12'),
#  (5036, 5037): ('필수조항11', '필수조항12'),
#  (5213, 5214): ('옵션조항3', '필수조항10.1'),
#  (5246, 5247): ('옵션조항6', '필수조항12'),
#  (5271, 5272): ('필수조항12', '필수조항7'),
#  (5364, 5365): ('옵션조항2', '필수조항5'),
#  (5367, 5368): ('필수조항12', '필수조항5'),
#  (5370, 5371): ('옵션조항2', '필수조항5'),
#  (5390, 5391): ('필수조항12', '필수조항6'),
#  (5431, 5432): ('필수조항11', '필수조항12'),
#  (5458, 5459): ('옵션조항2', '필수조항4'),
#  (5639, 5640): ('옵션조항2', '옵션조항3'),
#  (5649, 5650): ('옵션조항2', '옵션조항3'),
#  (5686, 5687): ('옵션조항2', '필수조항10.1'),
#  (5732, 5733): ('옵션조항2', '필수조항4'),
#  (5770, 5771): ('옵션조항2', '필수조항11'),
#  (5776, 5777): ('필수조항11', '필수조항12'),
#  (5778, 5779): ('필수조항11', '필수조항12'),
#  (5934, 5935): ('필수조항12', '필수조항4'),
#  (5963, 5964): ('옵션조항6', '필수조항12'),
#  (5968, 5969): ('옵션조항10', '필수조항12'),
#  (5987, 5988): ('옵션조항2', '필수조항5'),
#  (5990, 5991): ('필수조항12', '필수조항5'),
#  (5993, 5994): ('옵션조항2', '필수조항5'),
#  (6032, 6033): ('옵션조항2', '필수조항10.1'),
#  (6041, 6042): ('옵션조항3', '필수조항10.1'),
#  (6188, 6189): ('필수조항11', '필수조항12'),
#  (6190, 6191): ('필수조항11', '필수조항12'),
#  (6358, 6359): ('옵션조항3', '필수조항10.1'),
#  (6386, 6387): ('필수조항12', '필수조항7'),
#  (6428, 6429): ('옵션조항6', '필수조항12'),
#  (6438, 6439): ('옵션조항2', '필수조항4'),
#  (6597, 6598): ('필수조항11', '필수조항12'),
#  (6602, 6603): ('옵션조항2', '필수조항5'),
#  (6607, 6608): ('옵션조항2', '필수조항5'),
#  (6728, 6729): ('옵션조항2', '필수조항5'),
#  (6731, 6732): ('옵션조항2', '필수조항5'),
#  (6758, 6759): ('필수조항12', '필수조항4'),
#  (6792, 6793): ('옵션조항6', '필수조항12'),
#  (6797, 6798): ('옵션조항10', '필수조항12'),
#  (6847, 6848): ('옵션조항2', '필수조항10.1'),
#  (6856, 6857): ('옵션조항3', '필수조항10.1'),
#  (7001, 7002): ('필수조항11', '필수조항12'),
#  (7003, 7004): ('필수조항11', '필수조항12'),
#  (7152, 7153): ('필수조항12', '필수조항7'),
#  (7249, 7250): ('옵션조항3', '필수조항10.1'),
#  (7252, 7253): ('옵션조항2', '옵션조항3'),
#  (7302, 7303): ('옵션조항2', '필수조항4'),
#  (7330, 7331): ('필수조항11', '필수조항12'),
#  (7332, 7333): ('필수조항11', '필수조항12'),
#  (7346, 7347): ('옵션조항2', '필수조항5'),
#  (7350, 7351): ('필수조항12', '필수조항5'),
#  (7358, 7359): ('옵션조항2', '필수조항5'),
#  (7557, 7558): ('옵션조항2', '필수조항10.1'),
#  (7611, 7612): ('필수조항12', '필수조항6'),
#  (7761, 7762): ('옵션조항2', '필수조항5'),
#  (8036, 8037): ('필수조항12', '필수조항6'),
#  (8598, 8599): ('필수조항12', '필수조항6'),
#  (8714, 8715): ('옵션조항1', '옵션조항2'),
#  (8775, 8776): ('옵션조항2', '필수조항4'),
#  (8793, 8794): ('옵션조항3', '필수조항4'),
#  (8796, 8797): ('옵션조항3', '필수조항4'),
#  (8798, 8799): ('옵션조항3', '필수조항4'),
#  (8804, 8805): ('필수조항4', '필수조항9'),
#  (8841, 8842): ('옵션조항2', '필수조항10.1'),
#  (9208, 9209): ('필수조항11', '필수조항12'),
#  (9377, 9378): ('옵션조항3', '필수조항12'),
#  (9483, 9484): ('필수조항11', '필수조항12'),
#  (9667, 9668): ('옵션조항2', '옵션조항3'),
#  (9672, 9673): ('옵션조항2', '옵션조항3'),
#  (9695, 9696): ('옵션조항2', '옵션조항3'),
#  (9820, 9821): ('옵션조항2', '필수조항5'),
#  (9823, 9824): ('필수조항12', '필수조항5'),
#  (9879, 9880): ('옵션조항2', '옵션조항3'),
#  (9954, 9955): ('필수조항12', '필수조항6'),
#  (10042, 10043): ('옵션조항2', '필수조항7'),
#  (10082, 10083): ('필수조항11', '필수조항12'),
#  (10084, 10085): ('필수조항11', '필수조항12'),
#  (10086, 10087): ('필수조항11', '필수조항12'),
#  (10162, 10163): ('필수조항12', '필수조항3'),
#  (10181, 10182): ('필수조항10', '필수조항7'),
#  (10184, 10185): ('옵션조항3', '필수조항12'),
#  (10276, 10277): ('필수조항12', '필수조항4'),
#  (10368, 10369): ('필수조항12', '필수조항6'),
#  (10372, 10373): ('옵션조항2', '옵션조항5'),
#  (10376, 10377): ('옵션조항12', '옵션조항5'),
#  (10384, 10385): ('옵션조항2', '옵션조항5'),
#  (10669, 10670): ('옵션조항2', '필수조항4'),
#  (10676, 10677): ('옵션조항2', '필수조항7'),
#  (10700, 10701): ('필수조항11', '필수조항12'),
#  (10702, 10703): ('필수조항11', '필수조항12'),
#  (10937, 10938): ('필수조항11', '필수조항12'),
#  (10938, 10939): ('옵션조항1', '필수조항12'),
#  (10974, 10975): ('필수조항10', '필수조항11'),
#  (10976, 10977): ('필수조항10', '필수조항11'),
#  (10978, 10979): ('필수조항10', '필수조항11'),
#  (10980, 10981): ('필수조항10', '필수조항11'),
#  (11057, 11058): ('옵션조항2', '필수조항4'),
#  (11068, 11069): ('옵션조항2', '필수조항7'),
#  (11103, 11104): ('필수조항10.1', '필수조항4'),
#  (11207, 11208): ('필수조항11', '필수조항12'),
#  (11212, 11213): ('필수조항11', '필수조항12'),
#  (11411, 11412): ('옵션조항2', '옵션조항3'),
#  (11605, 11606): ('필수조항11', '필수조항11'),
#  (11656, 11657): ('필수조항13', '필수조항5'),
#  (11709, 11710): ('필수조항2', '필수조항9'),
#  (11807, 11808): ('필수조항11', '필수조항12'),
#  (11850, 11851): ('필수조항11', '필수조항12'),
#  (11916, 11917): ('필수조항11', '필수조항12'),
#  (11978, 11979): ('필수조항11', '필수조항12'),
#  (12097, 12098): ('필수조항11', '필수조항12'),
#  (12223, 12224): ('옵션조항1', '필수조항8'),
#  (12313, 12314): ('옵션조항2', '필수조항4'),
#  (12398, 12399): ('필수조항12', '필수조항6'),
#  (12415, 12416): ('필수조항11', '필수조항12'),
#  (12603, 12604): ('필수조항11', '필수조항12'),
#  (12950, 12951): ('옵션조항2', '필수조항4'),
#  (13013, 13014): ('옵션조항2', '필수조항10.1'),
#  (13506, 13507): ('옵션조항6', '필수조항9'),
#  (13529, 13530): ('옵션조항2', '필수조항5'),
#  (13652, 13653): ('필수조항11', '필수조항12'),
#  (13778, 13779): ('옵션조항2', '필수조항5'),
#  (13813, 13814): ('필수조항11', '필수조항12'),
#  (13987, 13988): ('옵션조항2', '옵션조항3'),
#  (14013, 14014): ('옵션조항2', '필수조항5'),
#  (14041, 14042): ('필수조항11', '필수조항12'),
#  (14211, 14212): ('옵션조항3', '필수조항4'),
#  (14213, 14214): ('옵션조항3', '필수조항4'),
#  (14406, 14407): ('옵션조항2', '옵션조항3'),
#  (14531, 14532): ('옵션조항2', '필수조항7'),
#  (14539, 14540): ('옵션조항2', '필수조항4'),
#  (14564, 14565): ('필수조항11', '필수조항12'),
#  (14583, 14584): ('옵션조항2', '필수조항5'),
#  (14650, 14651): ('옵션조항2', '옵션조항3'),
#  (14776, 14777): ('옵션조항2', '필수조항7'),
#  (14784, 14785): ('옵션조항2', '필수조항4'),
#  (14809, 14810): ('필수조항11', '필수조항12'),
#  (14828, 14829): ('옵션조항2', '필수조항5'),
#  (15195, 15196): ('필수조항11', '필수조항12'),
#  (15523, 15524): ('필수조항11', '필수조항12'),
#  (15694, 15695): ('옵션조항2', '필수조항4'),
#  (15758, 15759): ('필수조항11', '필수조항12'),
#  (15802, 15803): ('필수조항12', '필수조항6'),
#  (15868, 15869): ('필수조항10.1', '필수조항11'),
#  (15870, 15871): ('필수조항10', '필수조항11'),
#  (15934, 15935): ('필수조항13', '필수조항5'),
#  (15936, 15937): ('필수조항12', '필수조항5'),
#  (15975, 15976): ('필수조항7', '필수조항9'),
#  (16145, 16146): ('옵션조항1', '필수조항12'),
#  (16182, 16183): ('옵션조항2', '옵션조항3'),
#  (16234, 16235): ('옵션조항2', '옵션조항3'),
#  (16275, 16276): ('옵션조항2', '필수조항7'),
#  (16291, 16292): ('옵션조항2', '필수조항4'),
#  (16308, 16309): ('필수조항11', '필수조항12'),
#  (16320, 16321): ('필수조항11', '필수조항12'),
#  (16570, 16571): ('옵션조항2', '필수조항10.1'),
#  (16579, 16580): ('옵션조항3', '필수조항10.1'),
#  (16701, 16702): ('필수조항12', '필수조항7'),
#  (16707, 16708): ('옵션조항2', '필수조항11'),
#  (16726, 16727): ('필수조항11', '필수조항12'),
#  (16728, 16729): ('필수조항11', '필수조항12'),
#  (16860, 16861): ('필수조항11', '필수조항12'),
#  (16878, 16879): ('옵션조항3', '필수조항7'),
#  (16898, 16899): ('필수조항12', '필수조항4'),
#  (16959, 16960): ('옵션조항2', '필수조항5'),
#  (16962, 16963): ('필수조항12', '필수조항5'),
#  (17001, 17002): ('옵션조항2', '필수조항10.1'),
#  (17010, 17011): ('옵션조항3', '필수조항10.1'),
#  (17173, 17174): ('옵션조항2', '필수조항11'),
#  (17191, 17192): ('필수조항11', '필수조항12'),
#  (17193, 17194): ('필수조항11', '필수조항12'),
#  (17361, 17362): ('옵션조항2', '필수조항5'),
#  (17465, 17466): ('옵션조항2', '필수조항10.1'),
#  (17474, 17475): ('옵션조항3', '필수조항10.1'),
#  (17595, 17596): ('필수조항12', '필수조항7'),
#  (17601, 17602): ('옵션조항2', '필수조항7'),
#  (17608, 17609): ('옵션조항2', '필수조항11'),
#  (17626, 17627): ('필수조항11', '필수조항12'),
#  (17628, 17629): ('필수조항11', '필수조항12'),
#  (17776, 17777): ('옵션조항2', '필수조항5'),
#  (17779, 17780): ('옵션조항2', '필수조항5'),
#  (17816, 17817): ('필수조항12', '필수조항4'),
#  (17845, 17846): ('옵션조항6', '필수조항12'),
#  (17850, 17851): ('옵션조항10', '필수조항12'),
#  (17869, 17870): ('필수조항12', '필수조항5'),
#  (17872, 17873): ('옵션조항2', '필수조항5'),
#  (17911, 17912): ('옵션조항2', '필수조항10.1'),
#  (17920, 17921): ('옵션조항3', '필수조항10.1'),
#  (18066, 18067): ('필수조항11', '필수조항12'),
#  (18068, 18069): ('필수조항11', '필수조항12'),
#  (18140, 18141): ('필수조항12', '필수조항6'),
#  (18181, 18182): ('필수조항7', '필수조항9'),
#  (18217, 18218): ('필수조항10.1', '필수조항11'),
#  (18219, 18220): ('필수조항10', '필수조항11'),
#  (18402, 18403): ('필수조항11', '필수조항12'),
#  (18536, 18537): ('필수조항11', '필수조항12'),
#  (18730, 18731): ('필수조항10.1', '필수조항11'),
#  (18734, 18735): ('필수조항10', '필수조항11'),
#  (18760, 18761): ('필수조항13', '필수조항5'),
#  (18914, 18915): ('필수조항11', '필수조항12'),
#  (19049, 19050): ('필수조항11', '필수조항12'),
#  (19056, 19057): ('필수조항11', '필수조항12'),
#  (19331, 19332): ('필수조항11', '필수조항12'),
#  (19337, 19338): ('필수조항11', '필수조항12'),
#  (19677, 19678): ('필수조항12', '필수조항6'),
#  (19683, 19684): ('옵션조항3', '필수조항11'),
#  (19770, 19771): ('필수조항13', '필수조항5'),
#  (19899, 19900): ('필수조항11', '필수조항12'),
#  (19903, 19904): ('필수조항11', '필수조항12'),
#  (19970, 19971): ('필수조항11', '필수조항12'),
#  (20511, 20512): ('필수조항12', '필수조항6'),
#  (20582, 20583): ('필수조항10', '필수조항6'),
#  (20643, 20644): ('필수조항12', '필수조항6'),
#  (20714, 20715): ('필수조항12', '필수조항6'),
#  (20867, 20868): ('필수조항10', '필수조항11'),
#  (20949, 20950): ('필수조항10', '필수조항11'),
#  (20988, 20989): ('필수조항7', '필수조항9'),
#  (21024, 21025): ('필수조항10.1', '필수조항11'),
#  (21026, 21027): ('필수조항10', '필수조항11'),
#  (21186, 21187): ('필수조항10.1', '필수조항12'),
#  (21356, 21357): ('필수조항10', '필수조항7'),
#  (21358, 21359): ('필수조항10', '필수조항7'),
#  (21412, 21413): ('필수조항10.1', '필수조항11'),
#  (21939, 21940): ('필수조항10', '필수조항10'),
#  (21940, 21941): ('필수조항10', '필수조항11'),
#  (21982, 21983): ('필수조항10', '필수조항11'),
#  (21984, 21985): ('필수조항10.1', '필수조항11'),
#  (22189, 22190): ('필수조항10.1', '필수조항11'),
#  (22191, 22192): ('필수조항10.1', '필수조항11'),
#  (22715, 22716): ('필수조항12', '필수조항7'),
#  (22830, 22831): ('필수조항10', '필수조항6'),
#  (22874, 22875): ('필수조항11', '필수조항12'),
#  (22879, 22880): ('필수조항10.1', '필수조항11'),
#  (22954, 22955): ('필수조항10', '필수조항6'),
#  (22959, 22960): ('필수조항13', '필수조항5'),
#  (22966, 22967): ('필수조항11', '필수조항12'),
#  (22972, 22973): ('필수조항10', '필수조항11'),
#  (23186, 23187): ('필수조항12', '필수조항7'),
#  (23206, 23207): ('필수조항10.1', '필수조항11'),
#  (23208, 23209): ('필수조항10', '필수조항11'),
#  (23491, 23492): ('필수조항10', '필수조항11'),
#  (23655, 23656): ('필수조항10', '필수조항11'),
#  (23828, 23829): ('필수조항12', '필수조항6'),
#  (23936, 23937): ('옵션조항3', '필수조항11'),
#  (24175, 24176): ('필수조항11', '필수조항12'),
#  (24177, 24178): ('필수조항11', '필수조항12'),
#  (24179, 24180): ('필수조항11', '필수조항12'),
#  (24287, 24288): ('필수조항10', '필수조항5'),
#  (24528, 24529): ('옵션조항3', '필수조항11'),
#  (24761, 24762): ('필수조항10', '필수조항11'),
#  (24776, 24777): ('옵션조항1', '필수조항11'),
#  (24782, 24783): ('필수조항12', '필수조항4'),
#  (24784, 24785): ('필수조항12', '필수조항4'),
#  (24814, 24815): ('필수조항12', '필수조항5'),
#  (24822, 24823): ('옵션조항3', '필수조항12'),
#  (24826, 24827): ('필수조항12', '필수조항6'),
#  (24854, 24855): ('필수조항11', '필수조항12'),
#  (24856, 24857): ('필수조항10', '필수조항11'),
#  (25061, 25062): ('필수조항11', '필수조항4'),
#  (25075, 25076): ('필수조항10', '필수조항7'),
#  (25084, 25085): ('필수조항10', '필수조항7'),
#  (25128, 25129): ('필수조항13', '필수조항5'),
#  (25241, 25242): ('필수조항12', '필수조항6'),
#  (25295, 25296): ('필수조항10', '필수조항7'),
#  (25297, 25298): ('필수조항12', '필수조항7'),
#  (25327, 25328): ('필수조항11', '필수조항12'),
#  (25369, 25370): ('필수조항10', '필수조항12'),
#  (25389, 25390): ('필수조항10', '필수조항6'),
#  (25662, 25663): ('필수조항10.1', '필수조항6'),
#  (25735, 25736): ('필수조항10', '필수조항9'),
#  (25843, 25844): ('필수조항11', '필수조항12'),
#  (25857, 25858): ('필수조항12', '필수조항6'),
#  (25977, 25978): ('필수조항11', '필수조항12'),
#  (26148, 26149): ('필수조항12', '필수조항5'),
#  (26157, 26158): ('필수조항12', '필수조항6'),
#  (26164, 26165): ('필수조항12', '필수조항6'),
#  (26174, 26175): ('필수조항11', '필수조항12'),
#  (26175, 26176): ('필수조항12', '필수조항13'),
#  (26255, 26256): ('필수조항12', '필수조항5'),
#  (26257, 26258): ('필수조항12', '필수조항5'),
#  (26264, 26265): ('필수조항12', '필수조항6'),
#  (26278, 26279): ('필수조항11', '필수조항12'),
#  (26361, 26362): ('필수조항12', '필수조항5'),
#  (26363, 26364): ('필수조항12', '필수조항5'),
#  (26370, 26371): ('필수조항12', '필수조항6'),
#  (26384, 26385): ('필수조항11', '필수조항12'),
#  (26385, 26386): ('필수조항12', '필수조항13'),
#  (26489, 26490): ('필수조항12', '필수조항6'),
#  (26522, 26523): ('필수조항13', '필수조항5'),
#  (26612, 26613): ('필수조항10', '필수조항12'),
#  (26669, 26670): ('필수조항11', '필수조항12'),
#  (26731, 26732): ('옵션조항3', '필수조항10'),
#  (26757, 26758): ('필수조항11', '필수조항12'),
#  (26771, 26772): ('필수조항12', '필수조항6'),
#  (26953, 26954): ('nan', '필수조항12'),
#  (26954, 26955): ('필수조항12', '필수조항12'),
#  (27043, 27044): ('필수조항12', '필수조항5'),
#  (27064, 27065): ('필수조항11', '필수조항12'),
#  (27065, 27066): ('필수조항11', '필수조항13'),
#  (27314, 27315): ('필수조항13', '필수조항5'),
#  (27338, 27339): ('필수조항11', '필수조항12'),
#  (27865, 27866): ('필수조항11', '필수조항12'),
#  (27917, 27918): ('필수조항12', '필수조항6'),
#  (27921, 27922): ('필수조항11', '필수조항12'),
#  (27971, 27972): ('필수조항13', '필수조항5'),
#  (27988, 27989): ('필수조항10.1', '필수조항11'),
#  (27997, 27998): ('필수조항12', '필수조항4'),
#  (27999, 28000): ('필수조항12', '필수조항4'),
#  (28216, 28217): ('필수조항11', '필수조항12'),
#  (28236, 28237): ('필수조항12', '필수조항6'),
#  (28820, 28821): ('필수조항12', '필수조항9'),
#  (28876, 28877): ('필수조항11', '필수조항12'),
#  (28955, 28956): ('필수조항12', '필수조항9'),
#  (29011, 29012): ('필수조항11', '필수조항12'),
#  (29090, 29091): ('필수조항12', '필수조항9'),
#  (29146, 29147): ('필수조항11', '필수조항12'),
#  (29381, 29382): ('필수조항11', '필수조항12'),
#  (29463, 29464): ('필수조항11', '필수조항12'),
#  (29614, 29615): ('필수조항10', '필수조항11'),
#  (29685, 29686): ('필수조항5', '필수조항6'),
#  (29686, 29687): ('필수조항12', '필수조항6'),
#  (29734, 29735): ('옵션조항1', '필수조항8'),
#  (29736, 29737): ('옵션조항1', '필수조항8'),
#  (29789, 29790): ('필수조항12', '필수조항5'),
#  (29803, 29804): ('필수조항11', '필수조항12'),
#  (29807, 29808): ('필수조항12', '필수조항6'),
#  (29918, 29919): ('필수조항10', '필수조항11'),
#  (29920, 29921): ('필수조항10.1', '필수조항11'),
#  (30058, 30059): ('필수조항11', '필수조항12'),
#  (30123, 30124): ('필수조항11', '필수조항12'),
#  (30356, 30357): ('필수조항11', '필수조항12'),
#  (30359, 30360): ('필수조항11', '필수조항13'),
#  (30364, 30365): ('옵션조항2', '필수조항5'),
#  (30366, 30367): ('옵션조항2', '필수조항5'),
#  (30368, 30369): ('옵션조항2', '필수조항5'),
#  (30370, 30371): ('옵션조항2', '필수조항5'),
#  (30467, 30468): ('필수조항12', '필수조항6'),
#  (30525, 30526): ('필수조항11', '필수조항12'),
#  (30559, 30560): ('필수조항12', '필수조항5'),
#  (30678, 30679): ('필수조항7', '필수조항9'),
#  (30687, 30688): ('필수조항6', '필수조항7'),
#  (30702, 30703): ('필수조항10.1', '필수조항11'),
#  (30704, 30705): ('필수조항10', '필수조항11'),
#  (30841, 30842): ('필수조항12', '필수조항6'),
#  (31028, 31029): ('필수조항12', '필수조항6'),
#  (31045, 31046): ('필수조항11', '필수조항12'),
#  (31050, 31051): ('필수조항11', '필수조항12'),
#  (31173, 31174): ('필수조항10', '필수조항11'),
#  (31179, 31180): ('필수조항10', '필수조항11'),
#  (31186, 31187): ('필수조항13', '필수조항5'),
#  (31313, 31314): ('필수조항10', '필수조항5'),
#  (31316, 31317): ('필수조항12', '필수조항6'),
#  (31419, 31420): ('필수조항4', '필수조항7'),
#  (31427, 31428): ('필수조항12', '필수조항6'),
#  (31434, 31435): ('필수조항10', '필수조항11'),
#  (31474, 31475): ('필수조항12', '필수조항6'),
#  (31691, 31692): ('옵션조항1', '필수조항10.1'),
#  (31693, 31694): ('옵션조항1', '필수조항10'),
#  (31756, 31757): ('옵션조항3', '필수조항10.1'),
#  (31814, 31815): ('옵션조항2', '필수조항7'),
#  (31822, 31823): ('옵션조항2', '필수조항4'),
#  (31843, 31844): ('필수조항11', '필수조항12'),
#  (31845, 31846): ('필수조항11', '필수조항12'),
#  (31848, 31849): ('필수조항11', '필수조항12'),
#  (32045, 32046): ('필수조항10', '필수조항5'),
#  (32103, 32104): ('필수조항13', '필수조항5'),
#  (32127, 32128): ('필수조항11', '필수조항12'),
#  (32398, 32399): ('필수조항13', '필수조항5'),
#  (32445, 32446): ('필수조항11', '필수조항12'),
#  (32649, 32650): ('필수조항12', '필수조항6'),
#  (32666, 32667): ('필수조항11', '필수조항12'),
#  (32670, 32671): ('옵션조항3', '필수조항11'),
#  (32672, 32673): ('필수조항11', '필수조항12'),
#  (33077, 33078): ('필수조항11', '필수조항12'),
#  (33354, 33355): ('옵션조항3', '필수조항7'),
#  (33361, 33362): ('필수조항11', '필수조항7'),
#  (33368, 33369): ('필수조항11', '필수조항12'),
#  (33443, 33444): ('필수조항12', '필수조항6'),
#  (33633, 33634): ('필수조항12', '필수조항6'),
#  (33645, 33646): ('필수조항11', '필수조항12'),
#  (33822, 33823): ('필수조항11', '필수조항7'),
#  (34233, 34234): ('필수조항10', '필수조항11'),
#  (34588, 34589): ('필수조항12', '필수조항6'),
#  (34698, 34699): ('필수조항7', '필수조항8'),
#  (34836, 34837): ('필수조항12', '필수조항7'),
#  (34855, 34856): ('필수조항11', '필수조항12'),
#  (34903, 34904): ('필수조항10', '필수조항11'),
#  (34910, 34911): ('필수조항11', '필수조항12'),
#  (34953, 34954): ('필수조항7', '필수조항9'),
#  (35002, 35003): ('필수조항10', '필수조항6'),
#  (35036, 35037): ('필수조항12', '필수조항7'),
#  (35126, 35127): ('필수조항12', '필수조항6'),
#  (35231, 35232): ('필수조항12', '필수조항7'),
#  (35241, 35242): ('필수조항11', '필수조항12'),
#  (35299, 35300): ('필수조항10', '필수조항11'),
#  (35301, 35302): ('필수조항10', '필수조항11'),
#  (35327, 35328): ('필수조항13', '필수조항6'),
#  (35330, 35331): ('필수조항10', '필수조항11'),
#  (35332, 35333): ('필수조항10.1', '필수조항11'),
#  (35360, 35361): ('필수조항10', '필수조항11'),
#  (35363, 35364): ('필수조항10.1', '필수조항11'),
#  (35365, 35366): ('필수조항10.1', '필수조항11'),
#  (35367, 35368): ('필수조항10', '필수조항11'),
#  (35374, 35375): ('필수조항10.1', '필수조항11'),
#  (35497, 35498): ('필수조항11', '필수조항12'),
#  (35568, 35569): ('필수조항11', '필수조항12'),
#  (35752, 35753): ('필수조항4', '필수조항9'),
#  (35769, 35770): ('필수조항11', '필수조항12'),
#  (35865, 35866): ('필수조항11', '필수조항12'),
#  (35922, 35923): ('필수조항10', '필수조항11'),
#  (35925, 35926): ('필수조항11', '필수조항12'),
#  (35931, 35932): ('필수조항13', '필수조항5'),
#  (35937, 35938): ('필수조항10', '필수조항4'),
#  (36129, 36130): ('필수조항10', '필수조항9'),
#  (36155, 36156): ('필수조항12', '필수조항6'),
#  (36174, 36175): ('필수조항11', '필수조항12'),
#  (36224, 36225): ('필수조항11', '필수조항12'),
#  (36279, 36280): ('필수조항10.1', '필수조항9'),
#  (36290, 36291): ('필수조항11', '필수조항12'),
#  (36423, 36424): ('필수조항11', '필수조항12'),
#  (36427, 36428): ('옵션조항3', '필수조항11'),
#  (36429, 36430): ('필수조항11', '필수조항12'),
#  (36478, 36479): ('필수조항11', '필수조항6'),
#  (36493, 36494): ('필수조항11', '필수조항12'),
#  (36522, 36523): ('필수조항2', '필수조항9'),
#  (36539, 36540): ('필수조항10', '필수조항6'),
#  (36540, 36541): ('필수조항10', '필수조항12'),
#  (36547, 36548): ('필수조항10', '필수조항11'),
#  (36708, 36709): ('필수조항10', '필수조항11'),
#  (37291, 37292): ('필수조항10', '필수조항5'),
#  (37404, 37405): ('옵션조항3', '필수조항4'),
#  (37414, 37415): ('필수조항12', '필수조항7'),
#  (37417, 37418): ('필수조항13', '필수조항5'),
#  (37449, 37450): ('필수조항11', '필수조항12'),
#  (37507, 37508): ('옵션조항3', '필수조항11'),
#  (37517, 37518): ('필수조항11', '필수조항8'),
#  (37519, 37520): ('필수조항10', '필수조항11'),
#  (37967, 37968): ('필수조항1', '필수조항2'),
#  (38021, 38022): ('필수조항10', '필수조항11'),
#  (38189, 38190): ('필수조항11', '필수조항12'),
#  (38191, 38192): ('필수조항11', '필수조항12'),
#  (38217, 38218): ('필수조항11', '필수조항12'),
#  (38261, 38262): ('필수조항12', '필수조항6'),
#  (38410, 38411): ('필수조항11', '필수조항12'),
#  (38548, 38549): ('필수조항11', '필수조항12'),
#  (38589, 38590): ('필수조항11', '필수조항12'),
#  (38591, 38592): ('필수조항11', '필수조항12'),
#  (38643, 38644): ('필수조항5', '필수조항6'),
#  (38727, 38728): ('옵션조항3', '필수조항11'),
#  (38731, 38732): ('필수조항10', '필수조항6'),
#  (38815, 38816): ('옵션조항3', '필수조항11'),
#  (38830, 38831): ('필수조항12', '필수조항6'),
#  (38853, 38854): ('필수조항11', '필수조항12'),
#  (39009, 39010): ('필수조항11', '필수조항12'),
#  (39096, 39097): ('필수조항12', '필수조항5'),
#  (39098, 39099): ('필수조항12', '필수조항5'),
#  (39105, 39106): ('필수조항12', '필수조항6'),
#  (39122, 39123): ('필수조항11', '필수조항12'),
#  (39127, 39128): ('필수조항11', '필수조항12'),
#  (39653, 39654): ('필수조항4', '필수조항9'),
#  (39819, 39820): ('필수조항11', '필수조항12'),
#  (39867, 39868): ('필수조항11', '필수조항12'),
#  (39878, 39879): ('필수조항10', '필수조항11'),
#  (39990, 39991): ('필수조항10', '필수조항11'),
#  (39992, 39993): ('필수조항10.1', '필수조항11'),
#  (40195, 40196): ('필수조항11', '필수조항4'),
#  (40475, 40476): ('필수조항10.1', '필수조항11'),
#  (40531, 40532): ('필수조항11', '필수조항12'),
#  (40722, 40723): ('필수조항4', '필수조항7'),
#  (40738, 40739): ('필수조항10', '필수조항11'),
#  (40915, 40916): ('필수조항10.1', '필수조항11'),
#  (40916, 40917): ('필수조항10.1', '필수조항5'),
#  (40918, 40919): ('필수조항10', '필수조항11'),
#  (40919, 40920): ('필수조항10', '필수조항5'),
#  (41070, 41071): ('필수조항10.1', '필수조항11'),
#  (41073, 41074): ('필수조항10', '필수조항11'),
#  (41075, 41076): ('필수조항10.1', '필수조항11'),
#  (41166, 41167): ('필수조항13', '필수조항5'),
#  (41176, 41177): ('필수조항11', '필수조항12'),
#  (41210, 41211): ('필수조항13', '필수조항5'),
#  (41220, 41221): ('필수조항11', '필수조항12'),
#  (41291, 41292): ('필수조항12', '필수조항6'),
#  (41308, 41309): ('필수조항11', '필수조항12'),
#  (41313, 41314): ('필수조항11', '필수조항12'),
#  (41490, 41491): ('필수조항3', '필수조항9'),
#  (41546, 41547): ('필수조항11', '필수조항12'),
#  (41592, 41593): ('필수조항11', '필수조항12'),
#  (42261, 42262): ('필수조항11', '필수조항12'),
#  (42445, 42446): ('필수조항10.1', '필수조항11'),
#  (42541, 42542): ('필수조항13', '필수조항5'),
#  (42551, 42552): ('필수조항11', '필수조항12'),
#  (42653, 42654): ('필수조항11', '필수조항4'),
#  (42823, 42824): ('필수조항11', '필수조항12'),
#  (42827, 42828): ('필수조항11', '필수조항12'),
#  (42872, 42873): ('필수조항11', '필수조항12'),
#  (42915, 42916): ('필수조항1', '필수조항2'),
#  (42927, 42928): ('필수조항11', '필수조항5'),
#  (42947, 42948): ('필수조항11', '필수조항12'),
#  (42949, 42950): ('필수조항11', '필수조항12'),
#  (43058, 43059): ('필수조항3', '필수조항8'),
#  (43155, 43156): ('필수조항11', '필수조항12'),
#  (43159, 43160): ('필수조항10.1', '필수조항11'),
#  (43161, 43162): ('필수조항10.1', '필수조항11'),
#  (43194, 43195): ('필수조항11', '필수조항12'),
#  (43198, 43199): ('필수조항10.1', '필수조항11'),
#  (43200, 43201): ('필수조항10', '필수조항11'),
#  (43271, 43272): ('필수조항11', '필수조항12'),
#  (43286, 43287): ('필수조항10', '필수조항8'),
#  (43459, 43460): ('필수조항11', '필수조항12'),
#  (43656, 43657): ('필수조항11', '필수조항12'),
#  (43662, 43663): ('필수조항10', '필수조항11'),
#  (43857, 43858): ('필수조항11', '필수조항12'),
#  (43987, 43988): ('필수조항11', '필수조항12'),
#  (44017, 44018): ('필수조항5', '필수조항6'),
#  (44339, 44340): ('필수조항13', '필수조항5'),
#  (44387, 44388): ('필수조항11', '필수조항12'),
#  (44789, 44790): ('필수조항11', '필수조항12'),
#  (44796, 44797): ('필수조항11', '필수조항12'),
#  (44907, 44908): ('필수조항11', '필수조항12'),
#  (45304, 45305): ('필수조항12', '필수조항6'),
#  (45365, 45366): ('필수조항10', '필수조항7'),
#  (45367, 45368): ('필수조항4', '필수조항7'),
#  (45375, 45376): ('필수조항5', '필수조항6'),
#  (45376, 45377): ('필수조항12', '필수조항6'),
#  (45383, 45384): ('필수조항10', '필수조항11'),
#  (45814, 45815): ('필수조항10.1', '필수조항11'),
#  (45859, 45860): ('필수조항11', '필수조항12'),
#  (45888, 45889): ('필수조항7', '필수조항9'),
#  (45908, 45909): ('필수조항3', '필수조항8'),
#  (45926, 45927): ('필수조항10.1', '필수조항11'),
#  (45928, 45929): ('필수조항10', '필수조항11'),
#  (46068, 46069): ('필수조항10', '필수조항11'),
#  (46117, 46118): ('필수조항7', '필수조항9'),
#  (46140, 46141): ('필수조항10', '필수조항5'),
#  (46144, 46145): ('필수조항12', '필수조항6'),
#  (46148, 46149): ('필수조항12', '필수조항6'),
#  (46200, 46201): ('필수조항11', '필수조항12'),
#  (46412, 46413): ('필수조항13', '필수조항5'),
#  (46422, 46423): ('필수조항11', '필수조항12'),
#  (46818, 46819): ('필수조항10', '필수조항5'),
#  (47075, 47076): ('필수조항12', '필수조항6'),
#  (47081, 47082): ('옵션조항3', '필수조항11'),
#  (47211, 47212): ('필수조항13', '필수조항5'),
#  (47213, 47214): ('필수조항13', '필수조항5'),
#  (47215, 47216): ('필수조항13', '필수조항5'),
#  (47272, 47273): ('필수조항10', '필수조항13'),
#  (47275, 47276): ('필수조항12', '필수조항6'),
#  (47322, 47323): ('옵션조항3', '필수조항11'),
#  (47344, 47345): ('필수조항12', '필수조항6'),
#  (47391, 47392): ('필수조항12', '필수조항6'),
#  (47474, 47475): ('필수조항11', '필수조항12'),
#  (47495, 47496): ('옵션조항3', '필수조항11'),
#  (47510, 47511): ('필수조항12', '필수조항6'),
#  (47590, 47591): ('필수조항7', '필수조항9'),
#  (47616, 47617): ('필수조항12', '필수조항6'),
#  (47738, 47739): ('옵션조항1', '필수조항12'),
#  (47780, 47781): ('필수조항12', '필수조항6'),
#  (47992, 47993): ('필수조항11', '필수조항12'),
#  (48029, 48030): ('필수조항13', '필수조항5'),
#  (48039, 48040): ('필수조항11', '필수조항12'),
#  (48228, 48229): ('필수조항10.1', '필수조항11'),
#  (48353, 48354): ('옵션조항1', '옵션조항3'),
#  (48509, 48510): ('필수조항12', '필수조항6'),
#  (48618, 48619): ('필수조항10.1', '필수조항5'),
#  (48620, 48621): ('필수조항10.1', '필수조항5'),
#  (49145, 49146): ('필수조항12', '필수조항6'),
#  (49167, 49168): ('필수조항12', '필수조항5'),
#  (49311, 49312): ('필수조항12', '필수조항3'),
#  (49314, 49315): ('필수조항11', '필수조항12'),
#  (49332, 49333): ('필수조항12', '필수조항5'),
#  (49334, 49335): ('필수조항12', '필수조항5'),
#  (49341, 49342): ('필수조항12', '필수조항6'),
#  (49406, 49407): ('옵션조항3', '필수조항7'),
#  (49496, 49497): ('필수조항1', '필수조항2'),
#  (50039, 50040): ('필수조항11', '필수조항12'),
#  (50048, 50049): ('필수조항12', '필수조항6'),
#  (50056, 50057): ('필수조항11', '필수조항12'),
#  (50169, 50170): ('필수조항12', '필수조항6'),
#  (50307, 50308): ('필수조항12', '필수조항6'),
#  (50520, 50521): ('필수조항12', '필수조항6'),
#  (50612, 50613): ('필수조항13', '필수조항5'),
#  (50635, 50636): ('필수조항12', '필수조항6'),
#  (50648, 50649): ('필수조항10.1', '필수조항11'),
#  (50650, 50651): ('필수조항10.1', '필수조항11'),
#  (50654, 50655): ('필수조항12', '필수조항5'),
#  (50823, 50824): ('필수조항12', '필수조항6'),
#  (51281, 51282): ('필수조항11', '필수조항12'),
#  (51379, 51380): ('필수조항11', '필수조항12'),
#  (51476, 51477): ('필수조항11', '필수조항12'),
#  (51589, 51590): ('필수조항1', '필수조항2'),
#  (51613, 51614): ('필수조항11', '필수조항12'),
#  (51622, 51623): ('필수조항12', '필수조항6'),
#  (51629, 51630): ('필수조항13', '필수조항5'),
#  (51631, 51632): ('필수조항13', '필수조항5'),
#  (52824, 52825): ('필수조항11', '필수조항12'),
#  (53064, 53065): ('필수조항12', '필수조항6'),
#  (53149, 53150): ('필수조항10.1', '필수조항11'),
#  (53305, 53306): ('필수조항13', '필수조항5'),
#  (53519, 53520): ('필수조항4', '필수조항9'),
#  (53917, 53918): ('필수조항12', '필수조항6'),
#  (54286, 54287): ('옵션조항3', '필수조항11'),
#  (55846, 55847): ('필수조항4', '필수조항9'),
#  (55851, 55852): ('필수조항12', '필수조항5'),
#  (55870, 55871): ('필수조항13', '필수조항5'),
#  (56841, 56842): ('필수조항10', '필수조항11'),
#  (58123, 58124): ('필수조항4', '필수조항9'),
#  (58568, 58569): ('필수조항4', '필수조항9'),
#  (59565, 59566): ('필수조항10', '필수조항5'),
#  (61067, 61068): ('필수조항12', '필수조항6'),
#  (62272, 62273): ('필수조항11', '필수조항12'),
#  (62915, 62916): ('필수조항11', '필수조항12'),
#  (63140, 63141): ('필수조항11', '필수조항12'),
#  (63311, 63312): ('필수조항11', '필수조항12'),
#  (64093, 64094): ('필수조항11', '필수조항12'),
#  (64539, 64540): ('필수조항11', '필수조항12'),
#  (65021, 65022): ('필수조항11', '필수조항12'),
#  (65350, 65351): ('필수조항11', '필수조항12'),
#  (66705, 66706): ('필수조항11', '필수조항12'),
#  (66946, 66947): ('필수조항11', '필수조항12'),
#  (67006, 67007): ('필수조항11', '필수조항12'),
#  (67102, 67103): ('필수조항11', '필수조항12'),
#  (67388, 67389): ('옵션조항3', '필수조항11'),
#  (67684, 67685): ('필수조항11', '필수조항12'),
#  (68065, 68066): ('필수조항11', '필수조항12'),
#  (68199, 68200): ('필수조항10', '필수조항6'),
#  (68742, 68743): ('필수조항12', '필수조항6'),
#  (69076, 69077): ('필수조항4', '필수조항9'),
#  (69111, 69112): ('필수조항13', '필수조항5'),
#  (69405, 69406): ('필수조항4', '필수조항9'),
#  (69872, 69873): ('필수조항10', '필수조항4'),
#  (69920, 69921): ('필수조항13', '필수조항5'),
#  (69922, 69923): ('필수조항13', '필수조항5'),
#  (69926, 69927): ('필수조항12', '필수조항6'),
#  (70406, 70407): ('필수조항4', '필수조항9'),
#  (70873, 70874): ('필수조항12', '필수조항6'),
#  (70949, 70950): ('필수조항11', '필수조항12'),
#  (70951, 70952): ('필수조항11', '필수조항12'),
#  (70953, 70954): ('필수조항11', '필수조항12'),
#  (70955, 70956): ('필수조항11', '필수조항12'),
#  (70962, 70963): ('필수조항7', '필수조항9'),
#  (72266, 72267): ('필수조항10.1', '필수조항11'),
#  (72268, 72269): ('필수조항10', '필수조항11'),
#  (72778, 72779): ('필수조항7', '필수조항8'),
#  (73292, 73293): ('필수조항4', '필수조항9'),
#  (73883, 73884): ('필수조항13', '필수조항5'),
#  (73964, 73965): ('필수조항11', '필수조항12')}

# %%
count_list
# Out:
# [(('필수조항11', '필수조항12'), 204),
#  (('필수조항12', '필수조항6'), 71),
#  (('옵션조항2', '필수조항5'), 54),
#  (('필수조항10', '필수조항11'), 49),
#  (('필수조항10.1', '필수조항11'), 33),
#  (('필수조항13', '필수조항5'), 32),
#  (('필수조항12', '필수조항5'), 28),
#  (('옵션조항2', '필수조항4'), 20),
#  (('옵션조항3', '필수조항10.1'), 19),
#  (('옵션조항2', '필수조항10.1'), 18),
#  (('필수조항12', '필수조항4'), 16),
#  (('필수조항12', '필수조항7'), 16),
#  (('옵션조항2', '옵션조항3'), 16),
#  (('옵션조항3', '필수조항11'), 13),
#  (('옵션조항6', '필수조항12'), 11),
#  (('필수조항4', '필수조항9'), 11),
#  (('옵션조항2', '필수조항7'), 10),
#  (('필수조항10', '필수조항6'), 9),
#  (('옵션조항10', '필수조항12'), 9),
#  (('필수조항7', '필수조항9'), 9),
#  (('필수조항10', '필수조항5'), 8),
#  (('필수조항10', '필수조항7'), 7),
#  (('옵션조항3', '필수조항4'), 6),
#  (('옵션조항2', '필수조항11'), 5),
#  (('옵션조항3', '필수조항12'), 4),
#  (('필수조항5', '필수조항6'), 4),
#  (('필수조항1', '필수조항2'), 4),
#  (('필수조항12', '필수조항13'), 3),
#  (('필수조항10.1', '필수조항7'), 3),
#  (('옵션조항1', '필수조항12'), 3),
#  (('옵션조항1', '필수조항8'), 3),
#  (('옵션조항3', '필수조항7'), 3),
#  (('필수조항11', '필수조항4'), 3),
#  (('필수조항10', '필수조항12'), 3),
#  (('필수조항12', '필수조항9'), 3),
#  (('필수조항4', '필수조항7'), 3),
#  (('필수조항10.1', '필수조항5'), 3),
#  (('필수조항12', '필수조항3'), 2),
#  (('옵션조항2', '옵션조항5'), 2),
#  (('필수조항2', '필수조항9'), 2),
#  (('필수조항10', '필수조항9'), 2),
#  (('필수조항11', '필수조항13'), 2),
#  (('필수조항11', '필수조항7'), 2),
#  (('필수조항7', '필수조항8'), 2),
#  (('필수조항10', '필수조항4'), 2),
#  (('필수조항3', '필수조항8'), 2),
#  (('옵션조항2', '필수조항9'), 1),
#  (('옵션조항2', '필수조항6'), 1),
#  (('옵션조항1', '옵션조항2'), 1),
#  (('옵션조항12', '옵션조항5'), 1),
#  (('필수조항10.1', '필수조항4'), 1),
#  (('필수조항11', '필수조항11'), 1),
#  (('옵션조항6', '필수조항9'), 1),
#  (('필수조항10.1', '필수조항12'), 1),
#  (('필수조항10', '필수조항10'), 1),
#  (('옵션조항1', '필수조항11'), 1),
#  (('필수조항10.1', '필수조항6'), 1),
#  (('옵션조항3', '필수조항10'), 1),
#  (('nan', '필수조항12'), 1),
#  (('필수조항12', '필수조항12'), 1),
#  (('필수조항6', '필수조항7'), 1),
#  (('옵션조항1', '필수조항10.1'), 1),
#  (('옵션조항1', '필수조항10'), 1),
#  (('필수조항13', '필수조항6'), 1),
#  (('필수조항10.1', '필수조항9'), 1),
#  (('필수조항11', '필수조항6'), 1),
#  (('필수조항11', '필수조항8'), 1),
#  (('필수조항3', '필수조항9'), 1),
#  (('필수조항11', '필수조항5'), 1),
#  (('필수조항10', '필수조항8'), 1),
#  (('필수조항10', '필수조항13'), 1),
#  (('옵션조항1', '옵션조항3'), 1)]

# %%
ret = 0
for i, cnt in count_list:
    ret += cnt
ret
# Out:
# 760

# %%
def option_list(option, count_list):
    new_list = []
    for multi_label, cnt in count_list:
        if multi_label[0] == option:
            new_list.append(((option, multi_label[1]), cnt))
        elif multi_label[1] == option:
            new_list.append(((option, multi_label[0]), cnt))
    return new_list

# %%
option_list('필수조항1', count_list)
# Out:
# [(('필수조항1', '필수조항2'), 4)]

# %%
option_list('필수조항2', count_list)
# Out:
# [(('필수조항2', '필수조항1'), 4), (('필수조항2', '필수조항9'), 2)]

# %%
option_list('필수조항3', count_list)
# Out:
# [(('필수조항3', '필수조항12'), 2), (('필수조항3', '필수조항8'), 2), (('필수조항3', '필수조항9'), 1)]

# %%
option_list('필수조항11', count_list)
# Out:
# [(('필수조항11', '필수조항12'), 204),
#  (('필수조항11', '필수조항10'), 49),
#  (('필수조항11', '필수조항10.1'), 33),
#  (('필수조항11', '옵션조항3'), 13),
#  (('필수조항11', '옵션조항2'), 5),
#  (('필수조항11', '필수조항4'), 3),
#  (('필수조항11', '필수조항13'), 2),
#  (('필수조항11', '필수조항7'), 2),
#  (('필수조항11', '필수조항11'), 1),
#  (('필수조항11', '옵션조항1'), 1),
#  (('필수조항11', '필수조항6'), 1),
#  (('필수조항11', '필수조항8'), 1),
#  (('필수조항11', '필수조항5'), 1)]

# %%
matrix_df = pd.DataFrame(index=key_list, columns=key_list)
matrix_df
# Out:
#          필수조항1 필수조항2 필수조항3 필수조항4 필수조항5 필수조항6 필수조항7 필수조항8 필수조항9 필수조항10  \
# 필수조항1      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항2      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항3      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항4      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항5      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항6      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항7      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항8      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항9      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항10     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항10.1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항11     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항12     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항13     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항1      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항2      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항3      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항5      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항6      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항10     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
#          필수조항10.1 필수조항11 필수조항12 필수조항13 옵션조항1 옵션조항2 옵션조항3 옵션조항5 옵션조항6 옵션조항10
# 필수조항1         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항2         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항3         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항4         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항5         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항6         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항7         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항8         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항9         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항10        NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항10.1      NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항11        NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항12        NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항13        NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항1         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항2         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항3         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항5         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항6         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항10        NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN

# %%
for key in key_list:
    matrix_df[key][key] = len(find_by_option(df, key))
    for (option_key, other_option), cnt in option_list(key, count_list):
        matrix_df[option_key][other_option] = cnt
    
matrix_df
# Out:
#          필수조항1 필수조항2 필수조항3 필수조항4 필수조항5 필수조항6 필수조항7 필수조항8 필수조항9 필수조항10  \
# 필수조항1      881     4   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항2        4   153   NaN   NaN   NaN   NaN   NaN   NaN     2    NaN
# 필수조항3      NaN   NaN   908   NaN   NaN   NaN   NaN     2     1    NaN
# 필수조항4      NaN   NaN   NaN  1258   NaN   NaN     3   NaN    11      2
# 필수조항5      NaN   NaN   NaN   NaN   998     4   NaN   NaN   NaN      8
# 필수조항6      NaN   NaN   NaN   NaN     4  1163     1   NaN   NaN      9
# 필수조항7      NaN   NaN   NaN     3   NaN     1  1036     2     9      7
# 필수조항8      NaN   NaN     2   NaN   NaN   NaN     2  2076   NaN      1
# 필수조항9      NaN     2     1    11   NaN   NaN     9   NaN   857      2
# 필수조항10     NaN   NaN   NaN     2     8     9     7     1     2      1
# 필수조항10.1   NaN   NaN   NaN     1     3     1     3   NaN     1    NaN
# 필수조항11     NaN   NaN   NaN     3     1     1     2     1   NaN     49
# 필수조항12     NaN   NaN     2    16    28    71    16   NaN     3      3
# 필수조항13     NaN   NaN   NaN   NaN    32     1   NaN   NaN   NaN      1
# 옵션조항1      NaN   NaN   NaN   NaN   NaN   NaN   NaN     3   NaN      1
# 옵션조항2      NaN   NaN   NaN    20    54     1    10   NaN     1    NaN
# 옵션조항3      NaN   NaN   NaN     6   NaN   NaN     3   NaN   NaN      1
# 옵션조항5      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항6      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     1    NaN
# 옵션조항10     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
#          필수조항10.1 필수조항11 필수조항12 필수조항13 옵션조항1 옵션조항2 옵션조항3 옵션조항5 옵션조항6 옵션조항10
# 필수조항1         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항2         NaN    NaN    NaN    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항3         NaN    NaN      2    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 필수조항4           1      3     16    NaN   NaN    20     6   NaN   NaN    NaN
# 필수조항5           3      1     28     32   NaN    54   NaN   NaN   NaN    NaN
# 필수조항6           1      1     71      1   NaN     1   NaN   NaN   NaN    NaN
# 필수조항7           3      2     16    NaN   NaN    10     3   NaN   NaN    NaN
# 필수조항8         NaN      1    NaN    NaN     3   NaN   NaN   NaN   NaN    NaN
# 필수조항9           1    NaN      3    NaN   NaN     1   NaN   NaN     1    NaN
# 필수조항10        NaN     49      3      1     1   NaN     1   NaN   NaN    NaN
# 필수조항10.1      695     33      1    NaN     1    18    19   NaN   NaN    NaN
# 필수조항11         33      1    204      2     1     5    13   NaN   NaN    NaN
# 필수조항12          1    204      1      3     3   NaN     4   NaN    11      9
# 필수조항13        NaN      2      3    281   NaN   NaN   NaN   NaN   NaN    NaN
# 옵션조항1           1      1      3    NaN  1437     1     1   NaN   NaN    NaN
# 옵션조항2          18      5    NaN    NaN     1  1256    16     2   NaN    NaN
# 옵션조항3          19     13      4    NaN     1    16  2608   NaN   NaN    NaN
# 옵션조항5         NaN    NaN    NaN    NaN   NaN     2   NaN   324   NaN    NaN
# 옵션조항6         NaN    NaN     11    NaN   NaN   NaN   NaN   NaN    97    NaN
# 옵션조항10        NaN    NaN      9    NaN   NaN   NaN   NaN   NaN   NaN     28

# %%
matrix_df.fillna(0, inplace=True)
matrix_df
# Out:
#           필수조항1  필수조항2  필수조항3  필수조항4  필수조항5  필수조항6  필수조항7  필수조항8  필수조항9  \
# 필수조항1       881      4      0      0      0      0      0      0      0
# 필수조항2         4    153      0      0      0      0      0      0      2
# 필수조항3         0      0    908      0      0      0      0      2      1
# 필수조항4         0      0      0   1258      0      0      3      0     11
# 필수조항5         0      0      0      0    998      4      0      0      0
# 필수조항6         0      0      0      0      4   1163      1      0      0
# 필수조항7         0      0      0      3      0      1   1036      2      9
# 필수조항8         0      0      2      0      0      0      2   2076      0
# 필수조항9         0      2      1     11      0      0      9      0    857
# 필수조항10        0      0      0      2      8      9      7      1      2
# 필수조항10.1      0      0      0      1      3      1      3      0      1
# 필수조항11        0      0      0      3      1      1      2      1      0
# 필수조항12        0      0      2     16     28     71     16      0      3
# 필수조항13        0      0      0      0     32      1      0      0      0
# 옵션조항1         0      0      0      0      0      0      0      3      0
# 옵션조항2         0      0      0     20     54      1     10      0      1
# 옵션조항3         0      0      0      6      0      0      3      0      0
# 옵션조항5         0      0      0      0      0      0      0      0      0
# 옵션조항6         0      0      0      0      0      0      0      0      1
# 옵션조항10        0      0      0      0      0      0      0      0      0
#
#           필수조항10  필수조항10.1  필수조항11  필수조항12  필수조항13  옵션조항1  옵션조항2  옵션조항3  \
# 필수조항1          0         0       0       0       0      0      0      0
# 필수조항2          0         0       0       0       0      0      0      0
# 필수조항3          0         0       0       2       0      0      0      0
# 필수조항4          2         1       3      16       0      0     20      6
# 필수조항5          8         3       1      28      32      0     54      0
# 필수조항6          9         1       1      71       1      0      1      0
# 필수조항7          7         3       2      16       0      0     10      3
# 필수조항8          1         0       1       0       0      3      0      0
# 필수조항9          2         1       0       3       0      0      1      0
# 필수조항10         1         0      49       3       1      1      0      1
# 필수조항10.1       0       695      33       1       0      1     18     19
# 필수조항11        49        33       1     204       2      1      5     13
# 필수조항12         3         1     204       1       3      3      0      4
# 필수조항13         1         0       2       3     281      0      0      0
# 옵션조항1          1         1       1       3       0   1437      1      1
# 옵션조항2          0        18       5       0       0      1   1256     16
# 옵션조항3          1        19      13       4       0      1     16   2608
# 옵션조항5          0         0       0       0       0      0      2      0
# 옵션조항6          0         0       0      11       0      0      0      0
# 옵션조항10         0         0       0       9       0      0      0      0
#
#           옵션조항5  옵션조항6  옵션조항10
# 필수조항1         0      0       0
# 필수조항2         0      0       0
# 필수조항3         0      0       0
# 필수조항4         0      0       0
# 필수조항5         0      0       0
# 필수조항6         0      0       0
# 필수조항7         0      0       0
# 필수조항8         0      0       0
# 필수조항9         0      1       0
# 필수조항10        0      0       0
# 필수조항10.1      0      0       0
# 필수조항11        0      0       0
# 필수조항12        0     11       9
# 필수조항13        0      0       0
# 옵션조항1         0      0       0
# 옵션조항2         2      0       0
# 옵션조항3         0      0       0
# 옵션조항5       324      0       0
# 옵션조항6         0     97       0
# 옵션조항10        0      0      28

# %%
matrix_df.sum(axis=1)
# Out:
# 필수조항1        885
# 필수조항2        159
# 필수조항3        913
# 필수조항4       1320
# 필수조항5       1128
# 필수조항6       1252
# 필수조항7       1092
# 필수조항8       2085
# 필수조항9        888
# 필수조항10        85
# 필수조항10.1     776
# 필수조항11       316
# 필수조항12       375
# 필수조항13       320
# 옵션조항1       1448
# 옵션조항2       1384
# 옵션조항3       2671
# 옵션조항5        326
# 옵션조항6        109
# 옵션조항10        37
# dtype: int64

# %%
prob_matrix = matrix_df.apply(lambda x: x / sum(x), axis=1)
prob_matrix
# Out:
#              필수조항1     필수조항2     필수조항3     필수조항4     필수조항5     필수조항6  \
# 필수조항1     0.995480  0.004520  0.000000  0.000000  0.000000  0.000000
# 필수조항2     0.025157  0.962264  0.000000  0.000000  0.000000  0.000000
# 필수조항3     0.000000  0.000000  0.994524  0.000000  0.000000  0.000000
# 필수조항4     0.000000  0.000000  0.000000  0.953030  0.000000  0.000000
# 필수조항5     0.000000  0.000000  0.000000  0.000000  0.884752  0.003546
# 필수조항6     0.000000  0.000000  0.000000  0.000000  0.003195  0.928914
# 필수조항7     0.000000  0.000000  0.000000  0.002747  0.000000  0.000916
# 필수조항8     0.000000  0.000000  0.000959  0.000000  0.000000  0.000000
# 필수조항9     0.000000  0.002252  0.001126  0.012387  0.000000  0.000000
# 필수조항10    0.000000  0.000000  0.000000  0.023529  0.094118  0.105882
# 필수조항10.1  0.000000  0.000000  0.000000  0.001289  0.003866  0.001289
# 필수조항11    0.000000  0.000000  0.000000  0.009494  0.003165  0.003165
# 필수조항12    0.000000  0.000000  0.005333  0.042667  0.074667  0.189333
# 필수조항13    0.000000  0.000000  0.000000  0.000000  0.100000  0.003125
# 옵션조항1     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 옵션조항2     0.000000  0.000000  0.000000  0.014451  0.039017  0.000723
# 옵션조항3     0.000000  0.000000  0.000000  0.002246  0.000000  0.000000
# 옵션조항5     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 옵션조항6     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 옵션조항10    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#              필수조항7     필수조항8     필수조항9    필수조항10  필수조항10.1    필수조항11  \
# 필수조항1     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 필수조항2     0.000000  0.000000  0.012579  0.000000  0.000000  0.000000
# 필수조항3     0.000000  0.002191  0.001095  0.000000  0.000000  0.000000
# 필수조항4     0.002273  0.000000  0.008333  0.001515  0.000758  0.002273
# 필수조항5     0.000000  0.000000  0.000000  0.007092  0.002660  0.000887
# 필수조항6     0.000799  0.000000  0.000000  0.007188  0.000799  0.000799
# 필수조항7     0.948718  0.001832  0.008242  0.006410  0.002747  0.001832
# 필수조항8     0.000959  0.995683  0.000000  0.000480  0.000000  0.000480
# 필수조항9     0.010135  0.000000  0.965090  0.002252  0.001126  0.000000
# 필수조항10    0.082353  0.011765  0.023529  0.011765  0.000000  0.576471
# 필수조항10.1  0.003866  0.000000  0.001289  0.000000  0.895619  0.042526
# 필수조항11    0.006329  0.003165  0.000000  0.155063  0.104430  0.003165
# 필수조항12    0.042667  0.000000  0.008000  0.008000  0.002667  0.544000
# 필수조항13    0.000000  0.000000  0.000000  0.003125  0.000000  0.006250
# 옵션조항1     0.000000  0.002072  0.000000  0.000691  0.000691  0.000691
# 옵션조항2     0.007225  0.000000  0.000723  0.000000  0.013006  0.003613
# 옵션조항3     0.001123  0.000000  0.000000  0.000374  0.007113  0.004867
# 옵션조항5     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 옵션조항6     0.000000  0.000000  0.009174  0.000000  0.000000  0.000000
# 옵션조항10    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             필수조항12    필수조항13     옵션조항1     옵션조항2     옵션조항3     옵션조항5  \
# 필수조항1     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 필수조항2     0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 필수조항3     0.002191  0.000000  0.000000  0.000000  0.000000  0.000000
# 필수조항4     0.012121  0.000000  0.000000  0.015152  0.004545  0.000000
# 필수조항5     0.024823  0.028369  0.000000  0.047872  0.000000  0.000000
# 필수조항6     0.056709  0.000799  0.000000  0.000799  0.000000  0.000000
# 필수조항7     0.014652  0.000000  0.000000  0.009158  0.002747  0.000000
# 필수조항8     0.000000  0.000000  0.001439  0.000000  0.000000  0.000000
# 필수조항9     0.003378  0.000000  0.000000  0.001126  0.000000  0.000000
# 필수조항10    0.035294  0.011765  0.011765  0.000000  0.011765  0.000000
# 필수조항10.1  0.001289  0.000000  0.001289  0.023196  0.024485  0.000000
# 필수조항11    0.645570  0.006329  0.003165  0.015823  0.041139  0.000000
# 필수조항12    0.002667  0.008000  0.008000  0.000000  0.010667  0.000000
# 필수조항13    0.009375  0.878125  0.000000  0.000000  0.000000  0.000000
# 옵션조항1     0.002072  0.000000  0.992403  0.000691  0.000691  0.000000
# 옵션조항2     0.000000  0.000000  0.000723  0.907514  0.011561  0.001445
# 옵션조항3     0.001498  0.000000  0.000374  0.005990  0.976413  0.000000
# 옵션조항5     0.000000  0.000000  0.000000  0.006135  0.000000  0.993865
# 옵션조항6     0.100917  0.000000  0.000000  0.000000  0.000000  0.000000
# 옵션조항10    0.243243  0.000000  0.000000  0.000000  0.000000  0.000000
#
#              옵션조항6    옵션조항10
# 필수조항1     0.000000  0.000000
# 필수조항2     0.000000  0.000000
# 필수조항3     0.000000  0.000000
# 필수조항4     0.000000  0.000000
# 필수조항5     0.000000  0.000000
# 필수조항6     0.000000  0.000000
# 필수조항7     0.000000  0.000000
# 필수조항8     0.000000  0.000000
# 필수조항9     0.001126  0.000000
# 필수조항10    0.000000  0.000000
# 필수조항10.1  0.000000  0.000000
# 필수조항11    0.000000  0.000000
# 필수조항12    0.029333  0.024000
# 필수조항13    0.000000  0.000000
# 옵션조항1     0.000000  0.000000
# 옵션조항2     0.000000  0.000000
# 옵션조항3     0.000000  0.000000
# 옵션조항5     0.000000  0.000000
# 옵션조항6     0.889908  0.000000
# 옵션조항10    0.000000  0.756757

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc
# %matplotlib inline

rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(15, 12))
sns.heatmap(prob_matrix)

plt.title('조항별 관계도', fontsize=30)

plt.show()

# %%
matrix_df.to_csv('./result/multi_label_number.csv')
prob_matrix.to_csv('./result/probability_matrix.csv')

# %%
key_list = ['필수조항1', '필수조항2', '필수조항3', '필수조항4', '필수조항5', '필수조항6', '필수조항7',
       '필수조항8', '필수조항9', '필수조항10', '필수조항10.1', '필수조항11', '필수조항12', '필수조항13', 
 '옵션조항1', '옵션조항2', '옵션조항3', '옵션조항5', '옵션조항6', '옵션조항10']

len(key_list)
# Out:
# 20

# %%
key_priority_list = [(k, i) for k, i in zip(key_list, range(len(key_list)))]
key_priority_list
# Out:
# [('필수조항1', 0),
#  ('필수조항2', 1),
#  ('필수조항3', 2),
#  ('필수조항4', 3),
#  ('필수조항5', 4),
#  ('필수조항6', 5),
#  ('필수조항7', 6),
#  ('필수조항8', 7),
#  ('필수조항9', 8),
#  ('필수조항10', 9),
#  ('필수조항10.1', 10),
#  ('필수조항11', 11),
#  ('필수조항12', 12),
#  ('필수조항13', 13),
#  ('옵션조항1', 14),
#  ('옵션조항2', 15),
#  ('옵션조항3', 16),
#  ('옵션조항5', 17),
#  ('옵션조항6', 18),
#  ('옵션조항10', 19)]

# %%
key_dict = dict()
for k in list(df['조항구분'].unique()):
    key_dict[k] = 1

# %%
key_dict
# Out:
# {'nan': 1,
#  '필수조항1': 1,
#  '옵션조항3': 1,
#  '필수조항8': 1,
#  '옵션조항7': 1,
#  '필수조항10': 1,
#  '필수조항11': 1,
#  '필수조항3': 1,
#  '옵션조항1': 1,
#  '옵션조항2': 1,
#  '필수조항4': 1,
#  '필수조항9': 1,
#  '필수조항6': 1,
#  '필수조항12': 1,
#  '필수조항2': 1,
#  '필수조항7': 1,
#  '필수조항13': 1,
#  '필수조항5': 1,
#  '필수조항10.1': 1,
#  '옵션조항10': 1,
#  '옵션조항6': 1,
#  '옵션조항5': 1,
#  '옵션조항8': 1,
#  '옵션조항12': 1,
#  '옵션조항4': 1,
#  '옵션조항9': 1}

# %%
for i in range(len(df) - 1):
    if df.loc[i]['항목'] == df.loc[i+1]['항목'] and df.loc[i]['원본'] == df.loc[i+1]['원본']:
        key_dict[df.loc[i]['조항구분']] = 0
        key_dict[df.loc[i]['조항구분']] = 0

key_dict
# Out:
# {'nan': 0,
#  '필수조항1': 0,
#  '옵션조항3': 0,
#  '필수조항8': 0,
#  '옵션조항7': 1,
#  '필수조항10': 0,
#  '필수조항11': 0,
#  '필수조항3': 0,
#  '옵션조항1': 0,
#  '옵션조항2': 0,
#  '필수조항4': 0,
#  '필수조항9': 0,
#  '필수조항6': 0,
#  '필수조항12': 0,
#  '필수조항2': 0,
#  '필수조항7': 0,
#  '필수조항13': 0,
#  '필수조항5': 0,
#  '필수조항10.1': 0,
#  '옵션조항10': 0,
#  '옵션조항6': 0,
#  '옵션조항5': 0,
#  '옵션조항8': 1,
#  '옵션조항12': 1,
#  '옵션조항4': 1,
#  '옵션조항9': 1}

# %%
len(key_dict)
# Out:
# 26

# %%
key_list = ['필수조항1', '필수조항2', '필수조항3', '필수조항4', '필수조항5', '필수조항6', '필수조항7',
       '필수조항8', '필수조항9', '필수조항10', '필수조항10.1', '필수조항11', '필수조항12', '필수조항13', 
 '옵션조항1', '옵션조항2', '옵션조항3', '옵션조항5', '옵션조항6', '옵션조항10']

len(key_list)
# Out:
# 20

# %%
key_list
# Out:
# ['필수조항1',
#  '필수조항2',
#  '필수조항3',
#  '필수조항4',
#  '필수조항5',
#  '필수조항6',
#  '필수조항7',
#  '필수조항8',
#  '필수조항9',
#  '필수조항10',
#  '필수조항10.1',
#  '필수조항11',
#  '필수조항12',
#  '필수조항13',
#  '옵션조항1',
#  '옵션조항2',
#  '옵션조항3',
#  '옵션조항5',
#  '옵션조항6',
#  '옵션조항10']

# %%
len(find_by_option(df, '필수조항1'))
# Out:
# 881

# %%
df.loc[[97,98]]
# Out:
#         항목                                   원본     수정본   사유         조항구분  \
# 97  12조 4항  “을”은 전항의 위반으로 인한 민·형사상의 모든 책임을 진다.   _GOOD_  NaN        필수조항6
# 98  12조 4항  “을”은 전항의 위반으로 인한 민·형사상의 모든 책임을 진다.   _GOOD_  NaN  필수조항10 유사조항
#
#                          파일명
# 97  체크10. PC유지보수계약서_ID3.xlsx
# 98  체크10. PC유지보수계약서_ID3.xlsx

# %%
df.loc[[210,211]]
# Out:
#               항목                                           원본     수정본   사유  \
# 210  3장 12조 1항-2  목적물의 제조에 사용되는 설비, 금형, 기구류 등(이하 ‘설비등’이라 한다)   _GOOD_  NaN
# 211  3장 12조 1항-2  목적물의 제조에 사용되는 설비, 금형, 기구류 등(이하 ‘설비등’이라 한다)   _GOOD_  NaN
#
#       조항구분                                  파일명
# 210  옵션조항2  체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# 211  필수조항5  체크100. 기계업종 표준하도급계약서(16.12.30).xlsx

# %%
count_list
# Out:
# [(('필수조항11', '필수조항12'), 203),
#  (('필수조항12', '필수조항6'), 71),
#  (('옵션조항2', '필수조항5'), 54),
#  (('필수조항10', '필수조항11'), 47),
#  (('필수조항13', '필수조항5'), 32),
#  (('필수조항10.1', '필수조항11'), 32),
#  (('필수조항12', '필수조항5'), 28),
#  (('옵션조항2', '필수조항4'), 20),
#  (('옵션조항3', '필수조항10.1'), 19),
#  (('옵션조항2', '필수조항10.1'), 18),
#  (('필수조항12', '필수조항4'), 16),
#  (('필수조항12', '필수조항7'), 16),
#  (('옵션조항2', '옵션조항3'), 16),
#  (('옵션조항3', '필수조항11'), 13),
#  (('옵션조항6', '필수조항12'), 11),
#  (('필수조항4', '필수조항9'), 11),
#  (('옵션조항2', '필수조항7'), 10),
#  (('옵션조항10', '필수조항12'), 9),
#  (('필수조항7', '필수조항9'), 9),
#  (('필수조항10 유사조항', '필수조항6'), 8),
#  (('필수조항10 유사조항', '필수조항5'), 7),
#  (('옵션조항3', '필수조항4'), 6),
#  (('필수조항10', '필수조항7'), 6),
#  (('옵션조항2', '필수조항11'), 5),
#  (('옵션조항3', '필수조항12'), 4),
#  (('필수조항5', '필수조항6'), 4),
#  (('필수조항1', '필수조항2'), 4),
#  (('필수조항12', '필수조항13'), 3),
#  (('옵션조항1', '필수조항12'), 3),
#  (('옵션조항1', '필수조항8'), 3),
#  (('옵션조항3', '필수조항7'), 3),
#  (('필수조항11', '필수조항4'), 3),
#  (('필수조항12', '필수조항9'), 3),
#  (('필수조항4', '필수조항7'), 3),
#  (('필수조항10.1 유사조항', '필수조항7'), 2),
#  (('필수조항12', '필수조항3'), 2),
#  (('옵션조항2', '옵션조항5'), 2),
#  (('필수조항2', '필수조항9'), 2),
#  (('필수조항10', '필수조항12'), 2),
#  (('필수조항10 유사조항', '필수조항9'), 2),
#  (('필수조항11', '필수조항13'), 2),
#  (('필수조항10 유사조항', '필수조항11'), 2),
#  (('필수조항11', '필수조항7'), 2),
#  (('필수조항7', '필수조항8'), 2),
#  (('필수조항10', '필수조항4'), 2),
#  (('필수조항3', '필수조항8'), 2),
#  (('필수조항10.1 유사조항', '필수조항5'), 2),
#  (('옵션조항2', '필수조항9'), 1),
#  (('옵션조항2', '필수조항6'), 1),
#  (('필수조항10.1', '필수조항7'), 1),
#  (('옵션조항1', '옵션조항2'), 1),
#  (('옵션조항12', '옵션조항5'), 1),
#  (('필수조항10.1', '필수조항4'), 1),
#  (('필수조항11', '필수조항11'), 1),
#  (('팔수조항11', '필수조항12'), 1),
#  (('옵션조항6', '필수조항9'), 1),
#  (('필수조항10.1 유사조항', '필수조항12'), 1),
#  (('필수조항10', '필수조항10'), 1),
#  (('옵션조항1', '필수조항11'), 1),
#  (('필수조항10 유사조항', '필수조항7'), 1),
#  (('필수조항10', '필수조항6'), 1),
#  (('필수조항10.1 유사조항', '필수조항6'), 1),
#  (('옵션조항3', '필수조항10'), 1),
#  (('nan', '필수조항12'), 1),
#  (('필수조항12', '필수조항12'), 1),
#  (('필수조항10.1 유사조항', '필수조항11'), 1),
#  (('필수조항6', '필수조항7'), 1),
#  (('옵션조항1', '필수조항10.1'), 1),
#  (('옵션조항1', '필수조항10'), 1),
#  (('필수조항13', '필수조항6'), 1),
#  (('필수조항10.1 유사조항', '필수조항9'), 1),
#  (('필수조항11', '필수조항6'), 1),
#  (('필수조항10 유사조항', '필수조항12'), 1),
#  (('필수조항11', '필수조항8'), 1),
#  (('필수조항10.1', '필수조항5'), 1),
#  (('필수조항10', '필수조항5'), 1),
#  (('필수조항3', '필수조항9'), 1),
#  (('필수조항11', '필수조항5'), 1),
#  (('필수조항10', '필수조항8'), 1),
#  (('필수조항10 유사조항', '필수조항13'), 1),
#  (('옵션조항1', '옵션조항3'), 1)]

# %%
def find_by_option(df, option):
    return df[df['조항구분'] == option]

# %%
find_by_option(df, '필수조항11')
# Out:
#                항목                                                 원본     수정본  \
# 26          9조 1항  “갑”은 “을”이 다음 각호의 1에 해당될 때는 계약을 해지할 수 있고 해지 시에는...  _GOOD_
# 27       9조 1항 1호                “을”이 계약내용의 불이행 등으로 “갑”의 업무추진이 곤란할 때  _GOOD_
# 28       9조 1항 2호  “을”의 귀책사유로 음식물류폐기물 처리업무를 일방적으로 중단하여 계약 이행이 불가능...  _GOOD_
# 29       9조 1항 3호         “갑”의 자원화 사업이 불필요하거나 본 업무의 대행이 필요 없다고 인정될 때  _GOOD_
# 30          9조 2항  “을”은 사정상 음식물류폐기물을 더 이상 처리할 수 없는 사유가 발생시 최소 [날짜...  _GOOD_
# ...           ...                                                ...     ...
# 74124      15조 2항   제1항의 해제 또는 해지는 갑과 을의 손해배상 청구에 영향을 미치지      아니한다.  _GOOD_
# 74145     5조 1항-2  유효하며, 기간  만료 OO개월 전까지 상대방에게 서면으로 계약종료의 의사표시를  ...  _GOOD_
# 74170    2장 8조 1항     갑은 다음 각 호에 해당될 경우에는 "을"의 귀책사유로 본 계약을 해지할 수 있다.  _GOOD_
# 74171  2장 8조1항 1호                         정당한 이유없이 작업 진행이 이루어지지 않을 때  _GOOD_
# 74172  2장 8조1항 2호                  정당한 이유없이 계약기간에 작업완료가 불가능하다고 판단될 때  _GOOD_
#
#         사유    조항구분                                           파일명
# 26     NaN  필수조항11  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 27     NaN  필수조항11  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 28     NaN  필수조항11  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 29     NaN  필수조항11  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 30     NaN  필수조항11  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# ...    ...     ...                                           ...
# 74124  NaN  필수조항11                            체크733. 컨설팅계약서.xlsx
# 74145  NaN  필수조항11                          체크734. 컨설팅업무계약서.xlsx
# 74170  NaN  필수조항11                     체크735. 프리랜서와기업간업무계약서.xlsx
# 74171  NaN  필수조항11                     체크735. 프리랜서와기업간업무계약서.xlsx
# 74172  NaN  필수조항11                     체크735. 프리랜서와기업간업무계약서.xlsx
#
# [5528 rows x 6 columns]

# %%
find_by_option(df, '필수조항12')
# Out:
#               항목                                                 원본     수정본  \
# 110       17조 1항  “을”이 보수작업시 부주의하여 기기를 파손하는 등으로 “갑”에게 손해를 가하였을 경...  _GOOD_
# 201    3장 10조 4항  수급사업자는 원사업자로부터 교부받은 규격서류를 멸실·훼손하거나 제2항의 규정을 위반...  _GOOD_
# 220    3장 12조 5항  수급사업자는 원사업자로부터 대여받은 설비등이 멸실 또는 훼손되었을 경우에 지체없이 ...  _GOOD_
# 238    3장 14조 2항  제1항 단서에 따라 수급사업자가 위탁 업무의 일부를 제3자에게 재하도급한 경우 그 ...  _GOOD_
# 250    3장 16조 4항  제3항의 경우 원사업자는 이로 인해 발생한 손해에 대해 배상을 청구할 수 있다. 다...  _GOOD_
# ...          ...                                                ...     ...
# 73940   5조 1항 2호  부동산 중개대상물의 확인·설명을 소홀히 하여 재산상의 피해를 발생하게 한 경우 : ...  _GOOD_
# 73965      6조 1항  ‘갑’ 또는 ‘을’이 정당한 사유 없이 계약을 위반하는 경우 상대방은 계약을 해지할...  _GOOD_
# 74068      5조 1항  을이 작업중 건물,전기,비품 기타 기구 등이 파손될 때에는 "갑"의 요구에 따라 "...  _GOOD_
# 74142    4조 1항-2    갑은 을이 본 조항을 위반함으로써 갑에게 발생된 손해에 대해 배상을 청구할 수 있다.  _GOOD_
# 74174   2장 9조 1항  을의 귀책사유로 인하여 납기 지연 등 본 계약이 불이행되었을 경우 "을"은 "갑"이...  _GOOD_
#
#         사유    조항구분                                  파일명
# 110    NaN  필수조항12             체크10. PC유지보수계약서_ID3.xlsx
# 201    NaN  필수조항12  체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# 220    NaN  필수조항12  체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# 238    NaN  필수조항12  체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# 250    NaN  필수조항12  체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# ...    ...     ...                                  ...
# 73940  NaN  필수조항12                  체크728. 전속중개계약서.xlsx
# 73965  NaN  필수조항12                  체크729. 전속출연계약서.xlsx
# 74068  NaN  필수조항12                  체크732. 청소용역계약서.xlsx
# 74142  NaN  필수조항12                 체크734. 컨설팅업무계약서.xlsx
# 74174  NaN  필수조항12            체크735. 프리랜서와기업간업무계약서.xlsx
#
# [1682 rows x 6 columns]

# %%
find_by_option(df, '필수조항1')
# Out:
#                항목                               원본     수정본   사유   조항구분  \
# 9           3조 1항                 위수탁기간은 [기간]로 한다.  _GOOD_  NaN  필수조항1
# 43          3조 1항                계약기간은 [기간]까지로 한다.  _GOOD_  NaN  필수조항1
# 121      1장 2조 1항                             [기간]  _GOOD_  NaN  필수조항1
# 546      7장 8조 1항     이 계약은 체결일로부터 [날짜] 그 효력을 가진다.  _GOOD_  NaN  필수조항1
# 565      1장 2조 1항                             [기간]  _GOOD_  NaN  필수조항1
# ...           ...                              ...     ...  ...    ...
# 74023       3조 1항         본 계약에 의한 용역기간은 [기간]로 한다.  _GOOD_  NaN  필수조항1
# 74074     8조 1항-1              본 계약기간은 [기간]까지로 하며   _GOOD_  NaN  필수조항1
# 74111    11조 1항-1  본 계약의 유효기간은 계약체결일부터 [기간]으로 하고,   _GOOD_  NaN  필수조항1
# 74144     5조 1항-1         이 계약은 본  계약 체결일로부터 [기간]   _GOOD_  NaN  필수조항1
# 74157  2장 3조 1항-1               본 계약은 [기간]까지로 하며,   _GOOD_  NaN  필수조항1
#
#                                                   파일명
# 9        체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 43                           체크10. PC유지보수계약서_ID3.xlsx
# 121               체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# 546               체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# 565    체크101. 디자인업종(디지털) 표준하도급계약서(2017.12.27.개정).xlsx
# ...                                               ...
# 74023                            체크731. 창업컨설팅계약서.xlsx
# 74074                             체크732. 청소용역계약서.xlsx
# 74111                              체크733. 컨설팅계약서.xlsx
# 74144                            체크734. 컨설팅업무계약서.xlsx
# 74157                       체크735. 프리랜서와기업간업무계약서.xlsx
#
# [881 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74180 entries, 0 to 74179
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   항목      71358 non-null  object
#  1   원본      73561 non-null  object
#  2   수정본     73816 non-null  object
#  3   사유      22 non-null     object
#  4   조항구분    74180 non-null  object
#  5   파일명     74180 non-null  object
# dtypes: object(6)
# memory usage: 3.4+ MB

# %%
df[df['원본'] == ' ']
# Out:
#         항목 원본     수정본   사유 조항구분                         파일명
# 72947   4조     _GOOD_  NaN  nan  체크714. 빌딩종합관리+용역도급계약서.xlsx
# 73488   1조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73490   2조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73492   3조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73498   4조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73517   5조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73521   6조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73523   7조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73525   8조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73533   9조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73535  10조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73537  11조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73539  12조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73541  13조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73543  14조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx
# 73546  15조     _GOOD_  NaN  nan  체크722. 인테리어디자인표준설계계약서.xlsx

# %%
list(df['조항구분'].unique())
# Out:
# ['nan',
#  '필수조항1',
#  '옵션조항3',
#  '필수조항8',
#  '옵션조항7',
#  '필수조항10 유사조항',
#  '필수조항11',
#  '필수조항3',
#  '옵션조항1',
#  '옵션조항2',
#  '필수조항4',
#  '필수조항9',
#  '필수조항6',
#  '필수조항12',
#  '필수조항2',
#  '필수조항7',
#  '필수조항13',
#  '필수조항5',
#  '필수조항10.1 유사조항',
#  '옵션조항10',
#  '옵션조항6',
#  '필수조항10.1',
#  '옵션조항5',
#  '옵션조항8',
#  '필수조항10',
#  '옵션조항12',
#  '필수조항17',
#  '팔수조항11',
#  '옵션조항4',
#  '필수조항5, 필수조항10 유사조항',
#  '',
#  '옵션조항9',
#  '조항구분']

# %%
for option in list(df['조항구분'].unique()):
    find_option(option).to_csv(option + '.csv')

# %%
def get_freq_words(df):
    counter = Counter()
    for i in range(len(df)):
        try:
            counter += Counter(str(df.iloc[i]['원본']).split())
        except:
            pass
    print(len(df))
    return counter

def show_freq_by_option(df, option):
    return get_freq_words(find_by_option(df, option)).most_common()

# %%
show_freq_by_option(df, '필수조항1')
# Out:
# 881
# [('[기간]', 328),
#  ('한다.', 303),
#  ('본', 249),
#  ('[기간]로', 192),
#  ('계약의', 115),
#  ('계약기간은', 112),
#  (':', 106),
#  ('기간은', 86),
#  ('[날짜]', 80),
#  ('[기간]으로', 64),
#  ('계약은', 62),
#  ('계약기간', 59),
#  ('[기간]까지로', 51),
#  ('유효기간은', 48),
#  ('이', 45),
#  ('계약', 37),
#  ('하며', 35),
#  ('용역기간은', 35),
#  ('하며,', 33),
#  ('체결일로부터', 32),
#  ('용역의', 25),
#  ('효력을', 22),
#  ('계약기간:', 21),
#  ('[기간]까지', 18),
#  ('수행기간은', 17),
#  ('가진다.', 16),
#  ('계약체결일로부터', 16),
#  ('용역', 16),
#  ('계약서의', 16),
#  ('그', 15),
#  ('기', 15),
#  ('후', 15),
#  ('및', 15),
#  ('“을”은', 14),
#  ('일자', 14),
#  ('간', 13),
#  ('계약일로부터', 12),
#  ('하되,', 11),
#  ('하되', 11),
#  ('까지로', 10),
#  ('착수', 10),
#  ('완료', 10),
#  ('하고,', 10),
#  ('설계용역업무의', 10),
#  ('용역기간', 10),
#  ('계', 9),
#  ('약', 9),
#  ('착공', 8),
#  ('준공', 8),
#  ('계약에', 8),
#  ('부터', 8),
#  ('한다', 7),
#  ('[날짜]로', 7),
#  ('홈페이지', 7),
#  ('체결', 6),
#  ('경비도급계약', 6),
#  ('따른', 6),
#  ('1년간', 6),
#  ('약정기간은', 6),
#  ('위탁운영', 6),
#  ('경우', 6),
#  ('로', 6),
#  ('착수일로부터', 6),
#  ('[기간]간', 6),
#  ('내에', 6),
#  ('제작', 6),
#  ('한', 6),
#  ('만', 5),
#  ('총', 5),
#  ('--+', 5),
#  ('유효하다', 5),
#  ('[날짜][기간]', 5),
#  ('업무를', 5),
#  ('이내', 5),
#  ('정한', 5),
#  (',', 5),
#  ('계약체결', 5),
#  ('[날짜]으로', 4),
#  ('일로부터', 4),
#  ('사업의', 4),
#  ('협약기간은', 4),
#  ('착수일자', 4),
#  ('하고', 4),
#  ('1년으로', 4),
#  ('유효', 4),
#  ('의한', 4),
#  ('날로부터', 4),
#  ('유효하며', 4),
#  ('계약기한은', 4),
#  ('이내로', 4),
#  ('완료하여야', 4),
#  ('위', 4),
#  ('업무', 4),
#  ('개시일로부터', 4),
#  ('제1조의', 4),
#  ('용역수행기간은', 4),
#  ('“을”의', 4),
#  ('[기간]이다.', 4),
#  ('기간', 4),
#  ('년', 4),
#  ('월', 4),
#  ('“갑”과', 4),
#  ('관리대행', 4),
#  ('계약체결일부터', 3),
#  ('[날짜]까지', 3),
#  ('대행계약', 3),
#  ('착공일', 3),
#  ('완료일', 3),
#  ('완료일자', 3),
#  ('용역계약은', 3),
#  ('계약금', 3),
#  ('기간은[기간]까지로', 3),
#  ('날인한', 3),
#  ('공사감리업무의', 3),
#  ('만료일까지로', 3),
#  ('분양대행기간은', 3),
#  ('아래', 3),
#  ('착수금', 3),
#  ('입금일로부터', 3),
#  ('용역경비계약', 3),
#  ('"갑"과', 3),
#  ('완료하기로', 3),
#  ('의무계약', 3),
#  ('공사기간', 3),
#  ('존속한다.', 3),
#  ('본계약의', 3),
#  ('“갑”으로부터', 3),
#  ('의뢰', 3),
#  ('받은', 3),
#  ('완료한다.', 3),
#  ('.', 3),
#  ('유효하며,', 3),
#  ('유지보수', 3),
#  ('설치의', 3),
#  ('사유가', 3),
#  ('계약을', 3),
#  ('원칙적으로', 3),
#  ('"을"이', 3),
#  ('이다.', 3),
#  ('계약기간은[기간]으로', 3),
#  ('효력이', 3),
#  ('발생하며,', 3),
#  ('대하여', 3),
#  ('기간을', 3),
#  ('제2조에서', 3),
#  ('[날짜]까지로', 3),
#  ('기본계약은', 2),
#  ('기본계약의', 2),
#  ('개발', 2),
#  ('“갑”에게', 2),
#  ('제출하여야', 2),
#  ('지도기간', 2),
#  ('[날짜]간', 2),
#  ('협약의', 2),
#  ('존속기간은', 2),
#  ('종기', 2),
#  ('전', 2),
#  ('본건이', 2),
#  ('완료되는', 2),
#  ('수행기간', 2),
#  ('실시설계', 2),
#  ('적격자', 2),
#  ('선정일까지로', 2),
#  ('유효하다.', 2),
#  ('웹사이트구축', 2),
#  ('계약서', 2),
#  ('작성', 2),
#  ('직후부터', 2),
#  ('계산하여', 2),
#  ('통상', 2),
#  ('계약일로', 2),
#  ('[기간]에', 2),
#  ('업무범위:', 2),
#  ('업무기간:', 2),
#  ('비고:', 2),
#  ('완료는', 2),
#  ('양자가', 2),
#  ('서명', 2),
#  ('연구기간은', 2),
#  ('일자:', 2),
#  (')', 2),
#  ('계약일', 2),
#  ('[기간](시공전', 2),
#  ('[기간]/시공단계', 2),
#  ('[기간])', 2),
#  ('당사자의', 2),
#  ('성명으로', 2),
#  ('발효하고', 2),
#  ('제3조에', 2),
#  ('따라', 2),
#  ('조기해지', 2),
#  ('되지', 2),
#  ('않을', 2),
#  ('경우에는', 2),
#  ('계속한다.', 2),
#  ('계약체결후', 2),
#  ('완공일', 2),
#  ('토지매수', 2),
#  ('용역계약일로', 2),
#  ('합의한', 2),
#  ('매입', 2),
#  ('수령일로부터', 2),
#  ('제2조', 2),
#  ('3항', 2),
#  ('4호', 2),
#  ('공사기간까지로', 2),
#  ('당해연도', 2),
#  ('결산확정일,', 2),
#  ('개인사업자일', 2),
#  ('소득세신고', 2),
#  ('마감일까지로하며', 2),
#  ('기간:', 2),
#  ('사용', 2),
#  ('또는', 2),
#  ('날까지로', 2),
#  ('유상유지관리', 2),
#  ('디자인', 2),
#  ('운영기간은', 2),
#  ('계약은[기간]로', 2),
#  ('설치는', 2),
#  ('영상물을', 2),
#  ('제작,', 2),
#  ('효력은', 2),
#  ('청소대행', 2),
#  ('정당한', 2),
#  ('없는', 2),
#  ('"갑"이', 2),
#  ('원칙으로', 2),
#  ('[기간]지로', 2),
#  ('효력발생기간은', 2),
#  ('것으로', 2),
#  ('수요자는', 2),
#  ('공급자에게', 2),
#  ('수요자', 2),
#  ('소유의', 2),
#  ('최종인도물의', 2),
#  ('운영관리를', 2),
#  ('위탁한다.', 2),
#  ('"갑"', 2),
#  ('과', 2),
#  ('까지한다.', 2),
#  ('"을"의', 2),
#  ('계약기간은[기간]까지로', 2),
#  (':[날짜]', 2),
#  ('개발기간은', 2),
#  ('작업을', 2),
#  ('용역을', 2),
#  ('제공한다.', 2),
#  ('용역수행', 2),
#  ('착수하고', 2),
#  ('완료하여', 2),
#  ('을이', 2),
#  ('공식', 2),
#  ('20', 2),
#  ('일을', 2),
#  ('기준으로', 2),
#  ('수행', 2),
#  ('"용역"', 2),
#  ('대한', 2),
#  ('[금액]', 2),
#  ('업무기간', 2),
#  ('유효기간', 2),
#  ('간:', 2),
#  ('제3조의', 2),
#  ('발휘하여', 2),
#  ('까지', 2),
#  ('공', 2),
#  ('일', 2),
#  ('요구', 2),
#  ('내용이', 2),
#  ('수행되어', 2),
#  ('완료계가', 2),
#  ('제출되는', 2),
#  ('위․수탁기간은', 2),
#  ('위탁기간은', 2),
#  ('위·수탁', 2),
#  ('않는', 2),
#  ('개시일은', 2),
#  ('OO시부터', 2),
#  ('위수탁기간은', 1),
#  ('완공', 1),
#  ('동안으로', 1),
#  ('[날짜]년으로', 1),
#  ('세부', 1),
#  ('일정은', 1),
#  ('별첨', 1),
#  ('“사양서”에', 1),
#  ('의한다.', 1),
#  ('계약이행을', 1),
#  ('보증하기', 1),
#  ('위하여', 1),
#  ('보증보험회사에서', 1),
#  ('발행하는', 1),
#  ('이행(계약)보증보험증권을', 1),
#  ('계약시점으로부터', 1),
#  ('1주일이내에', 1),
#  ('내로', 1),
#  ('체결일부터', 1),
#  ('발하며,', 1),
#  ('[날짜]간으로', 1),
#  ('준공(예정)일', 1),
#  ('효력기간은', 1),
#  ('[날짜]일간', 1),
#  ('부품공급', 1),
#  ('[날짜]간(이하', 1),
#  ('“계약기간”)', 1),
#  ('[기간]까지([개월수]개월)', 1),
#  ('45일로', 1),
#  ('공사(설계)기간은', 1),
#  ('계약일로부터[날짜]일간으로', 1),
#  ('한다.([기간]까지)', 1),
#  ('1년간으로', 1),
#  ('감리기간', 1),
#  ('집필기간', 1),
#  ('한하며', 1),
#  ('기간은[기간]', 1),
#  ('수령일로부터[기간]간', 1),
#  ('연구의', 1),
#  ('착공일부터', 1),
#  ('완공일까지로', 1),
#  ('[기간](계약체결일부터', 1),
#  ('사용검사', 1),
#  ('완료일까지', 1),
#  ('PM', 1),
#  ('서명일로부터', 1),
#  ('[기간]유효하며', 1),
#  ('[날짜]이내로', 1),
#  ('건축물', 1),
#  ('준공일로부터', 1),
#  ('제작된', 1),
#  ('홈페이지의', 1),
#  ('납품', 1),
#  ('기한은', 1),
#  ('으로', 1),
#  ('제', 1),
#  ('3', 1),
#  ('조의', 1),
#  ('원칙적으로[기간]로', 1),
#  ('을의', 1),
#  ('사업구역내의', 1),
#  ('토지를', 1),
#  ('용역계약', 1),
#  ('[기간]이내로', 1),
#  ('사업부지', 1),
#  ('전체를', 1),
#  ('100%', 1),
#  ('동의', 1),
#  ('단,', 1),
#  ('‘갑’의', 1),
#  ('조합이', 1),
#  ('해산된', 1),
#  ('조합해산', 1),
#  ('인가일까지로', 1),
#  ('제작기간의', 1),
#  ('시점은', 1),
#  ('쌍방의', 1),
#  ('최초', 1),
#  ('체결일로', 1),
#  ('종속하며,', 1),
#  ('착수후', 1),
#  ('PM용역기간은', 1),
#  ('「을」·「병」·「정」은', 1),
#  ('연대하여', 1),
#  ('운송물을', 1),
#  ('도착지까지', 1),
#  ('운송하여야', 1),
#  ('정비보수', 1),
#  ('설계용역기간(이하', 1),
#  ('“계약기간”이라', 1),
#  ('한다)은', 1),
#  ('건축물의', 1),
#  ('승인일까지로', 1),
#  ('2년으로', 1),
#  ('계약발효일', 1),
#  ('업무착수일', 1),
#  ('중', 1),
#  ('빠른', 1),
#  ('최종용역보고서', 1),
#  ('를', 1),
#  ('제출하는', 1),
#  ('nan', 1),
#  ('기간은[기간]으로', 1),
#  ('[기간]이며', 1),
#  ('무상유지관리', 1),
#  ('상호협조', 1),
#  ('콘텐츠', 1),
#  ('변경', 1),
#  ('지원', 1),
#  ('12개월로', 1),
#  ('갖는다.', 1),
#  ('을은', 1),
#  ('사이트의', 1),
#  ('1차적', 1),
#  ('제작기간은', 1),
#  ('하며.', 1),
#  ('쇼핑몰', 1),
#  ('[기간](이하', 1),
#  ('"계약기간")으로', 1),
#  ('위탁관리용역', 1),
#  ('컨설팅', 1),
#  ('업무기간은', 1),
#  ('[기간]이며,', 1),
#  ('착수일', 1),
#  ('완료하는', 1),
#  ('[기간]까지([기간]간)', 1),
#  ('용역계약의', 1),
#  ('발효된', 1),
#  ('동안이다.', 1),
#  ('1차(현장조사', 1),
#  ('하자조사서', 1),
#  ('작성)', 1),
#  ('2차(사후관리)', 1),
#  ('조합청산총회', 1),
#  ('종료일까지로', 1),
#  (':[날짜]--+', 1),
#  ('(1년간)', 1),
#  ('제9조에서', 1),
#  ('수행기간은[기간]으로', 1),
#  ('산지전용허가', 1),
#  ('"신청', 1),
#  ('승인"', 1),
#  ('입목', 1),
#  ('제거(뿌리포함)', 1),
#  ('측량', 1),
#  ('산지복구설계', 1),
#  ('준공승인', 1),
#  ('사업구역내의토지를', 1),
#  ('인터넷', 1),
#  ('웹', 1),
#  ('호스팅', 1),
#  ('서비스', 1),
#  ('구축,', 1),
#  ('개발은', 1),
#  ('상호', 1),
#  ('유지된다.', 1),
#  ('업무수행', 1),
#  ('[기간]([날짜]', 1),
#  ('준비기간)', 1),
#  ('부품개발은', 1),
#  ('개발완료', 1),
#  ('임대차기간은', 1),
#  ('조사', 1),
#  ('체결한', 1),
#  ('날인', 1),
#  ('오전', 1),
#  ('11시부터', 1),
#  ('오후', 1),
#  ('4시까지', 1),
#  ('수행하여야', 1),
#  ('착수/완료일자', 1),
#  ('DB구축을', 1),
#  ('체결로부터', 1),
#  ('지속하기로', 1),
#  ('"을"은', 1),
#  ('실시할', 1),
#  ('기업가치평가의', 1),
#  ('업무에"갑"이', 1),
#  ('의뢰하는', 1),
#  ('실사', 1),
#  ('사항에', 1),
#  ('실사를', 1),
#  ('위한', 1),
#  ('계약상의', 1),
#  ('공사를', 1),
#  ('이해하여야', 1),
#  ('건물의', 1),
#  ('신축공사를', 1),
#  ('“갑“에게', 1),
#  ('인도한다.', 1),
#  ('광고의', 1),
#  ('금일', 1),
#  ('이후', 1),
#  ('이며', 1),
#  ('착공일자', 1),
#  ('준공일자', 1),
#  ('현', 1),
#  ('계약급여', 1),
#  ('복지는', 1),
#  ('과업내용을', 1),
#  ('수행하는', 1),
#  ('개발부담금', 1),
#  ('부과에', 1),
#  ('심사청구', 1),
#  ('행정소송이', 1),
#  ('필요한', 1),
#  ('동', 1),
#  ('업무의', 1),
#  ('수행완료일까지로', 1),
#  ('철거기간', 1),
#  ('준공일', 1),
#  ('체결일에', 1),
#  ('효력', 1),
#  ('발생일로부터', 1),
#  ('[기간]이', 1),
#  ('경과한', 1),
#  ('날에', 1),
#  ('종료되는', 1),
#  ('기간은[기간]로', 1),
#  ('완수일자', 1),
#  ('“병”은', 1),
#  ('업무수행에', 1),
#  ('용역비', 1),
#  ('이며,', 1),
#  ('지불방법은', 1),
#  ('다음과', 1),
#  ('같이', 1),
#  ('정한다.', 1),
#  ('(VAT별도)', 1),
#  ('수행기간은[기간]로', 1),
#  ('설계기간', 1),
#  ('을”은', 1),
#  ('계약체결일에', 1),
#  ('미술장식품의', 1),
#  ('심의', 1),
#  ('제작에', 1),
#  ('미술장식품을', 1),
#  ('아파트', 1),
#  ('검사', 1),
#  ('신청일[날짜]이전까지', 1),
#  ('“갑”이', 1),
#  ('지정하는', 1),
#  ('장소에', 1),
#  ('납품,', 1),
#  ('설치를', 1),
#  ('[기간]로하며', 1),
#  ('유효하고', 1),
#  ('당사자', 1),
#  ('일방이', 1),
#  ('만료', 1),
#  ('일전까지', 1),
#  ('서면으로', 1),
#  ('계약조건의', 1),
#  ('변경을', 1),
#  ('요구하지', 1),
#  ('아니하는', 1),
#  ('[기간]동안', 1),
#  ('감', 1),
#  ('리', 1),
#  ('“OOO”과', 1),
#  ('"OOO"의', 1),
#  ('개발기간', 1),
#  ('이전에', 1),
#  ('프로젝트가', 1),
#  ('끝나는', 1),
#  ('시점으로', 1),
#  ('제4항에', 1),
#  ('기재된', 1),
#  ('용역에', 1),
#  ('[날짜]로부터', 1),
#  ('하며,.', 1),
#  ('6개월간으로', 1),
#  ('착', 1),
#  ('준', 1),
#  ('[기간]까지이며', 1),
#  ('작업하는', 1),
#  ('작품의', 1),
#  ('(1월.8월', 1),
#  ('제외)', 1),
#  ('2016년', 1),
#  ('5월', 1),
#  ('20일까지로', 1),
#  ('다.', 1),
#  ('‘을’은', 1),
#  ('약정서', 1),
#  ('체결과', 1),
#  ('동시에', 1),
#  ('원고', 1),
#  ('번역에', 1),
#  ('착수하여', 1),
#  ('성과물을', 1),
#  ('계약금액은', 1),
#  ('금액(부가세', 1),
#  ('포함)으로', 1),
#  ('비즈니스', 1),
#  ('전시', 1),
#  ('수출상담회', 1),
#  ('운영', 1),
#  ('대행', 1),
#  ('[기간](검수완료일)까지로', 1),
#  ('용역기간:', 1),
#  ('본건', 1),
#  ('착수년월일', 1),
#  ('완수년월일', 1),
#  ('협약', 1),
#  ('추진하며', 1),
#  ('“양산하수처리장', 1),
#  ('정문(조', 1),
#  ('형', 1),
#  ('물', 1),
#  ('설치', 1),
#  ('용역”사업에', 1),
#  ('“수요', 1),
#  ('자”의', 1),
#  ('실제', 1),
#  ('의', 1),
#  ('완료시점은[회사명1]의', 1),
#  ('날', 1),
#  ('용', 1),
#  ('역', 1),
#  ('위탁운영비를', 1),
#  ('명시하여', 1),
#  ('협약서를', 1),
#  ('작성하여야', 1),
#  ('업무개시일은', 1),
#  ('관리대행업무', 1),
#  ('종료일은', 1),
#  ('사업기간', 1),
#  ('사업기간은', 1),
#  ('대행기간은', 1),
#  ('별도의', 1),
#  ('발생되지', 1),
#  ('위․수탁업무의', 1),
#  ('만료일은', 1),
#  ('구내통신유지보수', 1),
#  ('업무대행', 1),
#  ('관리기간은', 1),
#  ('병원시설소독', 1),
#  ('개시일로', 1),
#  ('2019.12.31일까지', 1),
#  ('승강기', 1),
#  ('제1항의', 1),
#  ('수탁운영', 1),
#  ('의료(감염성)폐기물', 1),
#  ('위탁처리', 1),
#  ('폐기물처리', 1),
#  ('“갑”의', 1),
#  ('사업장에서', 1),
#  ('배출되는', 1),
#  ('오염물질에', 1),
#  ('대기환경보전법', 1),
#  ('제39조의', 1),
#  ('규정에', 1),
#  ('자가측정', 1),
#  ('대행업무를', 1),
#  ('관리대행기간은', 1),
#  ('계약제결', 1),
#  ('[날짜]으로하며,', 1),
#  ('도급', 1),
#  ('사건', 1),
#  ('1심', 1),
#  ('종료', 1),
#  ('시점까지로', 1),
#  ('[금액](VAT포함)', 1),
#  ('“계약상대자”가', 1),
#  ('계약서에', 1),
#  ('기한', 1),
#  ('완성하지', 1),
#  ('아니한', 1),
#  ('때에는', 1),
#  ('매', 1),
#  ('지체', 1),
#  ('일수마다', 1),
#  ('지체상금율에', 1),
#  ('계약금액을', 1),
#  ('곱하여', 1),
#  ('산출한', 1),
#  ('금액을', 1),
#  ('“계약상대자”에게', 1),
#  ('현금으로', 1),
#  ('납부할', 1),
#  ('것을', 1),
#  ('요구할', 1),
#  ('수', 1),
#  ('있다.', 1),
#  ('(일반조건', 1),
#  ('제5조에', 1),
#  ('의거', 1),
#  ('연장가능)', 1),
#  ('운행개시일인', 1),
#  ('[금액](V.A.T', 1),
#  ('포함)', 1),
#  ('(단,', 1),
#  ('[날짜].', 1),
#  ('이전', 1),
#  ('공사', 1),
#  ('시', 1),
#  ('[날짜]까지)', 1),
#  ('연구기간과', 1),
#  ('동일하다.', 1),
#  ('계약체결일로부터[기간]', 1),
#  ('간으로', 1),
#  ('행사를', 1),
#  ('진행하며', 1),
#  ('행사', 1),
#  ('첫날', 1),
#  ('둘째날은', 1),
#  ('OO시까지', 1),
#  ('행사하며', 1),
#  ('잔여일은', 1),
#  ('OO시까지로', 1),
#  ('총계약기간', 1),
#  ('골프', 1),
#  ('매니지먼트', 1),
#  ('전속', 1),
#  ('특별한', 1),
#  ('사항이', 1),
#  ('발생하지', 1),
#  ('(O년간)', 1),
#  ('재', 1),
#  ('계약한다', 1),
#  ('자', 1),
#  ('지', 1),
#  ('설계업무의', 1),
#  ('실행기간은', 1),
#  ('([기간])', 1),
#  ('[기간]을', 1),
#  ('만료는', 1),
#  ('첫', 1),
#  ('번째', 1),
#  ('음반', 1),
#  ('출반일로부터[기간]까지로', 1),
#  ('계약일로부터[기간](', 1),
#  ('OO분물', 1),
#  ('O회까지로)으로', 1),
#  ('합니다.', 1)]

# %%
show_freq_by_option(df, '필수조항2')
# Out:
# 153
# [('한다.', 83),
#  ('[날짜]', 52),
#  ('[날짜]까지', 29),
#  ('최종', 28),
#  ('제출하여야', 25),
#  ('본', 23),
#  ('이내에', 22),
#  (':', 21),
#  ('납품하여야', 19),
#  ('“을”은', 19),
#  ('후', 18),
#  ('및', 18),
#  ('“갑”에게', 16),
#  ('하며,', 14),
#  ('[날짜]로', 13),
#  ('결과물을', 12),
#  ('작성하여', 12),
#  ('[기간]', 11),
#  ('‘을’은', 11),
#  ('계약에', 11),
#  ('제출한다.', 11),
#  ('납품일자', 10),
#  ('따른', 10),
#  ('공급일은', 10),
#  ('납품', 10),
#  ('기한은', 10),
#  ('"을"은', 9),
#  ('"갑"에게', 9),
#  ('정해진', 9),
#  ('일정대로', 9),
#  ('용역', 9),
#  ('제출해야', 9),
#  ('물품의', 9),
#  ('계약일로부터', 9),
#  ('을은', 8),
#  ('개발의', 8),
#  ('계약', 8),
#  ('구축하여', 8),
#  ('모바일용', 8),
#  ('따라', 7),
#  ('‘갑’에게', 7),
#  ('제작된', 7),
#  ('홈페이지의', 7),
#  ('“갑”이', 7),
#  ('이내', 7),
#  ('의', 6),
#  ('완료하여', 6),
#  ('이내로', 6),
#  ('S/W', 6),
#  ('[날짜]([장소])', 5),
#  ('완료된', 5),
#  ('보고서', 5),
#  ('최종보고서', 5),
#  ('테스트', 5),
#  ('다만,', 5),
#  ('작업을', 5),
#  ('갑에게', 5),
#  ('성과물을', 5),
#  ('계약서에', 4),
#  ('명시된', 4),
#  ('또는', 4),
#  ('연구가', 4),
#  ('연구결과에', 4),
#  ('체결이후', 4),
#  ('설계도서를', 4),
#  ('완제품은', 4),
#  ('입력', 4),
#  ('말하며', 4),
#  ('까지', 4),
#  ('제출', 4),
#  ('약정서', 4),
#  ('체결과', 4),
#  ('동시에', 4),
#  ('번역에', 4),
#  ('착수하여', 4),
#  ('최종보고', 4),
#  ('만료일', 4),
#  ('첨부한', 3),
#  ('납품목록에', 3),
#  ('개발제품을', 3),
#  ('표시된', 3),
#  ('납기에', 3),
#  ('하여야', 3),
#  ('최종조사', 3),
#  ('분석보고서는', 3),
#  ('계약만료시', 3),
#  ('잔금', 3),
#  ('수령시에', 3),
#  ('단,', 3),
#  ('제시한', 3),
#  ('대한', 3),
#  ('것을', 3),
#  ('7일', 3),
#  ('없는', 3),
#  ('경우에는', 3),
#  ('제출은', 3),
#  ('관한', 3),
#  ('보고서(', 3),
#  ('3', 3),
#  ('부)를', 3),
#  ('“위탁자”에게', 3),
#  ('심의', 3),
#  ('S/W의', 3),
#  ('은', 3),
#  ('기획한', 3),
#  ('안에', 3),
#  ('유사한', 3),
#  ('실시', 3),
#  ('제공하여야', 3),
#  ('최종보고서를', 3),
#  ('종료', 3),
#  ('버전을', 3),
#  ('작업', 3),
#  ('위', 3),
#  ('완료하여야', 3),
#  ('상태를', 3),
#  ('착수하고', 3),
#  ('장소에', 3),
#  ('-', 3),
#  ('‘최종보고서’', 3),
#  ('이전에', 3),
#  ('제출(필요시', 3),
#  ('개최)', 3),
#  ('성과평가', 3),
#  ('대상기간', 3),
#  ('인도', 2),
#  ('성과품은', 2),
#  ('밀양시에서', 2),
#  ('제출기한', 2),
#  ('[날짜]전까지', 2),
#  ('검수에', 2),
#  ('“계약당사자1”이', 2),
#  ('것으로', 2),
#  ('물품을', 2),
#  ('1부를', 2),
#  ('있을', 2),
#  ('그', 2),
#  ('완성된', 2),
#  ('내에', 2),
#  ('최종보고서의', 2),
#  ('CD와', 2),
#  ('함께', 2),
#  ('“OOO원”은', 2),
#  ('이를', 2),
#  ('보완하여', 2),
#  ('보고서를', 2),
#  ('개발된', 2),
#  ('[날짜]이내에', 2),
#  ('계약상대자는', 2),
#  ('하자조사', 2),
#  ('납품(제출)', 2),
#  ('제출토록', 2),
#  ('[날짜]에', 2),
#  ('기간', 2),
#  ('하며', 2),
#  ('일정에', 2),
#  ('세부', 2),
#  ('기획서', 2),
#  ('사양을', 2),
#  ('검수용', 2),
#  ('β-Version을', 2),
#  ('1차로', 2),
#  ('(β-Version', 2),
#  ('이란', 2),
#  ('게임', 2),
#  ('이미지', 2),
#  ('부문의', 2),
#  ('기본적인', 2),
#  ('DATA의', 2),
#  ('동작', 2),
#  ('가능', 2),
#  ('사운드는', 2),
#  ('기본', 2),
#  ('일본', 2),
#  ('J-Phone', 2),
#  ('모든', 2),
#  ('개발관련(그래픽,', 2),
#  ('프로그래밍,', 2),
#  ('Data', 2),
#  ('Manual을', 2),
#  ('위한', 2),
#  ('S/W동작', 2),
#  ('Description을', 2),
#  ('(Master-Version', 2),
#  ('V0.1부터', 2),
#  ('시작하며', 2),
#  ('완료', 2),
#  ('더', 2),
#  ('이상의', 2),
#  ('수정상태가', 2),
#  ('V1.0으로', 2),
#  ('감리일정', 2),
#  ('감리보고서를', 2),
#  ('미술장식품의', 2),
#  ('제작에', 2),
#  ('미술장식품을', 2),
#  ('아파트', 2),
#  ('사용', 2),
#  ('검사', 2),
#  ('지정하는', 2),
#  ('납품,', 2),
#  ('설치를', 2),
#  ('"용역"', 2),
#  ('원고', 2),
#  ('보고회', 2),
#  ('개최', 2),
#  ('영상', 2),
#  ('“발주자”에게', 2),
#  ('착수일로부터', 2),
#  ('초안', 2),
#  ('최', 2),
#  ('종보고회', 2),
#  ('성과서를', 2),
#  ('재계약', 2),
#  ('도래시에는', 2),
#  ('계약만료', 2),
#  ('경과', 2),
#  ('90일', 2),
#  ('관리대행성과서를', 2),
#  ('완료감리', 2),
#  ('위탁기관의', 2),
#  ('납품일자:', 1),
#  ('계약물품', 1),
#  ('전부를', 1),
#  ('발주일로부터', 1),
#  ('갑', 1),
#  ('지정장소에', 1),
#  ('장소까지의', 1),
#  ('일체의', 1),
#  ('비용은', 1),
#  ('을', 1),
#  ('부담으로', 1),
#  ('납', 1),
#  ('품', 1),
#  ('기', 1),
#  ('간', 1),
#  ('[날짜][장소]', 1),
#  ('전', 1),
#  ('제3조', 1),
#  ('제2항의', 1),
#  ('기준은', 1),
#  ('정하여', 1),
#  ('“계약당사자2”에게', 1),
#  ('요구사양서', 1),
#  ('시험절차서', 1),
#  ('등의', 1),
#  ('서면에', 1),
#  ('의하며,', 1),
#  ('동', 1),
#  ('기준에', 1),
#  ('개발제품이', 1),
#  ('독립적으로', 1),
#  ('관련장비의', 1),
#  ('일부로서', 1),
#  ('정상적이고도', 1),
#  ('완전한', 1),
#  ('기능을', 1),
#  ('발휘한다는', 1),
#  ('서면으로', 1),
#  ('인정하는', 1),
#  ('때에', 1),
#  ('최종납품이', 1),
#  ('본다.', 1),
#  ("계약대상2'는", 1),
#  ("'계약대상1'에게", 1),
#  ('[공급일]', 1),
#  ('로', 1),
#  ('‘계약대상1’은', 1),
#  ('‘계약대상2’로부터', 1),
#  ('공급받은', 1),
#  ('검수', 1),
#  ('판정을', 1),
#  ('‘계약대상2’에게', 1),
#  ('통보하여야', 1),
#  ('(단', 1),
#  ('‘계약대상1’로부터', 1),
#  ('별다른', 1),
#  ('통보가', 1),
#  ('합격한', 1),
#  ('본다.)', 1),
#  ('계약대상2가', 1),
#  ('작성한', 1),
#  ('세무조정계산서는', 1),
#  ('계약대상1에게', 1),
#  ('교부한다.', 1),
#  ('다만', 1),
#  ('계약대상1의', 1),
#  ('요구가', 1),
#  ('때는', 1),
#  ('부수를', 1),
#  ('증가할', 1),
#  ('수', 1),
#  ('있다.', 1),
#  ('([개월', 1),
#  ('수]개월간)', 1),
#  ('웹사이트', 1),
#  ('개발기간은', 1),
#  ('[기간]까지', 1),
#  ('납품한다.', 1),
#  ('설계도', 1),
#  ('계약기간', 1),
#  ('[개수]를', 1),
#  ('“갑”은', 1),
#  ('“을”의', 1),
#  ('내용을', 1),
#  ('보완사항이', 1),
#  ('경우', 1),
#  ('[기간]이내에', 1),
#  ('경우,', 1),
#  ('“을”', 1),
#  ('검사완료후', 1),
#  ('의해', 1),
#  ('소스코드를', 1),
#  ('“갑”', 1),
#  ('에게', 1),
#  ('제출하여', 1),
#  ('운영관리가', 1),
#  ('가능하게', 1),
#  ('“OOOO원”은', 1),
#  ('DCC', 1),
#  ('완공하여야', 1),
#  ('목적물의', 1),
#  ('대상물의', 1),
#  ('공급(인도)일은[날짜]로', 1),
#  ('납품일자(장소)', 1),
#  ('[날짜](장소', 1),
#  ('○○)', 1),
#  ('과제보고일자', 1),
#  ('결과물의', 1),
#  ('베타버전을', 1),
#  ('과제', 1),
#  ('[기간]전에', 1),
#  ('제출하고,', 1),
#  ('계속과제의', 1),
#  ('당해연도', 1),
#  ('과제종료', 1),
#  ('"발주처"에', 1),
#  ('설계도면을', 1),
#  ('관련', 1),
#  ('자료를', 1),
#  ('첨부하여', 1),
#  ('2부', 1),
#  ('연구책임자는', 1),
#  ('3부를', 1),
#  ('위탁자에게', 1),
#  ('납기일자', 1),
#  ('웹디자인', 1),
#  ('전체를', 1),
#  ('개발', 1),
#  ('을은[날짜]까지', 1),
#  ('제3조의', 1),
#  ('계획서의', 1),
#  ('확정', 1),
#  ('일로부터', 1),
#  ('홈페이지', 1),
#  ('종료하여', 1),
#  ('“갑”의', 1),
#  ('검수를', 1),
#  ('받도록', 1),
#  ('체결', 1),
#  ('한글문서로', 1),
#  ('번역작업을', 1),
#  ('완료한', 1),
#  ('E-mail로', 1),
#  ('만료일까지', 1),
#  ('납품을', 1),
#  ('완료해야', 1),
#  ('○○', 1),
#  ('명도는', 1),
#  ('"갑"이', 1),
#  ('회수정산을', 1),
#  ('요구한', 1),
#  ('날로부터', 1),
#  ('정산결과서를', 1),
#  ('제출함을', 1),
#  ('원칙으로', 1),
#  ('예정일자', 1),
#  ('"갑"은', 1),
#  ('개발을', 1),
#  ('계약상의', 1),
#  ('조사업무의', 1),
#  ('20', 1),
#  ('년', 1),
#  ('월', 1),
#  ('일까지', 1),
#  ('파일의', 1),
#  ('말한다.)', 1),
#  ('런칭용', 1),
#  ('Master-Version과', 1),
#  ('사운드', 1),
#  ('등)', 1),
#  ('Source', 1),
#  ('"댄스댄스"의', 1),
#  ('종결된다.)', 1),
#  ('납기:', 1),
#  ('건물의', 1),
#  ('신축공사를', 1),
#  ('“갑“에게', 1),
#  ('인도한다.', 1),
#  ('발주', 1),
#  ('주문한', 1),
#  ('상기', 1),
#  ('인도키로', 1),
#  ('인도기한:', 1),
#  ('인도장소.방법:', 1),
#  ('체결일에', 1),
#  ('신청일', 1),
#  ('[날짜]이전까지', 1),
#  ('기술용역의', 1),
#  ('하는데,', 1),
#  ('지정한다.', 1),
#  ('위탁한', 1),
#  ('목적물에', 1),
#  ('대해', 1),
#  ('직무를', 1),
#  ('이행한다.', 1),
#  ('을”은', 1),
#  ('계약체결일에', 1),
#  ('신청일[날짜]이전까지', 1),
#  ('갑”은', 1),
#  ('당월', 1),
#  ('착용한', 1),
#  ('필름을', 1),
#  ('다음달', 1),
#  ('“을”에게', 1),
#  ('반송하여야', 1),
#  ('소프트웨어의', 1),
#  ('개발설치', 1),
#  ('완료기간은', 1),
#  ('[날짜]까지이며,', 1),
#  ('납품물의', 1),
#  ('[날짜]까지로', 1),
#  ('서비스와', 1),
#  ('관련하여', 1),
#  ('생산된', 1),
#  ('디자인,', 1),
#  ('보고,', 1),
#  ('매뉴얼이나', 1),
#  ('기타', 1),
#  ('사항을', 1),
#  ('포함하는', 1),
#  ('감리자는', 1),
#  ('사용검사신청서', 1),
#  ('임시사용승인신청서에', 1),
#  ('날인한', 1),
#  ('관계법령에', 1),
#  ('의한', 1),
#  ('사업주체에게', 1),
#  ('용역의', 1),
#  ('완료는', 1),
#  ('(병)은', 1),
#  ('연구기간', 1),
#  ('다음의', 1),
#  ('연구결과', 1),
#  ('보고서를작성하여', 1),
#  ('(갑)에게', 1),
#  ('반드시', 1),
#  ('부를', 1),
#  ('파일', 1),
#  ('의상태를', 1),
#  ('말한다)', 1),
#  ('런칭용Master', 1),
#  ('Version과', 1),
#  ('사운드등)Source', 1),
#  ('“댄스댄스”의', 1),
#  ('종결', 1),
#  ('된다.)', 1),
#  ('최종감리', 1),
#  ('종료후', 1),
#  ('1주일', 1),
#  ('진행중', 1),
#  ('중간완료된', 1),
#  ('[날짜],', 1),
#  ('등', 1),
#  ('O회에', 1),
#  ('걸쳐', 1),
#  ('중간납품을', 1),
#  ('하기로', 1),
#  ('납품은', 1),
#  ('검토', 1),
#  ('수정', 1),
#  ('완성품으로', 1),
#  ('으로', 1),
#  ('납품키로', 1),
#  ('연구완료', 1),
#  ('연구결과를', 1),
#  ('정리하여', 1),
#  ('(○○)부를', 1),
#  ('(갑)으로부터', 1),
#  ('의뢰받은', 1),
#  ('업무를', 1),
#  ('(을)은', 1),
#  ('제3조에', 1),
#  ('종료일로부터', 1),
#  ('"용역"에', 1),
#  ('제공하며,', 1),
#  ('필요시', 1),
#  ('수행에', 1),
#  ('제공한다.', 1),
#  ('20161214', 1),
#  ('(납품기간)[기간]', 1),
#  ('최종결과물을', 1),
#  ('비즈니스', 1),
#  ('전시', 1),
#  ('수출상담회', 1),
#  ('운영', 1),
#  ('대행', 1),
#  ('계약기간은', 1),
#  ('[기간](검수완료일)까지로', 1),
#  ('2017/12/31', 1),
#  ('최종보고는[날짜]', 1),
#  ('완료하도록', 1),
#  ('(주관연구기관의', 1),
#  ('장)은', 1),
#  ('평가결과를', 1),
#  ('반영한', 1),
#  ('용역연구개발과제', 1),
#  ('관련자료', 1),
#  ('일체를', 1),
#  ('평', 1),
#  ('가원장에게', 1),
#  ('KOELSA', 1),
#  ('E/S', 1),
#  ('최종보고:', 1),
#  ('계약종료일로부터', 1),
#  ('이내까지', 1),
#  ('초안을', 1),
#  ('최종보고회', 1),
#  ('“용역수행자”는', 1),
#  ('용역완료시', 1),
#  ('최종용역', 1),
#  ('결과물', 1),
#  ('20부(요약본', 1),
#  ('전산화일', 1),
#  ('포함)를', 1),
#  ('용역완료일에', 1),
#  ('정한', 1),
#  ('선적(또는', 1),
#  ('인도)', 1),
#  ('기일까지', 1),
#  ('해당', 1),
#  ('물품(검사에', 1),
#  ('필요한', 1),
#  ('서류', 1),
#  ('등을', 1),
#  ('포함한다)을', 1),
#  ('협력단이', 1),
#  ('지정한', 1),
#  ('과업의', 1),
#  ('보고를', 1),
#  ('“관리대행업자”는', 1),
#  ('경과후', 1),
#  ('관리대행', 1),
#  ('“관리청”에게', 1),
#  ('관리대행운영관리', 1),
#  ('대행성과서를', 1),
#  ('60일', 1),
#  ('위·수탁', 1),
#  ('협약서', 1),
#  ('위탁업무', 1),
#  ('내용', 1),
#  ('처리방법에', 1),
#  ('의거한', 1),
#  ('만료', 1),
#  ('시에는', 1),
#  ('이전까지', 1),
#  ('위탁성과서를', 1),
#  ('30일', 1),
#  ('“갑”과', 1),
#  ('성과평가위원회에', 1),
#  ('납품기한', 1),
#  ('계약완료일', 1),
#  ('20영업일', 1),
#  ('사업완료보고서', 1),
#  ('[기간]이내', 1),
#  ('용역완료', 1),
#  ('시', 1),
#  ('제1항의', 1),
#  ('연구결과보고서', 1),
#  ('초안에', 1),
#  ('대하여', 1),
#  ('보완', 1),
#  ('요청이', 1),
#  ('없으면', 1),
#  ('초안은', 1),
#  ('연구결', 1),
#  ('과보고서로', 1),
#  ('확정되지만,', 1),
#  ('보완요청이', 1),
#  ('있는', 1),
#  ('수정된', 1),
#  ('최종연', 1),
#  ('구결과보고서를', 1),
#  ('청사진으로', 1),
#  ('3부', 1),
#  ('계약기간내에', 1),
#  ('납부하여야', 1)]

# %%
show_freq_by_option(df, '필수조항3')
# Out:
# 908
# [('[금액]', 376),
#  (':', 207),
#  ('한다.', 126),
#  ('[금액]으로', 120),
#  ('본', 91),
#  ('계약금액', 64),
#  ('총', 54),
#  ('계약금액은', 53),
#  ('지급한다.', 49),
#  ('포함)', 39),
#  ('[금액](부가세', 39),
#  ('[금액]을', 38),
#  ('대한', 36),
#  ('부가가치세', 30),
#  ('계약의', 29),
#  ('계약금액:', 28),
#  ('별도)', 25),
#  ('“갑”은', 24),
#  ('“을”에게', 24),
#  ('계약에', 22),
#  ('하고', 22),
#  ('용역비는', 22),
#  ('[금액](부가가치세', 21),
#  ('금', 21),
#  ('같이', 20),
#  ('계약', 20),
#  ('다음과', 19),
#  ('계', 19),
#  ('액', 19),
#  ('하며', 19),
#  ('따른', 19),
#  ('후', 19),
#  ('월', 18),
#  ('용역', 17),
#  ('비용은', 17),
#  ('"을"에게', 17),
#  ('공급가액', 16),
#  ('“을”이', 16),
#  ('용역에', 16),
#  ('그', 16),
#  ('금액:', 15),
#  ('별도)으로', 15),
#  ('하며,', 15),
#  ('경우', 15),
#  ('용역의', 15),
#  ('및', 15),
#  ('"갑"은', 15),
#  ('따라', 15),
#  ('용역대금은', 14),
#  ('일금', 14),
#  ('다음', 14),
#  ('금액을', 14),
#  ('약', 13),
#  ('보수는', 13),
#  ('단,', 13),
#  ('(부가세', 12),
#  ('제공하는', 12),
#  ('정한다.', 12),
#  ('별도로', 12),
#  ('용역비', 12),
#  ('“을”의', 11),
#  ('소요되는', 11),
#  ('수수료는', 11),
#  ('[요율]', 11),
#  ('금액은', 11),
#  ('[금액](VAT포함)', 11),
#  ('의한', 10),
#  ('의하여', 10),
#  ('갑은', 10),
#  ('계약금으로', 10),
#  ('지급하기로', 10),
#  ('“갑”이', 10),
#  ('[요율]를', 10),
#  ('총액', 10),
#  ('같다.', 10),
#  ('가격:', 10),
#  ('정하고', 9),
#  ('각', 9),
#  ('하고,', 9),
#  ('아니한다.', 9),
#  ('이', 9),
#  ('/', 9),
#  ('포함)으로', 8),
#  ('[금액])', 8),
#  ('부가세', 8),
#  ('해당하는', 8),
#  ('[금액],', 8),
#  ('현금으로', 8),
#  ('1인당', 8),
#  ('“을”은', 8),
#  ('개발', 8),
#  ('[금액](부가세포함)으로', 8),
#  ('각호에', 8),
#  ('초과하는', 8),
#  ('OOO,', 8),
#  ('상세내역은', 7),
#  ('첨부의', 7),
#  ('납품목록에', 7),
#  ('기재한다.', 7),
#  ('수', 7),
#  ('한다', 7),
#  ('연구에', 7),
#  ('연구비는', 7),
#  ('아래와', 7),
#  ('으로', 7),
#  ('(공급가액', 7),
#  ('"을"의', 7),
#  ('"갑"과', 7),
#  ('VAT별도', 7),
#  ('"을"이', 7),
#  ('"을"은', 7),
#  ('포함하여', 7),
#  ('[금액](VAT', 7),
#  ('영업지원', 7),
#  ('구체적', 7),
#  ('구분:', 6),
#  ('합계:', 6),
#  ('별도', 6),
#  ('규정에', 6),
#  ('경우에는', 6),
#  ('다음의', 6),
#  ('관련하여', 6),
#  ('가격', 6),
#  ('위', 6),
#  ('정한', 6),
#  ('별도)을', 6),
#  ('비용을', 6),
#  (',', 6),
#  ('1일', 6),
#  ('이내', 6),
#  ('지불할', 6),
#  ('을의', 6),
#  ('지급은', 6),
#  ('“갑”의', 6),
#  ('-', 6),
#  ('부가가치세를', 6),
#  ('“갑”에게', 6),
#  ('부가가치세는', 6),
#  ('[금액]-부가세별도', 6),
#  ('은행계좌에', 6),
#  ('인정되지', 6),
#  ('공급가액:', 5),
#  ('전', 5),
#  ('대가로', 5),
#  ('별첨', 5),
#  ('지급하여야', 5),
#  ('[금액]으로써,', 5),
#  ('하여', 5),
#  ('용역대행의', 5),
#  ('추가로', 5),
#  ('매월', 5),
#  ('[금액]의', 5),
#  ('의', 5),
#  ('수수료', 5),
#  ('총금액', 5),
#  ('총액의', 5),
#  ('곱한', 5),
#  ('금액', 5),
#  ('[금액](부가세포함)', 5),
#  ('“을”', 5),
#  ('[요율]로', 5),
#  ('부가세별도', 5),
#  ('개발용역비로서', 5),
#  ('용역금액', 5),
#  ('공급자의', 5),
#  ('00', 5),
#  ('디자인', 5),
#  ('시', 5),
#  ('"갑"에게', 5),
#  ('따른다.', 5),
#  ('1과', 5),
#  ('부가가치세:', 4),
#  ('변경전', 4),
#  ('변경', 4),
#  ('정산하여', 4),
#  (')', 4),
#  ('노무비', 4),
#  ('없는', 4),
#  ('협의하여', 4),
#  ('기준으로', 4),
#  ('시간당', 4),
#  ('미국변호사', 4),
#  ('업무', 4),
#  ('성공보수', 4),
#  ('합', 4),
#  ('같은', 4),
#  ('또는', 4),
#  ('등', 4),
#  ('계산하여', 4),
#  ('특별한', 4),
#  ('비용이', 4),
#  ('소요될', 4),
#  ('때는', 4),
#  ('가산한다.', 4),
#  ('지급하며', 4),
#  ('초과', 4),
#  ('용역수수료를', 4),
#  ('포함)을', 4),
#  ('용역을', 4),
#  ('[날짜]', 4),
#  ('하기로', 4),
#  ('포함한다.', 4),
#  ('총액은', 4),
#  ('(', 4),
#  ('원칙으로', 4),
#  ('착수금은', 4),
#  ('보수금액은', 4),
#  ('계,', 4),
#  ('매매대금', 4),
#  ('제2조에서', 4),
#  ('토지', 4),
#  ('매입', 4),
#  ('합계,', 4),
#  ('추가', 4),
#  ('운임을', 4),
#  ('“갑”', 4),
#  ('제2조에', 4),
#  ('각호의', 4),
#  ('합한', 4),
#  ('금액으로', 4),
#  ('아래', 4),
#  ('부담한다.', 4),
#  ('대하여', 4),
#  ('용역대금', 4),
#  ('직접인건비', 4),
#  ('기술자', 4),
#  ('등급별', 4),
#  ('제경비', 4),
#  ('지급율은', 4),
#  ('인원파견용역', 4),
#  ('직접인건비의', 4),
#  ('위탁개발용역', 4),
#  ('기술료', 4),
#  ('(직접인건비＋제경비)×[요율]', 4),
#  ('별도).', 4),
#  ('현금', 4),
#  ('호의', 4),
#  ('방법은', 4),
#  ('연간', 4),
#  ('이내에', 4),
#  ('입금한다.', 4),
#  ('지정하는', 4),
#  ('사업비는', 4),
#  ('비고:', 3),
#  ('지급한다', 3),
#  ('.', 3),
#  ('발생한', 3),
#  ('이하', 3),
#  ('병에게', 3),
#  ('포함된', 3),
#  ('것으로', 3),
#  ('착수금', 3),
#  ('파산자의', 3),
#  ('관할법원이', 3),
#  ('추후', 3),
#  ('정하는', 3),
#  ('전액', 3),
#  ('(부가가치세', 3),
#  ('동시에', 3),
#  ('구분에', 3),
#  ('승소로', 3),
#  ('지급하는', 3),
#  ('판매가', 3),
#  ('미만일', 3),
#  ('경우는', 3),
#  ('판매할시는', 3),
#  ('그리고', 3),
#  ('초과시는', 3),
#  ('완료하고', 3),
#  ('계:', 3),
#  ('V.A.T는', 3),
#  ('별도임', 3),
#  ('용역비의', 3),
#  ('상표도입', 3),
#  ('기술도입', 3),
#  ('직접', 3),
#  (')원', 3),
#  ('을이', 3),
#  ('을에게', 3),
#  ('세대당', 3),
#  ('한다(V.A.T', 3),
#  ('설계', 3),
#  ('[금액](VAT별도)으로', 3),
#  ('매매계약', 3),
#  ('체결한', 3),
#  ('용역금액으로', 3),
#  ('‘갑’은', 3),
#  ('수송비:', 3),
#  ('“갑”과', 3),
#  ('지불방법은', 3),
#  ('(VAT별도)', 3),
#  ('경우,', 3),
#  ('업무를', 3),
#  ('하되', 3),
#  ('책임구간', 3),
#  ('즉시', 3),
#  ('에게', 3),
#  ('대해서는', 3),
#  ('산정한', 3),
#  ('제외)', 3),
#  ('유지보수', 3),
#  ('계약대금은', 3),
#  ('결정한다.', 3),
#  ('[금액](부가세별도)', 3),
#  ('현금입금하며', 3),
#  ('표에', 3),
#  ('계약금', 3),
#  ('시에', 3),
#  ('지불한다.', 3),
#  ('1인', 3),
#  ('연구비', 3),
#  ('평당', 3),
#  ('시공사', 3),
#  ('용역수행에', 3),
#  ('산정하며', 3),
#  ('제2조', 3),
#  ('"갑"이', 3),
#  ('위탁에', 3),
#  ('대가는', 3),
#  ('○○○원', 3),
#  ('만원초과', 3),
#  ('만원이하:', 3),
#  ('의해', 3),
#  ('있다.', 3),
#  ('지급할', 3),
#  ('업무의', 3),
#  ('[금액]이며,', 3),
#  ('이상을', 3),
#  ('정산시', 3),
#  ('포함', 3),
#  ('￦-', 3),
#  ('￦', 3),
#  ('-)', 3),
#  ('운영관리', 3),
#  ('톤당', 3),
#  ('처리시설', 3),
#  ('0.004', 3),
#  ('(노무비', 2),
#  ('단가:', 2),
#  ('지불하기로', 2),
#  ('건설산업기본법', 2),
#  ('시행령', 2),
#  ('손해가', 2),
#  ('있는', 2),
#  ('총금액,', 2),
#  ('동', 2),
#  ('요율에', 2),
#  ('계산된', 2),
#  ('병의', 2),
#  ('용역수수료(부가가치세는', 2),
#  ('같다)를', 2),
#  ('Partner', 2),
#  ('Associate', 2),
#  ('보수액', 2),
#  ('용역수행과', 2),
#  ('직원이', 2),
#  ('출장시에', 2),
#  ('수반되는', 2),
#  ('출장비,', 2),
#  ('교통비,', 2),
#  ('체제비등', 2),
#  ('제경비는', 2),
#  ('위의', 2),
#  ('용역금액에', 2),
#  ('용역과', 2),
#  ('성공률', 2),
#  ('승소금액/소가×100)', 2),
#  ('부담하며', 2),
#  ('체결과', 2),
#  ('계약금은', 2),
#  ('단가', 2),
#  ('외', 2),
#  ('등으로', 2),
#  ('때에는', 2),
#  ('승소한', 2),
#  ('일부', 2),
#  ('금액(부가가치세', 2),
#  ('[백분율]에', 2),
#  ('상소심의', 2),
#  ('전부를', 2),
#  ('성과', 2),
#  ('공제한', 2),
#  ('“계약대상2”에게', 2),
#  ('을', 2),
#  ('감리용역계약금액:', 2),
#  ('익월', 2),
#  ('[날짜]까지', 2),
#  ('지급액', 2),
#  ('제출한', 2),
#  ('가액', 2),
#  ('업무범위:', 2),
#  ('업무기간:', 2),
#  ('[기간]', 2),
#  ('지급시기*:', 2),
#  ('지급', 2),
#  ('용역대행', 2),
#  ('VAT를', 2),
#  ('자문', 2),
#  ('①', 2),
#  ('수입시:', 2),
#  ('감리비', 2),
#  ('감리비는', 2),
#  ('‘', 2),
#  ('PM(Project', 2),
#  ('Management.)용역', 2),
#  ('업무범위’를', 2),
#  ('컨설팅에', 2),
#  ('청구서를', 2),
#  ('받고', 2),
#  ('자문료(“자문료”)로서', 2),
#  ('[금액]를', 2),
#  ('판독대금은', 2),
#  ('경리지불', 2),
#  ('계약을', 2),
#  ('노력으로', 2),
#  ('본문', 2),
#  ('약정한', 2),
#  ('토지매입', 2),
#  ('총금액원정', 2),
#  ('보다', 2),
#  ('저렴한', 2),
#  ('가격으로', 2),
#  ('토지를', 2),
#  ('매입하였을시는', 2),
#  ('총차액금액의', 2),
#  ('상여금으로', 2),
#  ('갑의', 2),
#  ('사업계획', 2),
#  ('매입조건으로', 2),
#  ('의뢰하고', 2),
#  ('이를', 2),
#  ('수락하며', 2),
#  ('용역비용으로', 2),
#  ('세금포함', 2),
#  ('지불키로한다.', 2),
#  ('지급일:', 2),
#  ('이상의', 2),
#  ('‘을’에게', 2),
#  ('사업시행인가', 2),
#  ('연면적이', 2),
#  ('확정되면', 2),
#  ('확정된', 2),
#  ('연면적(평)에', 2),
#  ('[금액](부가가치세별도)을', 2),
#  ('최종금액으로', 2),
#  ('(총액)', 2),
#  ('[금액](세금공제전금액)', 2),
#  ('“병”은', 2),
#  ('제1조의', 2),
#  ('업무수행에', 2),
#  ('이며,', 2),
#  ('체결', 2),
#  ('될', 2),
#  ('자금', 2),
#  ('보수로', 2),
#  ('발생하는', 2),
#  ('분양수수료는', 2),
#  ('한다.(부가세', 2),
#  ('물건을', 2),
#  ('분양할', 2),
#  ('때', 2),
#  ('타인(건축주,', 2),
#  ('건축업자,', 2),
#  ('기타관련자)의', 2),
#  ('알선분양과', 2),
#  ('임직원의', 2),
#  ('소개에', 2),
#  ('계약인', 2),
#  ('분양수수료의', 2),
#  ('계약금액,', 2),
#  ('총계약', 2),
#  ('다만,', 2),
#  ('취소된', 2),
#  ('거래에', 2),
#  ('수수료가', 2),
#  ('지급되지', 2),
#  ('제공한', 2),
#  ('“용역”에', 2),
#  ('대해', 2),
#  ('수수료(부가가치세', 2),
#  ('별도)는', 2),
#  ('방식으로', 2),
#  ('모두', 2),
#  ('비용과', 2),
#  ('비용에', 2),
#  ('가산이익률을', 2),
#  ('금액.', 2),
#  ('가산이익', 2),
#  ('계산시', 2),
#  ('2)항의', 2),
#  ('계산에', 2),
#  ('포함하지', 2),
#  ('않는다.', 2),
#  ('인건비', 2),
#  ('인건비성', 2),
#  ('경비', 2),
#  ('일반관리비', 2),
#  ('일체(단,', 2),
#  ('광고선전비,', 2),
#  ('접대비,', 2),
#  ('무형자산', 2),
#  ('감가상각비등', 2),
#  ('컨설팅', 2),
#  ('비용', 2),
#  ('정비보수료는', 2),
#  ('연', 2),
#  ('별도)이며,', 2),
#  ('부가세를', 2),
#  ('하되,', 2),
#  ('은', 2),
#  ('내에', 2),
#  ('계약은', 2),
#  ('월납', 2),
#  ('[금액]/톤(건조', 2),
#  ('기준)', 2),
#  ('“본', 2),
#  ('매년', 2),
#  ('OOO자문', 2),
#  ('매', 2),
#  ('분기', 2),
#  ('산정한다.', 2),
#  ('[금액]-부가세포함', 2),
#  ('이행을', 2),
#  ('위하여', 2),
#  ('Employee에게', 2),
#  ('다음에', 2),
#  ('합계금액', 2),
#  ('점검', 2),
#  ('업무에', 2),
#  ('세부내역은', 2),
#  ('수입', 2),
#  ('대행비를', 2),
#  ('조건으로', 2),
#  ('용역비로', 2),
#  ('포함한', 2),
#  ('1회', 2),
#  ('VAT', 2),
#  ('투입되는', 2),
#  ('예상투입공수에', 2),
#  ('기준', 2),
#  ('노임단가를', 2),
#  ('적용하여', 2),
#  ('총액을', 2),
#  ('산출한다.', 2),
#  ('영역별', 2),
#  ('용역별', 2),
#  ('직접경비', 2),
#  ('사용된', 2),
#  ('경비에', 2),
#  ('한하여', 2),
#  ('인정하는', 2),
#  ('범위', 2),
#  ('내에서', 2),
#  ('산정기준은', 2),
#  ('쌍방협의하여', 2),
#  ('1항에', 2),
#  ('명시된', 2),
#  ('직접인건비,', 2),
#  ('제경비,', 2),
#  ('기술료,', 2),
#  ('직접경비의', 2),
#  ('합계금액으로', 2),
#  ('용역대가는', 2),
#  ('현금입금', 2),
#  ('통하여', 2),
#  ('양수도', 2),
#  ('"갑"의', 2),
#  ('따른다(VAT', 2),
#  ('완료', 2),
#  ('시에는', 2),
#  ('“乙”이', 2),
#  ('사업을', 2),
#  ('지분은', 2),
#  ('지급방법은', 2),
#  ('회수운송비용', 2),
#  ('책정된다.', 2),
#  ('별도,', 2),
#  ('포함)한다.', 2),
#  ('대가', 2),
#  ('제2항의', 2),
#  ('용역결과물을', 2),
#  ('제공하고,', 2),
#  ('이에', 2),
#  ('방법으로', 2),
#  ('총[금액]으로', 2),
#  ('설계용역의', 2),
#  ('하고.', 2),
#  ('지급토록', 2),
#  ('매입대금의', 2),
#  ('견적서에', 2),
#  ('도급금액은', 2),
#  ('따른다(부가세', 2),
#  ('Consulting', 2),
#  ('Fee는', 2),
#  ('후보자', 2),
#  ('연봉(Incentive', 2),
#  ('포함)의', 2),
#  ('합의에', 2),
#  ('인하여', 2),
#  ('구체적으로', 2),
#  ('구', 2),
#  ('지급되는', 2),
#  ('성공보수의', 2),
#  ('청구하고,', 2),
#  ('대출금', 2),
#  ('상기', 2),
#  ('계약내용의', 2),
#  ('[금액](VAT포함)으로', 2),
#  ('VAT포함', 2),
#  ('지체상금', 2),
#  ('인한', 2),
#  ('지체상금을', 2),
#  ('작업을', 2),
#  ('종료하여', 2),
#  ('성과물을', 2),
#  ('제출하면', 2),
#  ('“대상자”에', 2),
#  ('종합검진', 2),
#  ('발주자는', 2),
#  ('수탁자에게', 2),
#  ('수탁자가', 2),
#  ('용역금액은', 2),
#  ('\\', 2),
#  ('비용(이하', 2),
#  ('한다)은', 2),
#  ('비목별', 2),
#  ('내역은', 2),
#  ('에', 2),
#  ('단가는', 2),
#  ('수수료(kg당):', 2),
#  ('수수료(회당):', 2),
#  ('×', 2),
#  ('=', 2),
#  ('변호사(OOO,', 2),
#  ('OOO)', 2),
#  ('[금액]-[금액]', 2),
#  ('[요율]에', 2),
#  ('지급합니다.', 2),
#  ('0.005', 2),
#  ('0.003', 2),
#  ('甲은', 2),
#  ('乙에게', 2),
#  ('(용역)공급가액:', 1),
#  ('자재공급가액:', 1),
#  ('(해당되는', 1),
#  ('경우에', 1),
#  ('한함)', 1),
#  ('시수×임율', 1),
#  ('시수:', 1),
#  ('단가×납품수량', 1),
#  ('매월말', 1),
#  ('기성분을', 1),
#  ('대금을', 1),
#  ('지급함', 1),
#  ('[표]', 1),
#  ('공종:', 1),
#  ('수량(Ton):', 1),
#  ('VAT:', 1),
#  ('Loss율', 1),
#  ('[백분율]', 1),
#  ('경비료는', 1),
#  ('[금액](', 1),
#  ('개발에', 1),
#  ('“사양서”에', 1),
#  ('기재된', 1),
#  ('개발비의', 1),
#  ('3분의1에', 1),
#  ('운반단가', 1),
#  ('기본단가', 1),
#  ('[단위]당', 1),
#  ('계약금액은[금액]으로', 1),
#  ('제4조', 1),
#  ('공', 1),
#  ('급', 1),
#  ('가', 1),
#  ('계약내용을', 1),
#  ('변경하여', 1),
#  ('손해발생에', 1),
#  ('책임이', 1),
#  ('자가', 1),
#  ('손해를', 1),
#  ('배상하도록', 1),
#  ('원사업자나', 1),
#  ('수급사업자', 1),
#  ('모두에게', 1),
#  ('귀책사유가', 1),
#  ('없거나', 1),
#  ('귀책사유를', 1),
#  ('알', 1),
#  ('원사업자와', 1),
#  ('수급사', 1),
#  ('업자가', 1),
#  ('손해의', 1),
#  ('분담액을', 1),
#  ('[금액]/[개수]를', 1),
#  ('[전기공사업법', 1),
#  ('제34조의', 1),
#  ('노임]', 1),
#  ('(노무비:', 1),
#  ('제88조제2항,', 1),
#  ('제84제1항', 1),
#  ('산출한', 1),
#  ('노임', 1),
#  ('변호사([성명1],', 1),
#  ('[성명2],', 1),
#  ('[성명3],', 1),
#  ('[성명4],', 1),
#  ('[성명5],', 1),
#  ('[성명6]):', 1),
#  ('변호사([성명7],', 1),
#  ('[성명8],', 1),
#  ('[성명9],', 1),
#  ('[성명10],', 1),
#  ('[성명11],', 1),
#  ('[성명12]):', 1),
#  ('관련된', 1),
#  ('보수를', 1),
#  ('금액×성공률', 1),
#  ('(*', 1),
#  ('"위탁자"가', 1),
#  ('"위탁자"는', 1),
#  ('[회사명2]에', 1),
#  ('[금액]원', 1),
#  ('월정액', 1),
#  ('계약대상2”는', 1),
#  ('지급받으며', 1),
#  ('반환하지', 1),
#  ('계약대상2는', 1),
#  ('내용(금형비', 1),
#  ('1set', 1),
#  ('제품', 1),
#  ('과', 1),
#  ('부품을', 1),
#  ('명기된', 1),
#  ('수량으로', 1),
#  ('공급한다.', 1),
#  ('착수보수', 1),
#  ('[착수보수]', 1),
#  ('성과보수', 1),
#  ('위임사무가', 1),
#  ('판결,', 1),
#  ('재판상', 1),
#  ('내지', 1),
#  ('재판', 1),
#  ('화해(화해권고결정', 1),
#  ('포함),', 1),
#  ('조정(조정에', 1),
#  ('갈음한', 1),
#  ('결정', 1),
#  ('성공한', 1),
#  ('성과보수를', 1),
#  ('전부', 1),
#  ('승소비율로', 1),
#  ('계산한', 1),
#  ('얻은', 1),
#  ('경제적', 1),
#  ('이익가액의', 1),
#  ('달리', 1),
#  ('정함이', 1),
#  ('한', 1),
#  ('심판의', 1),
#  ('대상', 1),
#  ('승소', 1),
#  ('비율을', 1),
#  ('보는', 1),
#  ('보고,', 1),
#  ('가항에', 1),
#  ('보수액을', 1),
#  ('계약대상1은', 1),
#  ('계약대상2에게', 1),
#  ('위임계약의', 1),
#  ('성립과', 1),
#  ('착수보수로', 1),
#  ('환급', 1),
#  ('취소․경정', 1),
#  ('감액된', 1),
#  ('세액의', 1),
#  ('[백분율](부가가치세', 1),
#  ('(원,', 1),
#  ('[금액]으로써', 1),
#  ('전항의', 1),
#  ('매상대금은', 1),
#  ('“계약대상1”이', 1),
#  ('기일마다', 1),
#  ('마감일에', 1),
#  ('매상총액에서', 1),
#  ('제세', 1),
#  ('공과금을', 1),
#  ('후,', 1),
#  ('잔액의', 1),
#  ('상당하는', 1),
#  ('보수(위탁료)로서', 1),
#  ('총비용은', 1),
#  ('제작비용은', 1),
#  ('웹사이트', 1),
#  ('제작', 1),
#  ('[금액](세금포함)으로', 1),
#  ('“계약대상1”은', 1),
#  ('대행보수로서', 1),
#  ('(VAT포함)', 1),
#  ('공사금액/AMOUNT', 1),
#  ('공사(설계)금액은', 1),
#  ('(V.A.T별도)', 1),
#  ('청소용역비', 1),
#  ('[금액](평당[금액]', 1),
#  ('청구에', 1),
#  ('[금액]은', 1),
#  ('최종결과물을', 1),
#  ('(공급', 1),
#  ('계약목적물의', 1),
#  ('제작비용을', 1),
#  ('약정', 1),
#  ('없으면', 1),
#  ('청구일부터', 1),
#  ('[날짜],', 1),
#  ('설계도서', 1),
#  ('인도일부터', 1),
#  ('계약금액은[금액](', 1),
#  ('VAT포함)으로', 1),
#  ('[금액]으로하고', 1),
#  ('②', 1),
#  ('계약시:', 1),
#  ('연구비는[금액]으로', 1),
#  ('[요율][금액]', 1),
#  ('[금액]부가가치세', 1),
#  ('‘첨부#1’', 1),
#  ('기준으', 1),
#  ('로', 1),
#  ('댓가는', 1),
#  ('고객으로', 1),
#  ('부터', 1),
#  ('수령한다.', 1),
#  ('현금결재를', 1),
#  ('판매', 1),
#  ('보수액:', 1),
#  ('[금액]씩(부가세별도,', 1),
#  ('1년/7인)', 1),
#  ('용역비용은', 1),
#  ('임대차', 1),
#  ('체결할', 1),
#  ('세대별로', 1),
#  ('‘甲’이', 1),
#  ('지급하되,', 1),
#  ('세대별[금액]으로', 1),
#  ('제', 1),
#  ('1', 1),
#  ('조의', 1),
#  ('위탁의무에', 1),
#  ('보수로써', 1),
#  ('공급가액과', 1),
#  ('부가세액', 1),
#  ('합계금액[금액]을', 1),
#  ('입력하세요', 1),
#  ('지불시기:', 1),
#  ('[금액]부가세별도', 1),
#  ('[금액]단,', 1),
#  ('‘을’에', 1),
#  ('조합', 1),
#  ('당초(계약', 1),
#  ('당시)', 1),
#  ('사업계획에', 1),
#  ('비하여', 1),
#  ('수익이', 1),
#  ('발생하였을', 1),
#  ('발생수익의', 1),
#  ('성과급을', 1),
#  ('지급회차:', 1),
#  ('지급비율:', 1),
#  ('을”또는', 1),
#  ('추천기관과', 1),
#  ('“갑”간에', 1),
#  ('PF', 1),
#  ('관련', 1),
#  ('계약이', 1),
#  ('최초자금', 1),
#  ('유치일에', 1),
#  ('유칙금액의', 1),
#  ('계약완료수수료', 1),
#  (':[금액]', 1),
#  ('("을"이', 1),
#  ('완료한', 1),
#  ('시점)', 1),
#  ('주차장', 1),
#  ('관리대행으로부터', 1),
#  ('수익의', 1),
#  ('지불하며,', 1),
#  ('잔여액은', 1),
#  ('수취한다.', 1),
#  ('본계약', 1),
#  ('“갑”을', 1),
#  ('‘첨부1’', 1),
#  ('월간', 1),
#  ('한다.(세금을', 1),
#  ('제외한', 1),
#  ('지급하다.)', 1),
#  ('운송물에', 1),
#  ('전구간의', 1),
#  ('운임총액은', 1),
#  ('「을」의', 1),
#  ('「병」의', 1),
#  ('「정」의', 1),
#  ('「갑」은', 1),
#  ('운송물의', 1),
#  ('운송이', 1),
#  ('완료되는', 1),
#  ('각자에게', 1),
#  ('년비용:', 1),
#  ('[금액](세별도)', 1),
#  ('거래처에', 1),
#  ('판매한', 1),
#  ('상품', 1),
#  ('총금액의', 1),
#  ('5.5%로', 1),
#  ('[금액]_VAT별도', 1),
#  ('([금액]/월_VAT별도)', 1),
#  ('수행에', 1),
#  ('대가(이하', 1),
#  ('“용역비”이라', 1),
#  ('함)로', 1),
#  ('하는', 1),
#  ('경영자문', 1),
#  ('“용역”과', 1),
#  ('금액(“가산이익”)을', 1),
#  ('OOO', 1),
#  ('(기술지원', 1),
#  ('비용)', 1),
#  ('월보수료:', 1),
#  ('건축설계용역비', 1),
#  ('건축설계용역', 1),
#  ('업무(건축주', 1),
#  ('업무대행', 1),
#  ('요청사항)', 1),
#  ('(교통영향평가,', 1),
#  ('지하안전영향평가,', 1),
#  ('지질조사,', 1),
#  ('색채•사인계획)', 1),
#  ('대금', 1),
#  ('제외하고', 1),
#  ('체결후', 1),
#  ('[회사명1]', 1),
#  ('와', 1),
#  ('[회사명2].에', 1),
#  ('판매하는', 1),
#  ('매출액(공급가액)의', 1),
#  ('그러하지', 1),
#  ('아니하다.단,', 1),
#  ('직거래', 1),
#  ('BIZ', 1),
#  ('전환前', 1),
#  ('거래(‘20년도', 1),
#  ('10월', 1),
#  ('이전)거래에', 1),
#  ('영업', 1),
#  ('지원', 1),
#  ('매달', 1),
#  ('거래처로부터', 1),
#  ('상품의', 1),
#  ('대금이', 1),
#  ('수금된', 1),
#  ('날로부터', 1),
#  ('20일', 1),
#  ('수수료를', 1),
#  ('송금하며,', 1),
#  ('각자', 1),
#  ('유지보수료는', 1),
#  ('첨부1)', 1),
#  ('견적서와', 1),
#  ('2021년', 1),
#  ('2022년', 1),
#  ('이후', 1),
#  ('자동', 1),
#  ('연장되는', 1),
#  ('별도.', 1),
#  ('제품가격', 1),
#  ('건조', 1),
#  ('투입량', 1),
#  ('분쇄,', 1),
#  ('포장', 1),
#  ('생산량', 1),
#  ('계약”과', 1),
#  ('일금[금액]을', 1),
#  ('용역보수로', 1),
#  ('[금액]/년', 1),
#  ('금액(가산이익)을', 1),
#  ('“용역”', 1),
#  ('청구/지급을', 1),
#  ('청구', 1),
#  ('분기별', 1),
#  ('정산한', 1),
#  ('매월로', 1),
#  ('나누어', 1),
#  ('완전한', 1),
#  ('상호', 1),
#  ('신뢰와', 1),
#  ('성실로', 1),
#  ('협조한다.', 1),
#  (':[금액](세별도)', 1),
#  ('계약”에', 1),
#  ('대리사무보수는', 1),
#  ('목적물에', 1),
#  ...]

# %%
show_freq_by_option(df, '필수조항8')
# Out:
# 2076
# [(':', 444),
#  ('[날짜]', 367),
#  ('[금액]', 287),
#  ('지급한다.', 269),
#  ('후', 246),
#  ('이내에', 211),
#  ('한다.', 191),
#  ('지급', 164),
#  ('[요율]', 159),
#  ('“갑”은', 140),
#  ('이내', 131),
#  ('시', 129),
#  ('및', 128),
#  ('매월', 123),
#  ('수', 122),
#  ('받은', 118),
#  ('현금으로', 117),
#  ('“을”에게', 117),
#  ('중도금', 109),
#  ('[금액]을', 97),
#  ('금', 95),
#  ('계약', 95),
#  ('그', 92),
#  ('선급금을', 88),
#  ('본', 88),
#  ('금액:', 86),
#  ('선급금', 82),
#  ('잔', 81),
#  ('동시에', 78),
#  ('따라', 75),
#  ('잔금', 75),
#  ('[요율]를', 75),
#  ('월', 73),
#  ('[금액],', 73),
#  ('완료', 72),
#  ('현금', 68),
#  ('경우', 68),
#  ('있다.', 66),
#  ('발주자로부터', 61),
#  ('정한', 60),
#  ('지급할', 59),
#  ('잔금,', 58),
#  ('지불', 58),
#  ('“을”은', 57),
#  ('계약금', 55),
#  ('익월', 54),
#  ('경우에는', 54),
#  ('지불한다.', 54),
#  ('"갑"은', 54),
#  ('"을"에게', 54),
#  ('총', 53),
#  ('날로부터', 53),
#  ('[날짜]까지', 50),
#  ('대한', 48),
#  ('청구를', 48),
#  ('계약금액의', 47),
#  ('때에는', 46),
#  ('지급하여야', 46),
#  ('비고:', 46),
#  ('계약체결', 45),
#  ('또는', 45),
#  ('체결', 45),
#  ('-', 44),
#  ('[날짜]에', 43),
#  ('지불시기:', 43),
#  ('의하여', 42),
#  ('“갑”에게', 42),
#  ('하며', 41),
#  ('“을”의', 41),
#  ('대가를', 40),
#  ('지급기일:', 39),
#  ('지급방법:', 39),
#  ('검수', 39),
#  ('[백분율]', 38),
#  ('착수금', 38),
#  ('지급받은', 37),
#  ('기성금', 36),
#  ('[금액]은', 36),
#  ('금액을', 35),
#  ('청구', 34),
#  ('선급금,', 34),
#  ('“을”이', 33),
#  ('내용과', 31),
#  ('후,', 31),
#  ('1차', 31),
#  ('따른', 30),
#  ('이', 30),
#  ('용역', 30),
#  ('갑은', 28),
#  ('[금액]으로', 28),
#  ('지급하는', 28),
#  ('의한', 28),
#  ('지급하기로', 27),
#  ('비율에', 27),
#  ('이를', 27),
#  ('대하여', 27),
#  ('계', 27),
#  ('청구할', 27),
#  ('1차,', 26),
#  ('2차,', 26),
#  ('“갑”의', 26),
#  ('하며,', 26),
#  ('중도금,', 26),
#  ('지불금액:', 26),
#  ('용역비', 26),
#  ('지급비율:', 25),
#  ('지급방법', 25),
#  ('을에게', 25),
#  ('지급하고', 25),
#  ('원칙으로', 25),
#  ('같이', 25),
#  ('선금', 25),
#  ('해당', 25),
#  ('[요율][금액]', 25),
#  ('단,', 24),
#  ('날부터', 24),
#  ('다음', 24),
#  ('청구일로부터', 23),
#  ('협의하여', 23),
#  ('청구에', 23),
#  ('납품', 23),
#  ('을은', 22),
#  ('계약과', 22),
#  ('제', 22),
#  ('수수료는', 22),
#  ('완료시,', 22),
#  ('[요율],', 22),
#  ('[백분율],', 21),
#  ('한', 21),
#  ('"을"의', 21),
#  ('원사업자가', 20),
#  ('어음', 20),
#  ('중', 20),
#  ('2차', 20),
#  ('다음과', 20),
#  ('첨부하여', 20),
#  ('지급시기:', 20),
#  ('차수:', 20),
#  ('지급예정일:', 20),
#  ('있고', 20),
#  ('합계,', 19),
#  ('[기간]', 19),
#  ('대금을', 19),
#  ('갑에게', 19),
#  ('유지보수', 19),
#  ('“갑”이', 19),
#  ('잔액을', 19),
#  ('(', 19),
#  ('다만,', 19),
#  ('계약금,', 19),
#  ('[금액](부가세', 19),
#  ('([요율])', 19),
#  ('선급금은', 18),
#  ('정산한다.', 18),
#  ('을이', 18),
#  ('제1항의', 18),
#  ('보고서', 18),
#  ('매', 18),
#  ('지급하고,', 18),
#  ('수급사업자에게', 17),
#  ('금액', 17),
#  ('날', 17),
#  ('착수금으로', 17),
#  ('지불비율:', 17),
#  ('"을"이', 17),
#  ('에게', 17),
#  ('"갑"에게', 17),
#  ('[날짜]이내에', 16),
#  ('=', 16),
#  ('이후', 16),
#  ('전체', 16),
#  ('청구하여야', 16),
#  ('기준으로', 16),
#  ('단위로', 16),
#  ('‘갑’은', 16),
#  ('제작', 16),
#  ('계약시', 16),
#  ('규정에', 16),
#  ('지급하며,', 16),
#  ('지', 16),
#  ('수수료', 16),
#  ('지급은', 16),
#  ('구분:', 16),
#  ('지급회차:', 16),
#  ('“발주자”는', 16),
#  ('지급금액:', 15),
#  ('갑이', 15),
#  ('최종', 15),
#  ('약', 15),
#  ('제외한', 15),
#  ('등', 15),
#  ('지급시', 15),
#  ('"을"은', 15),
#  ('용역비를', 15),
#  ('지급일:', 15),
#  ('금액의', 15),
#  ('[요율]로', 15),
#  ('청구하고', 14),
#  ('이상', 14),
#  ('때마다', 14),
#  ('산출한', 14),
#  ('등을', 14),
#  ('홈페이지', 14),
#  ('해당하는', 14),
#  ('완료된', 14),
#  ('잔금을', 14),
#  ('용역에', 14),
#  ('나머지', 14),
#  ('계약기간', 14),
#  ('은', 14),
#  ('수급사업자는', 13),
#  ('시기에', 13),
#  ('지급기일', 13),
#  ('기성부분의', 13),
#  ('정산액', 13),
#  ('컨설팅', 13),
#  ('세금계산서', 13),
#  ('선금을', 13),
#  ('계약을', 13),
#  ('선금은', 13),
#  ('제출하고', 13),
#  ('계약에', 13),
#  ('하고', 13),
#  ('[요율]는', 13),
#  ('2회', 13),
#  ('불', 13),
#  ('말일까지', 13),
#  ('“을”', 13),
#  ('인보이스', 13),
#  ('대가로', 13),
#  ('원사업자와', 12),
#  ('있고,', 12),
#  ('선급금액', 12),
#  ('×', 12),
#  ('조정', 12),
#  ('대금의', 12),
#  ('[날짜]을', 12),
#  ('[날짜]이내', 12),
#  ('청구하고,', 12),
#  ('분할하여', 12),
#  ('총액금의', 12),
#  ('시점에서', 12),
#  ('계약의', 12),
#  ('지급을', 12),
#  ('관한', 12),
#  ('은행도', 12),
#  ('수수료의', 12),
#  ('잔금:', 12),
#  ('계좌로', 12),
#  ('청구한', 12),
#  ('항목:', 12),
#  ('별도)', 12),
#  ('지급방법(금액):', 12),
#  ('"갑"이', 12),
#  ('위', 12),
#  ('여부를', 11),
#  ('정할', 11),
#  ('체결한', 11),
#  ('[횟수]', 11),
#  ('(기성부분의', 11),
#  ('계약금액)', 11),
#  ('등에', 11),
#  ('산식에', 11),
#  ('선급금의', 11),
#  ('/', 11),
#  ('금액에', 11),
#  ('없는', 11),
#  ('확인한', 11),
#  ('3차', 11),
#  ('계약서', 11),
#  ('만기', 11),
#  ('약속어음,', 11),
#  ('별도)을', 11),
#  ('금:', 11),
#  ('부터', 11),
#  ('기준', 11),
#  ('"갑"의', 11),
#  ('“갑”', 11),
#  ('지급방법(지급시기):', 11),
#  ('정산하여', 11),
#  ('지급한다', 10),
#  ('÷', 10),
#  ('하도급', 10),
#  ('계약일로부터', 10),
#  ('대가', 10),
#  ('원사업자는', 10),
#  ('전에', 10),
#  ('수령한', 10),
#  ('[백분율]를', 10),
#  ('각', 10),
#  ('제출', 10),
#  ('세금계산서를', 10),
#  ('월별로', 10),
#  ('때', 10),
#  ('하되,', 10),
#  ('공제한', 10),
#  ('발행)', 10),
#  ('완료시', 10),
#  ('계약금으로', 10),
#  ('15일', 10),
#  ('용역비는', 10),
#  ('방법은', 10),
#  ('계약이', 10),
#  ('1회', 10),
#  ('계,', 10),
#  (')', 10),
#  ('분할', 10),
#  ('것으로', 10),
#  ('[요율])', 10),
#  ('지급방법은', 10),
#  ('청구서를', 10),
#  ('포함)', 10),
#  ('하되', 10),
#  ('잔금인', 10),
#  ('월별', 9),
#  ('청구하며,', 9),
#  ('목적물', 9),
#  ('중도금1차,', 9),
#  ('중도금2차,', 9),
#  ('사용할', 9),
#  ('일로부터', 9),
#  ('이의가', 9),
#  ('상호', 9),
#  ('수령', 9),
#  ('대가지급', 9),
#  ('청구하며', 9),
#  ('범위', 9),
#  ('공사', 9),
#  ('보고서를', 9),
#  ('의거', 9),
#  ('위하여', 9),
#  ('준용한다.', 9),
#  ('[요율]의', 9),
#  ('체결과', 9),
#  ('을', 9),
#  ('포함하여', 9),
#  ('VAT', 9),
#  ('발행', 9),
#  ('같다.', 9),
#  ('청구한다.', 9),
#  ('14일', 9),
#  ('지불일자:', 9),
#  ('추가', 9),
#  ('관련', 9),
#  ('“병”에게', 9),
#  ('종료', 9),
#  ('조건:', 9),
#  ('5일', 9),
#  ('복사기', 9),
#  ('제15조의', 9),
#  ('업무', 8),
#  ('일할', 8),
#  ('계산하여', 8),
#  ('정산', 8),
#  ('하도급대금을', 8),
#  ('모든', 8),
#  ('포함)을', 8),
#  ('일금', 8),
#  ('인수와', 8),
#  ('말일을', 8),
#  ('의', 8),
#  ('계약서에', 8),
#  ('제작단가의', 8),
#  ('‘을’에게', 8),
#  ('([금액])', 8),
#  ('제출하면', 8),
#  ('우선', 8),
#  ('하는', 8),
#  ('용역체결과', 8),
#  ('중도금을', 8),
#  ('현금입금', 8),
#  ('잔금은', 8),
#  ('아래와', 8),
#  ('할', 8),
#  ('공사감리용역', 8),
#  ('1개월', 8),
#  ('총제작비의', 8),
#  ('검사', 8),
#  ('액:', 8),
#  ('제반', 8),
#  ('공사감리업무', 8),
#  ('용역의', 8),
#  ('[금액]의', 8),
#  ('당월', 8),
#  ('지급방법(구분):', 8),
#  ('중도금:', 8),
#  ('계약금([요율]),', 8),
#  ('잔금([요율]),', 8),
#  ('승인', 8),
#  ('지급조건:', 8),
#  ('확인', 8),
#  ('분양수수료는', 8),
#  ('1심판결', 8),
#  ('2심판결', 8),
#  ('3심판결', 8),
#  ('1심판결후,', 8),
#  ('2심판결후,', 8),
#  ('3심판결후,', 8),
#  ('“공급자”가', 8),
#  ('표지에서', 7),
#  ('따름', 7),
#  ('경제상황변동', 7),
#  ('초과하지', 7),
#  ('수급사업자가', 7),
#  ('대금', 7),
#  ('정하여', 7),
#  ('개발', 7),
#  ('내에', 7),
#  ('제4조', 7),
#  ('경비료를', 7),
#  ('접수일로부터', 7),
#  ('을의', 7),
#  ('수행을', 7),
#  ('초과하는', 7),
#  ('합격', 7),
#  ('당해', 7),
#  ('갑', 7),
#  ('2조에', 7),
#  ('지급청구서를', 7),
#  ('시설주로부터', 7),
#  ('선', 7),
#  ('비용은', 7),
#  ('계약체결일로부터', 7),
#  ('당사자로', 7),
#  ('계약시,', 7),
#  (',', 7),
#  ('수수료를', 7),
#  ('지불하며', 7),
#  ('기', 7),
#  ('비', 7),
#  ('상기', 7),
#  ('세대당', 7),
#  ('필요한', 7),
#  ('기타', 7),
#  ('전월', 7),
#  ('잔금의', 7),
#  ('일', 7),
#  ('1항의', 7),
#  ('입금한다.', 7),
#  ('부담한다.', 7),
#  ('비용', 7),
#  ('각각', 7),
#  ('[금액]([요율])', 7),
#  ('경우에', 6),
#  ('전문에서', 6),
#  ('현금비율', 6),
#  ('설계변경,', 6),
#  ('상당액', 6),
#  ('수행하는', 6),
#  ('증액', 6),
#  ('있도록', 6),
#  ('후에', 6),
#  ('별도로', 6),
#  ('최종납품일', 6),
#  ('지급키로', 6),
#  ('공사의', 6),
#  ('월간', 6),
#  ('지불하여야', 6),
#  ('대해', 6),
#  ('대금은', 6),
#  ('관리용역', 6),
#  ('착수금의', 6),
#  ('개발이', 6),
#  ('납품한', 6),
#  ('목적물에', 6),
#  ('대해서', 6),
#  ('요구하는', 6),
#  ('선급금에', 6),
#  ('보증을', 6),
#  ('지급하지', 6),
#  ('한다', 6),
#  ('급', 6),
#  ('총금액,', 6),
#  ('달', 6),
#  ('연간', 6),
#  ('나누어', 6),
#  ('않은', 6),
#  ('원활한', 6),
#  ('요구할', 6),
#  ('[날짜]일', 6),
#  ('용역대금을', 6),
#  ('30일', 6),
#  ('하고,', 6),
#  ('이내)', 6),
#  ('선급금으로', 6),
#  ('즉시', 6),
#  ('1주일', 6),
#  ('별도)으로', 6),
#  ('사업을', 6),
#  ('[요율]을', 6),
#  ('[요율]에', 6),
#  ('3회', 6),
#  ('4회', 6),
#  ('선금의', 6),
#  ('중도금([요율])', 6),
#  ('1일부터', 6),
#  ('[기간][금액][요율]', 6),
#  ('금([요율])', 6),
#  ('토지', 6),
#  ('말일에', 6),
#  ('“병”은', 6),
#  ('컨설팅결과', 6),
#  ('납입', 6),
#  ('때까지', 6),
#  ('지급시기는', 6),
#  ('10일', 6),
#  ('지정된', 6),
#  ('지불금액(부가세):', 6),
#  ('지불금액(계):', 6),
#  ('보수', 6),
#  ('의해', 6),
#  ('제3조', 6),
#  ('용역료', 6),
#  ('일체의', 6),
#  ('3년차', 6),
#  ('50~70:', 6),
#  ('80:', 6),
#  ('90:', 6),
#  ('100:', 6),
#  ('110:', 6),
#  ('120:', 6),
#  ('130:', 6),
#  ('140:', 6),
#  ('하자보증금액', 6),
#  ('발생되는', 6),
#  ('디자인개발비', 6),
#  ('지급액,', 6),
#  ('노선:', 6),
#  ('기준단가(원):', 6),
#  ('지급(선금', 6),
#  ('말', 5),
#  ('해당월의', 5),
#  ('하도급계약을', 5),
#  ('어음대체결제수단', 5),
#  ('어음으로', 5),
#  ('조정받은', 5),
#  ('위탁한', 5),
#  ('지급기일은', 5),
#  ('날)부터', 5),
#  ('계약체결후', 5),
#  ('제작비의', 5),
#  ('전', 5),
#  ('까지', 5),
#  ('[일수]일', 5),
#  ('중도금(1차)', 5),
#  ('중도금(2차)', 5),
#  ('중도금(3차)', 5),
#  ('작업', 5),
#  ('후)', 5),
#  ('경비대금을', 5),
#  ('전항의', 5),
#  ('대금지급', 5),
#  ('완료와', 5),
#  ('인도', 5),
#  ('단', 5),
#  ('갑의', 5),
#  ('따른다.', 5),
#  ('않을', 5),
#  ('관련하여', 5),
#  ('내에서', 5),
#  ('일수에', 5),
#  ('계약일에', 5),
#  ('지급한다.(영수함)', 5),
#  ('법률', 5),
#  ('비율대로', 5),
#  ('받지', 5),
#  ('경우라도', 5),
#  ('과업의', 5),
#  ('당사자간', 5),
#  ('협의를', 5),
#  ('통해', 5),
#  ('국가를', 5),
#  ('법률의', 5),
#  ('현금지급)', 5),
#  ('승인과', 5),
#  ('잔액은', 5),
#  ('시에', 5),
#  ('경우,', 5),
#  ('납품과', 5),
#  ('시점은', 5),
#  ('하여야', 5),
#  ('기본설계', 5),
#  ('지급하되', 5),
#  ('없다.', 5),
#  ('별도)의', 5),
#  ('체결시', 5),
#  ('선금급', 5),
#  ('([날짜])', 5),
#  ('없이', 5),
#  ('“위탁자”는', 5),
#  ('경비료는', 5),
#  ('동시', 5),
#  ('지불하고', 5),
#  ('중도금으로', 5),
#  ('(사용검사필증', 5),
#  ('고', 5),
#  ('지불하며,', 5),
#  ('1일', 5),
#  ('현재', 5),
#  ('말일', 5),
#  ('내', 5),
#  ('직후', 5),
#  ('[요율]([금액])를', 5),
#  ('비용의', 5),
#  ('다.', 5),
#  ('용역금액은', 5),
#  ('지급일자는', 5),
#  ('"갑"', 5),
#  ('＼', 5),
#  ('일괄', 5),
#  ('"갑"과', 5),
#  ('말까지', 5),
#  ('4차', 5),
#  ('금액은', 5),
#  ('마감하여', 5),
#  ('받은지', 5),
#  ('용역비의', 5),
#  ('분양수수료의', 5),
#  ('O일', 5),
#  ('지불금액(공급가액):', 5),
#  ('25일', 5),
#  ('계약금액', 5),
#  ('체결일로부터', 5),
#  ('발행:', 5),
#  ('기술', 5),
#  ('[요율]인', 5),
#  ('입금', 5),
#  ('(부가세', 5),
#  ('착수금:', 5),
#  ('착수일로부터', 5),
#  ('최종시안', 5),
#  ('결정', 5),
#  ('최종인도물', 5),
#  ('보수잔금', 5),
#  ('운영', 5),
#  ('사업주체는', 5),
#  ('감리자에게', 5),
#  ('(단,', 5),
#  ('없을', 5),
#  ('인지대,', 5),
#  ('시는', 5),
#  ('그에', 5),
#  ('은행', 5),
#  ('계약종료', 5),
#  ('지정하는', 5),
#  ('지급하도록', 5),
#  ('종료한', 5),
#  ('완료일로부터', 5),
#  ('기준기한:', 5),
#  ('[요율][금액]를', 5),
#  ('“계약상대자”는', 5),
#  ('음식물류폐기물', 4),
#  ('.', 4),
#  ('선금,', 4),
#  ('중도금(지급횟수:', 4),
#  ('[횟수]),', 4),
#  ('인수일부터', 4),
#  ('어음의', 4),
#  ('이내의', 4),
#  ('대가상당액', 4),
#  ('기성부분금', 4),
#  ('대금조정', 4),
#  ('지급.', 4),
#  ('않는', 4),
#  ('대하여는', 4),
#  ('위탁하기', 4),
#  ('날)로부터', 4),
#  ('증액한', 4),
#  ('하도급대금의', 4),
#  ('지급받는', 4),
#  ('계산한다.', 4),
#  ('[백분율]에', 4),
#  ('서비스', 4),
#  ('총액의', 4),
#  ('구축', 4),
#  ('[금액]([날짜]', 4),
#  ('별도', 4),
#  ('[날짜]일이내', 4),
#  ('준공', 4),
#  ('부가세', 4),
#  ('1차:', 4),
#  ('지급)', 4),
#  ('용역계약체결과', 4),
#  ('현금지불한다.', 4),
#  ('공장입지조사', 4),
#  ('중간보고를', 4),
#  ('함과', 4),
#  ('작업을', 4),
#  ('비용을', 4),
#  ('총계약금액의', 4),
#  ('도', 4),
#  ('월정액으로', 4),
#  ('경과한', 4),
#  ('체결후', 4),
#  ('중도금의', 4),
#  ('잔금금의', 4),
#  ('사업완료', 4),
#  ('DB구축', 4),
#  ('공공근로인력의', 4),
#  ('철수일과', 4),
#  ('에', 4),
#  ('초과기간에', 4),
#  ('이자를', 4),
#  ('사용하도록', 4),
#  ('수행', 4),
#  ('수행한', 4),
#  ('지급한', 4),
#  ('없으며,', 4),
#  ('노임지급', 4),
#  ('자재확보에', 4),
#  ('같은', 4),
#  ('운영비를', 4),
#  ('예산', 4),
#  ('바에', 4),
#  ('제출을', 4),
#  ('제출하여야', 4),
#  ('제8조를', 4),
#  ('외국인', 4),
#  ('투자', 4),
#  ('인허가', 4),
#  ('(갑)은', 4),
#  ('[금액]원', 4),
#  ('합의에', 4),
#  ('제1항에', 4),
#  ('계약금:', 4),
#  ('선금*,', 4),
#  ('중도금(지급회수:', 4),
#  ('회),', 4),
#  ('제출한', 4),
#  ('초과하여', 4),
#  ('제13조', 4),
#  ('([날짜]', 4),
#  ('월의', 4),
#  ('검수완료', 4),
#  ('검사를', 4),
#  ('첨부', 4),
#  ('확정하여', 4),
#  ('각호의', 4),
#  ('[백분율][금액]', 4),
#  ('완료한', 4),
#  ('절차에', 4),
#  ('있으며,', 4),
#  ('타', 4),
#  ('다음의', 4),
#  ('대금지급은', 4),
#  (')를', 4),
#  ('운영에', 4),
#  ('매월말', 4),
#  ('전액', 4),
#  ('[요율]현금', 4),
#  ('용역비중', 4),
#  ('사업', 4),
#  ('지불키로', 4),
#  ('추천한', 4),
#  ('회사와', 4),
#  ('체결되었을', 4),
#  ('체결된', 4),
#  ('([날짜]):', 4),
#  ('제출시', 4),
#  ('기준으로하여', 4),
#  ('청구서는', 4),
#  ('조건에', 4),
#  ('사항은', 4),
#  ('제7조', 4),
#  ('(부가가치세', 4),
#  ('계약금([요율])', 4),
#  ('용역경비료를', 4),
#  ('지불시기:,', 4),
#  ('지급토록', 4),
#  ('1차중도금,', 4),
#  ('2차중도금,', 4),
#  ('평당', 4),
#  ('계약한', 4),
#  ('만원이하:', 4),
#  ('매입대금의', 4),
#  ('협의', 4),
#  ('지급:', 4),
#  ('합의', 4),
#  ('지급율(%):', 4),
#  ('[요율]내외', 4),
#  ('지급액(천원):', 4),
#  ('대당', 4),
#  ('액', 4),
#  ('5차', 4),
#  ('6차', 4),
#  ('7차', 4),
#  ('8차', 4),
#  ('제2항의', 4),
#  ('증빙자료를', 4),
#  ('1', 4),
#  ('증빙서류를', 4),
#  ('보조금', 4),
#  ('총제작비', 4),
#  ('분양될', 4),
#  ('유보하며', 4),
#  ('전체빌라가', 4),
#  ('분양되지', 4),
#  ('귀속한다.', 4),
#  ('세대', 4),
#  ('당', 4),
#  ('것을', 4),
#  ('매달', 4),
#  ('계약금액을', 4),
#  ('원', 4),
#  ('계약서,', 4),
#  ('건축자문', 4),
#  ('건축허가', 4),
#  ('실시설계도서', 4),
#  ('‘갑’의', 4),
#  ('사용승인', 4),
#  ('기준에', 4),
#  ('“乙”에게', 4),
#  ('부가가치세는', 4),
#  ('규정된', 4),
#  ('시점:', 4),
#  ('잔금으로', 4),
#  ('용', 4),
#  ('작성하여', 4),
#  ('"기술용역계약일반조건"', 4),
#  ('이전과', 4),
#  ('지불은', 4),
#  ('하여', 4),
#  ('5일까지', 4),
#  ('원천징수', 4),
#  ('[금액](계약금의', 4),
#  ('교부후)', 4),
#  ('지급한다.)', 4),
#  ('용역대금의', 4),
#  ('청구금액을', 4),
#  ('확인하여', 4),
#  ('금,', 4),
#  ('소송', 4),
#  ('감정료', 4),
#  ('납부', 4),
#  ('Identity', 4),
#  ('Program', 4),
#  ('50%', 4),
#  ('함께', 4),
#  ('말일로', 4),
#  ('은행계좌에', 4),
#  ('수익금액의', 4),
#  ('용역비:', 4),
#  ('1항', 4),
#  ('[금액][요율]', 4),
#  ('“계약상대자”가', 4),
#  ('착수보고서를', 4),
#  ('제14조에', 4),
#  ('“발주자”의', 4),
#  ('“[금액](부가세', 4),
#  ('별도),', 4),
#  ('입금일', 4),
#  ('10일까지', 4),
#  ('계약된', 4),
#  ('금액에서', 4),
#  ('지체', 4),
#  ('OOO에', 4),
#  ('수탁처리비를', 3),
#  ('조정할', 3),
#  ('지급,', 3),
#  ('수령일로부터', 3),
#  ('인수일로부터', 3),
#  ('지급기간을', 3),
#  ('교부', 3),
#  ('일을', 3),
#  ('과정에서', 3),
#  ('초기에', 3),
#  ('비용소요가', 3),
#  ('예상되는', 3),
#  ('사용분야,', 3),
#  ('수급사업자와', 3),
#  ('정한다.', 3),
#  ('로부터', 3),
#  ('아니한다.', 3),
#  ('착수할', 3),
#  ('등의', 3),
#  ('일시불로', 3),
#  ('관리비', 3),
#  ('공정의', 3),
#  ('진척시', 3),
#  ('(잔금)', 3),
#  ('청소용역비', 3),
#  ('호와', 3),
#  ('발행하여', 3),
#  ('계약일', 3),
#  ('있어서', 3),
#  ('선지급하고', 3),
#  ('별도의', 3),
#  ('결정하며', 3),
#  ('사전', 3),
#  ('설치', 3),
#  ('명시한', 3),
#  ('지출한다.', 3),
#  ('계약일이', 3),
#  ('지급액수(VAT별도),', 3),
#  ('[날짜]:', 3),
#  ('종료시)', 3),
#  ('검수후', 3),
#  ('공정거래위원회가', 3),
#  ('고시하는', 3),
#  ('외의', 3),
#  ('하지', 3),
#  ('기성금을', 3),
#  ('부분에', 3),
#  ('지급기일이', 3),
#  ('도래하는', 3),
#  ('계약에서', 3),
#  ('방법으로', 3),
#  ('2차:', 3),
#  ('지급하되,', 3),
#  ('불가피한', 3),
#  ('사유로', 3),
#  ('인하여', 3),
#  ('가산하여', 3),
#  ('검토서', 3),
#  ('[금액])', 3),
#  ('하도급거래공정화에', 3),
#  ('(계약', 3),
#  ('중도금([백분율])', 3),
#  ('일부인', 3),
#  ('(을)에게', 3),
#  ('마케팅', 3),
#  ('동', 3),
#  ('이하', 3),
#  ('보수의', 3),
#  ('전조', 3),
#  ('분할지급하기로', 3),
#  ('이상인', 3),
#  ('업무를', 3),
#  ('동일한', 3),
#  ('수급사업자의', 3),
#  ('제1항에서', 3),
#  ('관하여는', 3),
#  ('하도급법', 3),
#  ('본다.', 3),
#  ('시점', 3),
#  ('결재하여야', 3),
#  ('3개월', 3),
#  ('[날짜],', 3),
#  ('계약상대자는', 3),
#  ('완료하는', 3),
#  ('제출할', 3),
#  ('대가의', 3),
#  ('회', 3),
#  ('규정은', 3),
#  ('관하여', 3),
#  ('제출한다.', 3),
#  ('(당해기성금', 3),
#  ('총계약금액)', 3),
#  ('계약목적', 3),
#  ('지불시기', 3),
#  ('실시설계', 3),
#  ('(착공신고용)', 3),
#  ('정기점검', 3),
#  ('월정', 3),
#  ('용역수행결과에', 3),
#  ('흠결이', 3),
#  ('없음을', 3),
#  ('미만의', 3),
#  ('범위내에서', 3),
#  ('총제작비([금액],', 3),
#  ('호스팅', 3),
#  ('검사완료', 3),
#  ('발행일로부터', 3),
#  ('잔금[요율]를', 3),
#  ('제작에', 3),
#  ('현재로', 3),
#  ('투입한', 3),
#  ('인원을', 3),
#  ('집계', 3),
#  ('당월분의', 3),
#  ('작업비를', 3),
#  ('산출하고', 3),
#  ('직영부분', 3),
#  ('임금', 3),
#  ('지급일에', 3),
#  ('부담하며', 3),
#  ('영수한', 3),
#  ('착수하여야', 3),
#  ('측량설계를', 3),
#  ('완성한', 3),
#  ('후에는', 3),
#  ('설계도서를', 3),
#  ('납품하고', 3),
#  ('청구키로', 3),
#  ('납품품목을', 3),
#  ('체결시에', 3),
#  ('걸쳐', 3),
#  ('심의', 3),
#  ('연구비의', 3),
#  ('보수는', 3),
#  ('[선급금]보증보험증권', 3),
#  ('용역게약시,', 3),
#  ('기본설계(인·허가신청용)인도시,', 3),
#  ('실시설계(착공신고용)인도시,', 3),
#  ('시공사', 3),
#  ('별첨', 3),
#  ('다음달', 3),
#  ('첫', 3),
#  ('미분양', 3),
#  ('별첨과', 3),
#  ...]

# %%
show_freq_by_option(df, '필수조항4')
# Out:
# 1258
# [('경우', 387),
#  ('때에는', 366),
#  ('수', 299),
#  ('지체일수에', 296),
#  ('또는', 289),
#  ('경우에는', 265),
#  ('정한', 259),
#  ('지체상금을', 248),
#  ('한다.', 239),
#  ('그', 217),
#  ('한', 205),
#  ('규정에', 202),
#  ('의한', 199),
#  ('있다.', 179),
#  ('금액을', 166),
#  ('제1항의', 164),
#  ('대한', 162),
#  ('산입한다.', 152),
#  ('내에', 145),
#  ('계약금액의', 144),
#  ('의하여', 142),
#  ('기간을', 137),
#  ('매', 137),
#  ('합격한', 132),
#  ('해당하는', 131),
#  ('다음', 124),
#  ('따라', 123),
#  ('검사에', 120),
#  ('날까지의', 117),
#  ('다만,', 116),
#  ('있는', 115),
#  ('이', 113),
#  ('납부하여야', 104),
#  ('한한다.', 101),
#  ('대하여', 99),
#  ('아니한다.', 98),
#  ('산입하지', 93),
#  ('상당하는', 90),
#  ('할', 90),
#  ('기타', 86),
#  ('기간은', 86),
#  ('시정조치를', 85),
#  ('이하', 82),
#  ('인하여', 82),
#  ('용역목적물', 82),
#  ('용역완료보고서를', 82),
#  ('1,000분의', 82),
#  ('경우를', 81),
#  ('계약서에', 81),
#  ('날부터', 80),
#  ('부분에', 77),
#  (':', 77),
#  ('현금으로', 75),
#  ('제출한', 74),
#  ('곱하여', 73),
#  ('익일부터', 72),
#  ('소요된', 70),
#  ('못한', 69),
#  ('사유로', 69),
#  ('공제한다.', 69),
#  ('용역수행기한', 69),
#  ('지체일수', 68),
#  ('용역을', 68),
#  ('아니한', 67),
#  ('계약금액에서', 66),
#  ('산출한', 66),
#  ('2.5', 66),
#  ('성질상', 65),
#  ('“갑”은', 65),
#  ('각', 64),
#  ('경우에', 64),
#  ('경우,', 63),
#  ('금액(이하', 63),
#  ('인수는', 62),
#  ('인수하는', 62),
#  ('1000분의', 62),
#  ('지체일수마다', 61),
#  ('따른', 60),
#  ('이를', 59),
#  ('것에', 59),
#  ('경과하여', 59),
#  ('완성하지', 59),
#  ('지급하여야', 57),
#  ('지체', 57),
#  ('분할할', 56),
#  ('최종', 56),
#  ('“을”은', 55),
#  ('1일당', 55),
#  ('원사업자는', 53),
#  ('지체일수를', 52),
#  ('및', 51),
#  ('완료하지', 51),
#  ('상계할', 50),
#  ('“을”이', 48),
#  ('기성부분의', 48),
#  ('이후에', 48),
#  ('초과한', 48),
#  ('계약서에서', 47),
#  ('"갑"에게', 47),
#  ('아니하고', 46),
#  ('계약기간', 46),
#  ('공제할', 46),
#  ('기간에', 46),
#  ('기간', 45),
#  ('“지체상금”이라', 45),
#  ('을', 45),
#  ('거쳐', 44),
#  ('동조에', 44),
#  ('수급사업자의', 43),
#  ('최종검사에', 43),
#  ('“갑”에게', 43),
#  ('내지', 43),
#  ('한다)을', 43),
#  ('대가,', 43),
#  ('포함한다.', 42),
#  ('기준으로', 42),
#  ('등으로', 42),
#  ('완성부분으로', 42),
#  ('계약', 42),
#  ('1일에', 42),
#  ('수급사업자가', 41),
#  ('곱한', 41),
#  ('기성부분에', 41),
#  ('각호에', 41),
#  ('산출된', 41),
#  ('이자', 41),
#  ('검사를', 40),
#  ('원사업자가', 40),
#  ('용역에', 40),
#  ('지체일수는', 40),
#  ('“을”에게', 40),
#  ('지급될', 40),
#  ('호의', 39),
#  ('부도', 39),
#  ('지체된', 38),
#  ('용역수행기한내에', 38),
#  ('제3항의', 37),
#  ('보증이행을', 37),
#  ('등', 37),
#  ('지체상금율을', 37),
#  ('기간(검사기간이', 37),
#  ('제1항', 37),
#  ('대가지급지연에', 37),
#  ('계약금액에', 36),
#  ('공제한', 35),
#  ('같다)을', 35),
#  ('검사(시정조치를', 35),
#  ('다음날부터', 34),
#  ('총', 34),
#  ('용역수행기한의', 34),
#  ('말일이', 34),
#  ('공휴일(관련', 34),
#  ('익일', 34),
#  ('기한', 33),
#  ('산정하여야', 33),
#  ('공휴일의', 33),
#  ('중단된', 32),
#  ('없는', 32),
#  ('용역수행기한을', 32),
#  ('예치금', 32),
#  ('다만', 31),
#  ('을이', 31),
#  ('일수에', 31),
#  ('인수(인수하지', 31),
#  ('이조에서', 31),
#  ('지체상금율', 31),
#  ('용역수행기간', 31),
#  ('청구할', 30),
#  ('수정요구를', 30),
#  ('최종검사)에', 30),
#  ('에', 30),
#  ('계약상대자는', 30),
#  ('계약담당공무원은', 30),
#  ('등과', 30),
#  ('제1항에', 30),
#  ('완료한', 29),
#  ('전부', 29),
#  ('못하였을', 29),
#  ('지체상금은', 29),
#  ('정당한', 29),
#  ('“을”의', 29),
#  ('동', 29),
#  ('검사)에', 29),
#  ('“갑”의', 28),
#  ('날로부터', 28),
#  ('시', 28),
#  ('천재지변', 28),
#  ('계약담당직원은', 28),
#  ('"을"은', 28),
#  ('발주기관의', 28),
#  ('기산한다.', 28),
#  ('어느', 27),
#  ('하나에', 27),
#  ('위탁', 27),
#  ('지연되거나', 27),
#  ('귀책사유로', 27),
#  ('대해서는', 27),
#  ('그에', 27),
#  ('날', 27),
#  ('2.5에', 27),
#  ('인수한', 26),
#  ('대금에서', 26),
#  ('납품을', 26),
#  ('일괄하여', 26),
#  ('월', 26),
#  ('"을"에게', 26),
#  ('초과하는', 26),
#  ('목적물을', 25),
#  ('기성부분', 25),
#  ('해당', 25),
#  ('불가항력의', 25),
#  ('책임으로', 25),
#  ('지급할', 25),
#  ('까지의', 25),
#  ('소프트웨어', 25),
#  ('그러하지', 24),
#  ('계산한다.', 24),
#  ('사유에', 24),
#  ('이내에', 24),
#  ('지연일수', 24),
#  ('1항', 24),
#  ('하는', 24),
#  ('관리․사용하고', 24),
#  ('포함한다)인', 24),
#  ('등이', 23),
#  ('지체일수의', 23),
#  ('제1호', 23),
#  ('본', 23),
#  ('후', 23),
#  ('같다)한', 23),
#  ('제20조의', 23),
#  ('제3항제5호에', 23),
#  ('과업내용을', 23),
#  ('조정하고자', 23),
#  ('휴무일인', 23),
#  ('1.', 23),
#  ('발생한', 22),
#  ('산정기준은', 22),
#  ('제3조', 22),
#  ('제', 22),
#  ('지', 22),
#  ('법령에', 22),
#  ('같다.', 21),
#  ('이후', 21),
#  ('제조가', 21),
#  ('을의', 21),
#  ('없이', 21),
#  ('기성부분을', 21),
#  ('단,', 21),
#  ('제20조에', 21),
#  ('1일', 20),
#  ('일부가', 20),
#  ('제5항에', 20),
#  ('제5항의', 20),
#  ('지불한다.', 20),
#  ('사유', 20),
#  ('이외의', 20),
#  ('"갑"은', 20),
#  ('소요기간을', 20),
#  ('모두', 20),
#  ('22.', 20),
#  ('[천분율]', 19),
#  ('지시한', 19),
#  ('지정하여', 19),
#  ('접수한', 19),
#  ('지급한다.', 19),
#  ('하도급대금에서', 19),
#  ('납기', 19),
#  ('등의', 19),
#  ('때', 19),
#  ('"을"이', 19),
#  ('“갑”이', 19),
#  ('"을"의', 19),
#  ('계약금액을', 19),
#  ('연대보증인이', 18),
#  ('날까지를', 18),
#  ('보증기관이', 18),
#  ('보증이행업체를', 18),
#  ('보증채무이행청구서를', 18),
#  ('보증이행개시일', 18),
#  ('책임', 18),
#  ('납품한', 18),
#  ('용역', 18),
#  ('계약에', 18),
#  ('업무를', 18),
#  ('못할', 18),
#  ('의', 18),
#  ('마다', 18),
#  ('경우:', 18),
#  ('지체상금율에', 18),
#  ('아니하다.', 17),
#  ('원사업자의', 17),
#  ('착수가', 17),
#  ('경우(부도', 17),
#  ('확정된', 17),
#  ('수급사업자에게', 17),
#  ('한다)', 17),
#  ('지체상금', 17),
#  ('갑은', 17),
#  ('0.25%', 17),
#  ('계약상대자에게', 17),
#  ('디자인', 17),
#  ('산정하고,', 17),
#  ('납품하지', 16),
#  ('일수를', 16),
#  ('전일까지를', 16),
#  ('보수를', 16),
#  ('지체되었다고', 16),
#  ('각호의', 16),
#  ('계약기간을', 16),
#  ('설계와', 16),
#  ('설계에', 16),
#  ('지체상금으로', 16),
#  ('연장될', 16),
#  ('"지체상금"이라', 16),
#  ('계약담당자는', 16),
#  ('연차별', 16),
#  ('계약금액)에', 16),
#  ('매1일에', 16),
#  ('2016.', 16),
#  ('개정)', 16),
#  ('고의', 15),
#  ('완성부분으로서', 15),
#  ('단서에', 15),
#  ('[백분율]', 15),
#  ('용역수행', 15),
#  ('검사(수정요구를', 15),
#  ('제조', 15),
#  ('제2항의', 15),
#  ('규정을', 15),
#  ('금액의', 15),
#  ('있을', 15),
#  ('계약이행기간이', 15),
#  ('물품과', 15),
#  ('부치는', 15),
#  ('사유없이', 15),
#  ('일수마다', 15),
#  ('지체상금율:', 15),
#  ('1.5', 15),
#  ('10.', 15),
#  ('당', 14),
#  ('보증이행할', 14),
#  ('경우(원사업자로부터', 14),
#  ('않는다.', 14),
#  ('용역수행기간을', 14),
#  ('공사의', 14),
#  ('필요한', 14),
#  ('제4항의', 14),
#  ('불가항력적인', 14),
#  ('책임이', 14),
#  ('"갑"의', 14),
#  ('계약상의', 14),
#  ('1', 14),
#  ('제출하지', 14),
#  ('"갑"이', 14),
#  ('부과할', 14),
#  ('대해', 13),
#  ('합격하지', 13),
#  ('지체상금요율을', 13),
#  ('산정한', 13),
#  ('의미함,', 13),
#  ('요구한', 13),
#  ('홍수,', 13),
#  ('폭동,', 13),
#  ('시행령', 13),
#  ('갑에게', 13),
#  ('지체한', 13),
#  ('결과물을', 13),
#  ('<신설', 13),
#  ('제20조제3항에', 13),
#  ('용', 13),
#  ('역수행기한', 13),
#  ('2.5/1,000', 13),
#  ('않거나', 12),
#  ('조에서', 12),
#  ('의미함)', 12),
#  ('[날짜]', 12),
#  ('한함)', 12),
#  ('의한다.', 12),
#  ('납품기한', 12),
#  ('도과하여', 12),
#  ('전쟁', 12),
#  ('않는', 12),
#  ('위반되거나', 12),
#  ('공사를', 12),
#  ('인한', 12),
#  ('발주한', 12),
#  ('납기를', 12),
#  ('상당한', 12),
#  ('계약금액', 12),
#  ('부과하여야', 12),
#  ('발생한다.', 12),
#  ('을은', 12),
#  ('물품에', 12),
#  ('이루어지고,', 12),
#  ('장의', 12),
#  ('승인이', 12),
#  ('외의', 12),
#  ('한다.)을', 12),
#  ('부득이한', 12),
#  ('3에', 12),
#  ('기간내에', 12),
#  ('2011.5.13.>', 12),
#  ('사업시', 12),
#  ('법령의', 12),
#  ('“계약상대자”에게', 12),
#  ('“발주자”는', 12),
#  ('지체일당', 11),
#  ('인해', 11),
#  ('업무가', 11),
#  ('검사결과(불합격판정에', 11),
#  ('한한다)에', 11),
#  ('지진', 11),
#  ('해당되어', 11),
#  ('책임에', 11),
#  ('속하지', 11),
#  ('1과', 11),
#  ('지급하지', 11),
#  ('초과할', 11),
#  ('용역수', 11),
#  ('행기한', 11),
#  ('계약의', 11),
#  ('기간이', 11),
#  ('지연', 11),
#  ('2.5/1000에', 11),
#  ('/', 11),
#  ('통지한다.', 11),
#  ('제22조에', 11),
#  ('납부할', 11),
#  ('적용한다.', 11),
#  ('하여', 11),
#  ('포', 11),
#  ('호와', 11),
#  ('협력단은', 11),
#  ('이행하지', 10),
#  ('계산하여', 10),
#  ('이로', 10),
#  ('손해에', 10),
#  ('해당한', 10),
#  ('납품기한의', 10),
#  ('1에', 10),
#  ('인정할', 10),
#  ('해당일수를', 10),
#  ('검사', 10),
#  ('아닌', 10),
#  ('이행이', 10),
#  ('계약이행', 10),
#  ('목적물의', 10),
#  ('일부를', 10),
#  ('전쟁,', 10),
#  ('소요되는', 10),
#  ('[천분율]에', 10),
#  ('지체상환금을', 10),
#  ('지연되었을', 10),
#  ('경우는', 10),
#  ('때는', 10),
#  ('에게', 10),
#  ('지불하여야', 10),
#  ('명시된', 10),
#  ('제18조에', 10),
#  ('수행하지', 10),
#  ('약정기간', 10),
#  ('계약관은', 10),
#  ('초과하여', 10),
#  ('물품계약의', 10),
#  ('성질에', 10),
#  ('에는', 10),
#  ('것을', 10),
#  ('함한다)인', 10),
#  ('배상을', 9),
#  ('증명한', 9),
#  ('경우(인수하지', 9),
#  ('관리ㆍ사용하고', 9),
#  ('같다)에는', 9),
#  ('기납부분의', 9),
#  ('업무의', 9),
#  ('납품기한을', 9),
#  ('검사가', 9),
#  ('끝난', 9),
#  ('내용의', 9),
#  ('을에게', 9),
#  ('계약기간내에', 9),
#  ('갑의', 9),
#  ('적용하는', 9),
#  ('대해서', 9),
#  ('사유가', 9),
#  ('당해', 9),
#  ('불구하고', 9),
#  ('분할', 9),
#  ('지불할', 9),
#  ('배상하여야', 9),
#  ('제20조', 9),
#  ('하며', 9),
#  ('불가항력적', 9),
#  ('차감', 9),
#  ('초과', 9),
#  ('시간당', 9),
#  ('“갑”과', 9),
#  ('검사(사정조치를', 9),
#  ('완성하', 9),
#  ('여', 9),
#  ('곱', 9),
#  ('5.', 9),
#  ('요구할', 9),
#  ('사업에', 9),
#  ('지체상금율은', 9),
#  ('제19조에', 9),
#  ('표지에서', 8),
#  ('기납부분에', 8),
#  ('목적물에', 8),
#  ('전문에서', 8),
#  ('수행을', 8),
#  ('부당함에', 8),
#  ('항만봉쇄,', 8),
#  ('있어', 8),
#  ('정하여', 8),
#  ('지급을', 8),
#  ('지체일수에서', 8),
#  ('예치금에서', 8),
#  ('된', 8),
#  ('없음이', 8),
#  ('위반했을', 8),
#  ('수정,', 8),
#  ('보완', 8),
#  ('지체되는', 8),
#  ('하며,', 8),
#  ('입찰에', 8),
#  ('중앙관서의', 8),
#  ('제22조의', 8),
#  ('대가의', 8),
#  ('제16조의', 8),
#  ('계약을', 8),
#  ('지체없이', 8),
#  ('사전', 8),
#  ('승인을', 8),
#  ('계약금의', 8),
#  ('유지보수', 8),
#  ('용역비의', 8),
#  ('○%', 8),
#  ('금액', 8),
#  ('○○에', 8),
#  ('같다.)한', 8),
#  ('산정하여야한다.', 8),
#  ('제출한때에는', 8),
#  ('휴', 8),
#  ('무일인', 8),
#  ('기타예치금등과', 8),
#  ('“계약상대자”가', 8),
#  ('(2016.', 8),
#  ('신설)', 8),
#  ('(2007.', 8),
#  ('15.,', 8),
#  ('완성검사를', 8),
#  ('요청한', 8),
#  ('30.,', 8),
#  ('제23조', 8),
#  ('과실없음을', 7),
#  ('납품기한내에', 7),
#  ('실제납품한', 7),
#  ('용역수행을', 7),
#  ('공사가', 7),
#  ('인정될', 7),
#  ('지진,', 7),
#  ('공급이', 7),
#  ('불가능하였을', 7),
#  ('착공이', 7),
#  ('준공기한', 7),
#  ('공사목적물을', 7),
#  ('따른다.', 7),
#  ('원칙으로', 7),
#  ('위탁에', 7),
#  ('납품이', 7),
#  ('기한을', 7),
#  ('지급', 7),
#  ('이에', 7),
#  ('없다.', 7),
#  ('재제작함으로', 7),
#  ('미납품분에', 7),
#  ('지연사유가', 7),
#  ('총액의', 7),
#  ('.', 7),
#  ('지체상금이', 7),
#  ('경우로서', 7),
#  ('용역의', 7),
#  ('기한내에', 7),
#  ('관리,', 7),
#  ('사용하고', 7),
#  ('내', 7),
#  ('상계', 7),
#  ('‘을’이', 7),
#  ('적용하지', 7),
#  ('대가에서', 7),
#  ('특별한', 7),
#  ('원인으로', 7),
#  ('제작비의', 7),
#  ('지체상금으로서', 7),
#  ('즉시', 7),
#  ('현금', 7),
#  ('하지', 7),
#  ('설계업무를', 7),
#  ('완료할', 7),
#  ('명백한', 7),
#  ('시간', 7),
#  ('사실을', 7),
#  ('약정한', 7),
#  ('입찰', 7),
#  ('16조의', 7),
#  ('제16조제3항의', 7),
#  ('제6항의', 7),
#  ('제2조에서', 7),
#  ('현', 7),
#  ('금으로', 7),
#  ('<개정', 7),
#  ('인', 7),
#  ('[날짜]이내에', 6),
#  ('대금의', 6),
#  ('규정된', 6),
#  ('원사업자에게', 6),
#  ('완성부분을', 6),
#  ('태풍,', 6),
#  ('악천후,', 6),
#  ('사변,', 6),
#  ('방역', 6),
#  ('보안상', 6),
#  ('출입제한', 6),
#  ('지연되어', 6),
#  ('시공이', 6),
#  ('공사진행이', 6),
#  ('한한다)', 6),
#  ('밖에', 6),
#  ('인도한', 6),
#  ('검사시', 6),
#  ('지연배상액(이하', 6),
#  ('하도급대금의', 6),
#  ('금액으로', 6),
#  ('제조의', 6),
#  ('다음과', 6),
#  ('계약에서', 6),
#  ('해당되는', 6),
#  ('천재지변,', 6),
#  ('귀책사유가', 6),
#  ('없음)', 6),
#  ('기술용역을', 6),
#  ('제20조제3항의', 6),
#  ('대하여는', 6),
#  ('아니된다.', 6),
#  ('돌릴', 6),
#  ('대가지급', 6),
#  ('해당일수에', 6),
#  ('제23조의', 6),
#  ('계약기간이', 6),
#  ('용역금액의', 6),
#  ('금액에서', 6),
#  ('발생하였을', 6),
#  ('터', 6),
#  ('이상', 6),
#  ('사고', 6),
#  ('1/1000에', 6),
#  ('1의', 6),
#  ('1000의', 6),
#  ('지체일', 6),
#  ('의무를', 6),
#  ('유지보수료의', 6),
#  ('본다.', 6),
#  ('의거', 6),
#  ('납품', 6),
#  ('것으로', 6),
#  ('보수의', 6),
#  ('3/1000에', 6),
#  ('○○○분의', 6),
#  ('지체상금률을', 6),
#  ('“00', 6),
#  ('수요자는', 6),
#  ('공급자의', 6),
#  ('호에', 6),
#  ('중', 6),
#  ('용역비에서', 6),
#  ('발주자의', 6),
#  ('상', 6),
#  ('같다)', 6),
#  ('기', 6),
#  ('급될', 6),
#  ('제16조제3항에', 6),
#  ('각목을', 6),
#  ('산정하', 6),
#  ('있', 6),
#  ('다.', 6),
#  ('2015.1.1.>', 6),
#  ('2.5%', 6),
#  ('제21조에', 6),
#  ('수(인수하지', 6),
#  ('`99.11.4>', 6),
#  ('제21조의', 6),
#  ('(검사기간이', 6),
#  ('당공사의', 6),
#  ('상계처리', 5),
#  ('하도급', 5),
#  ('지체상금율과', 5),
#  ('연장된', 5),
#  ('의미한다)', 5),
#  ('의미한다.', 5),
#  ('이행되지', 5),
#  ('같이', 5),
#  ('산정한다.', 5),
#  ('기본계약', 5),
#  ('계산하여야', 5),
#  ('갑이', 5),
#  ('화재,', 5),
#  ('합의', 5),
#  ('아니', 5),
#  ('초과하지', 5),
#  ('지체배상금을', 5),
#  ('지연에', 5),
#  ('제18조의', 5),
#  ('제3항에', 5),
#  ('를', 5),
#  ('제25조의', 5),
#  ('귀책사유나', 5),
#  ('태만으로', 5),
#  ('경과', 5),
#  ('(단,', 5),
#  ('과실로', 5),
#  ('납기지연이', 5),
#  ('않은', 5),
#  ('이행을', 5),
#  ('당월', 5),
#  ('처리한다.', 5),
#  ('[요율]', 5),
#  ('하여야', 5),
#  ('의해', 5),
#  ('경', 5),
#  ('약정기간내에', 5),
#  ('중에서', 5),
#  ('(', 5),
#  ('지체보상금을', 5),
#  ('공제', 5),
#  ('유지', 5),
#  ('이미', 5),
#  ('5조', 5),
#  ('대금', 5),
#  ('검수', 5),
#  ('보수에서', 5),
#  ('용역료', 5),
#  ('우선', 5),
#  ('준용한', 5),
#  ('지체보상금의', 5),
#  ('결제할', 5),
#  ('대신에', 5),
#  ('수정에', 5),
#  ('면제할', 5),
#  ('공급자가', 5),
#  ('개발”을', 5),
#  ('(2)/1000을', 5),
#  ('공급자에게', 5),
#  ('1일마다', 5),
#  ('공제하고', 5),
#  ('매지체', 5),
#  ('제출할', 5),
#  ('협의하여', 5),
#  ('금액(이하“지체상금”이라', 5),
#  ('2.5/1000', 5),
#  ('간을', 5),
#  ('대하', 5),
#  ('면제한다.', 5),
#  ('“발주자”에게', 5),
#  ('계약금액(장기계속용역계약의', 5),
#  ('산', 5),
#  ('아', 5),
#  ('제3항', 5),
#  ('발주자는', 5),
#  ('계약금액(장기계속', 5),
#  ('용역계약의', 5),
#  ('합', 5),
#  ('격한', 5),
#  ('완성', 5),
#  ('적', 5),
#  ('용하는', 5),
#  ('로', 5),
#  ('2.', 5),
#  ('정', 5),
#  ('못하여', 4),
#  ('지장을', 4),
#  ('정하여진', 4),
#  ('[천분율]를', 4),
#  ('용역수행이', 4),
#  ('동조', 4),
#  ('지급재료의', 4),
#  ('동안', 4),
#  ('않음에', 4),
#  ('손해배상을', 4),
#  ('하되,', 4),
#  ('이루어지고', 4),
#  ('제조에', 4),
#  ('[천분율]을', 4),
#  ('보증이행', 4),
#  ('이후의', 4),
#  ('목적물', 4),
#  ('계약내용과', 4),
#  ('다르거나', 4),
#  ('하자', 4),
#  ('불구하고,', 4),
#  ('아니하면', 4),
#  ('수급사업자는', 4),
#  ('통보하고', 4),
#  ('일시', 4),
#  ('중지할', 4),
#  ('제외한다.', 4),
#  ('이행할', 4),
#  ('한다', 4),
#  ('수정', 4),
#  ('만약', 4),
#  ('일수', 4),
#  ('못했을', 4),
#  ('규정한', 4),
#  ('계약상대자의', 4),
#  ('계약보증금상당액에', 4),
#  ('달한', 4),
#  ('지연된', 4),
#  ('계약기간의', 4),
#  ('연장을', 4),
#  ('아니하는', 4),
#  ('공제후에', 4),
#  ('재', 4),
#  ('과업수행을', 4),
#  ('유지관리', 4),
#  ('받은', 4),
#  ('후에', 4),
#  ('다음날부', 4),
#  ('지급하는', 4),
#  ('지연일수에', 4),
#  ('공사비', 4),
#  ('부과한다.', 4),
#  ('계약보증금을', 4),
#  ('이상이', 4),
#  ('하자로', 4),
#  ('이때', 4),
#  ('성과품을', 4),
#  ('‘갑’은', 4),
#  ('제7조', 4),
#  ('작업', 4),
#  ('못하거나,', 4),
#  ('잔금에서', 4),
#  ('정해진', 4),
#  ('장애', 4),
#  ('제6조', 4),
#  ('정상가동', 4),
#  ('확대', 4),
#  ('설계업무의', 4),
#  ('수행한', 4),
#  ('공제하며,', 4),
#  ('제4조에', 4),
#  ('불가항력으로', 4),
#  ('예외로', 4),
#  ('지급시', 4),
#  ('잔금', 4),
#  ('○%를', 4),
#  ('결과', 4),
#  ('정도는', 4),
#  ('아니지만', 4),
#  ('오류의', 4),
#  ('납품완료일을', 4),
#  ('지체1일', 4),
#  ('구축비의', 4),
#  ('3/100에', 4),
#  ('손해금이', 4),
#  ('"발주처"에게', 4),
#  ('위하여', 4),
#  ('지급해야', 4),
#  ('분의', 4),
#  ('정하는', 4),
#  ('준하는', 4),
#  ('인정하는', 4),
#  ('지체상금의', 4),
#  ('일부', 4),
#  ('전부를', 4),
#  ('개발용역비', 4),
#  ('수행기한', 4),
#  ('조치를', 4),
#  ('토지매입이', 4),
#  ('80%를', 4),
#  ('미달하는', 4),
#  ('토지용역비를', 4),
#  ('13조', 4),
#  ('해제·해지할', 4),
#  ('불가능한', 4),
#  ('계약이행이', 4),
#  ('해제·해지', 4),
#  ('14조', 4),
#  ('사업의', 4),
#  ('전체', 4),
#  ('2.5/1,000으로', 4),
#  ('제하고', 4),
#  ('“공급자”는', 4),
#  ('다', 4),
#  ('만,', 4),
#  ('니한', 4),
#  ('검', 4),
#  ('사를', 4),
#  ('것', 4),
#  ('지체하지', 4),
#  ('제23조에', 4),
#  ('산입한다.(2002.', 4),
#  ('14.,', 4),
#  ('2003.', 4),
#  ('다시', 4),
#  ('검사일수를', 4),
#  ('검사한', 4),
#  ('초과일수를', 4),
#  ('차감한다.', 4),
#  ('(2003.', 4),
#  ('용역대가의', 4),
#  ('일반용역을', 4),
#  ('한한다.)을', 4),
#  ('예치금등과', 4),
#  ('“을”로부터', 4),
#  ('는', 4),
#  ('산입한다.<신설', 4),
#  ('계약상대자', 4),
#  ('제19조의', 4),
#  ('제16조', 4),
#  ('일괄하', 4),
#  ('목을', 4),
#  ('사항을', 3),
#  ('월보수료의', 3),
#  ('보수료에서', 3),
#  ('같다', 3),
#  ('수행기간', 3),
#  ('계약이행내용의', 3),
#  ('없음을', 3),
#  ('지급하기로', 3),
#  ('공사', 3),
#  ('지연으로', 3),
#  ('준공기한을', 3),
#  ('준공기한의', 3),
#  ('실제인도한', 3),
#  ('계약내용대로', 3),
#  ('납기에', 3),
#  ('납기지연으로', 3),
#  ('있으며', 3),
#  ('배상청구의', 3),
#  ('범위는', 3),
#  ('별도로', 3),
#  ('품질보증', 3),
#  ('납기보증계약서에', 3),
#  ('개별계약으로', 3),
#  ('선급금이나', 3),
#  ('기성금을', 3),
#  ('요청할', 3),
#  ('있고,', 3),
#  ('요청하였음에도', 3),
#  ('위탁받은', 3),
#  ('작업에', 3),
#  ('중지기간을', 3),
#  ('중지기간은', 3),
#  ('산정', 3),
#  ('지체일수당', 3),
#  ('완공하지', 3),
#  ('하도급대금', 3),
#  ('[백분율]를', 3),
#  ('업무', 3),
#  ('[백분율],', 3),
#  ('출입제한,', 3),
#  ('[날짜]을', 3),
#  ('있으며,', 3),
#  ('지체배상금은', 3),
#  ('지체가', 3),
#  ('연장할', 3),
#  ('시는', 3),
#  ('[날짜]에', 3),
#  ('에서', 3),
#  ('계약금', 3),
#  ('관리·사용하고', 3),
#  ('취한', 3),
#  ('승인하였을', 3),
#  ('연장기간에', 3),
#  ('부과하여서는', 3),
#  ('준공기한내에', 3),
#  ('"甲"이', 3),
#  ('중단되었을', 3),
#  ('계', 3),
#  ('과업을', 3),
#  ('하', 3),
#  ('때에', 3),
#  ('지급키로', 3),
#  ('장애가', 3),
#  ('해제', 3),
#  ('최종보고서를', 3),
#  ('남품일이', 3),
#  ('늦어진', 3),
#  ('제3자에게', 3),
#  ('첨부', 3),
#  ('계획서상의', 3),
#  ('사업내용을', 3),
#  ('별첨', 3),
#  ('계획서상', 3),
#  ('목표대비', 3),
#  ('실적을', 3),
#  ('천재지변등', 3),
#  ('용역대금에서', 3),
#  ('관리.사용하고', 3),
#  ...]

# %%
show_freq_by_option(df, '필수조항5')
# Out:
# 998
# [('수', 402),
#  ('또는', 326),
#  ('그', 295),
#  ('및', 290),
#  ('한다.', 254),
#  ('경우', 224),
#  ('있다.', 217),
#  ('등을', 208),
#  ('있는', 205),
#  ('경우에는', 184),
#  ('특허권', 179),
#  ('대한', 169),
#  ('본', 165),
#  ('지식재산권', 138),
#  ('이', 129),
#  ('한', 110),
#  ('따른', 109),
#  ('수급사업자는', 108),
#  ('의하여', 107),
#  ('등', 99),
#  ('계약상대자가', 99),
#  ('제3자의', 96),
#  ('계약에', 94),
#  ('등에', 92),
#  ('할', 90),
#  ('이를', 89),
#  ('관한', 88),
#  ('관련하여', 87),
#  ('없이', 87),
#  ('때에는', 86),
#  ('일체의', 85),
#  ('사용할', 84),
#  ('제3자에게', 83),
#  ('계약의', 81),
#  ('해당', 78),
#  ('다만,', 76),
#  ('제1항에', 76),
#  ('기타', 75),
#  ('책임을', 75),
#  ('등의', 74),
#  ('공동으로', 74),
#  ('없다.', 72),
#  ('계약상대자는', 71),
#  ('사용에', 71),
#  ('원사업자의', 70),
#  ('“을”은', 69),
#  ('계약상대자에게', 66),
#  ('지식재산권을', 64),
#  ('따라', 61),
#  ('없는', 60),
#  ('관련한', 59),
#  ('대하여', 59),
#  ('협의하여', 58),
#  ('경우에', 57),
#  ('대상으로', 57),
#  ('권리를', 57),
#  ('“을”이', 57),
#  ('통해', 57),
#  ('권리의', 55),
#  ('고려하여', 54),
#  ('사용을', 53),
#  ('지식재산권의', 53),
#  ('후', 52),
#  ('협의를', 51),
#  ('목적물의', 50),
#  ('한다)', 49),
#  ('특허권,', 47),
#  ('저작권', 47),
#  ('을은', 47),
#  ('요구할', 47),
#  ('사용', 46),
#  ('수급사업자가', 46),
#  ('하며,', 45),
#  ('원사업자는', 43),
#  ('원사업자에게', 43),
#  ('원사업자와', 43),
#  ('지적재산권은', 43),
#  ('지급할', 42),
#  ('의한', 42),
#  ('모든', 41),
#  ('용역의', 41),
#  ('정할', 40),
#  ('정한', 39),
#  ('사실을', 39),
#  ('지식재산권은', 39),
#  ('계약문서에', 39),
#  ('“갑”의', 39),
#  ('지분', 39),
#  ('침해하지', 38),
#  ('이에', 38),
#  ('져야', 38),
#  ('“갑”이', 38),
#  ('필요한', 37),
#  ('분쟁이', 37),
#  ('중', 37),
#  ('것으로', 37),
#  ('“갑”에게', 37),
#  ('외교관계', 37),
#  ('수행', 36),
#  ('아니하고', 36),
#  ('계약', 36),
#  ('있어', 36),
#  ('실용신안권,', 35),
#  ('별도의', 35),
#  ('비용을', 35),
#  ('계약목적물의', 35),
#  ('수급사업자의', 34),
#  ('상호', 34),
#  ('수행방법을', 34),
#  ('지정하지', 34),
#  ('계약상대자의', 34),
#  ('원사업자', 33),
#  ('발생할', 33),
#  ('문서로서', 33),
#  ('것', 33),
#  ('적용을', 33),
#  ('소요된', 33),
#  ('저작권은', 33),
#  ('발생한', 32),
#  ('위하여', 32),
#  ('“갑”은', 32),
#  ('국내', 32),
#  ('<신설', 32),
#  ('설비등', 31),
#  ('지체', 31),
#  ('다음', 31),
#  ('"을"은', 31),
#  ('"갑"에게', 31),
#  ('되어', 31),
#  ('기타사항은', 31),
#  ('않는', 30),
#  ('관하여', 30),
#  ('대해', 30),
#  ('각', 30),
#  ('갑의', 30),
#  ('이내에', 30),
#  ('준용한다.', 30),
#  ('사용하지', 29),
#  ('목적물', 29),
#  ('않음을', 29),
#  ('경우,', 29),
#  ('갑에게', 29),
#  ('기술자료의', 29),
#  ('개발의', 29),
#  ('“을”의', 29),
#  ('계약목적물에', 29),
#  ('자신의', 28),
#  ('사전', 28),
#  ('공동', 28),
#  ('다른', 28),
#  ('호의', 28),
#  ('그러나', 28),
#  ('제56조를', 28),
#  ('귀속된', 28),
#  ('다.', 28),
#  ('국외에서', 28),
#  ('원사업자로부터', 27),
#  ('사양서,', 27),
#  ('제공한', 27),
#  ('개발한', 27),
#  ('이하', 27),
#  ('발주기관과', 27),
#  ('국가의', 27),
#  ('기술,', 26),
#  ('아니한다.', 26),
#  ('제3자', 26),
#  ('에', 26),
#  ('받은', 26),
#  ('당해', 26),
#  ('권리가', 26),
#  ('개발', 26),
#  ('포함한다.', 26),
#  ('등)을', 26),
#  ('계약당사자간의', 26),
#  ('소유하는', 26),
#  ('정보활동,', 26),
#  ('공유자', 26),
#  ('지식재산권이', 26),
#  ('사용하게', 25),
#  ('수행에', 25),
#  ('되어있는', 25),
#  ('제반편의를', 25),
#  ('아니된다.', 25),
#  ('제반', 25),
#  ('의해', 25),
#  ('출원', 25),
#  ('발주기관이', 25),
#  ('특수성(국가안전보장,', 25),
#  ('국방,', 25),
#  ('발주기관에', 25),
#  ('정함이', 25),
#  ('동의를', 24),
#  ('등과', 24),
#  ('상대방에게', 24),
#  ('통지한', 24),
#  ('를', 24),
#  ('지식재산권과', 24),
#  ('밖에', 24),
#  ('[본조신설', 24),
#  ('단독으로', 24),
#  ('국가안전보장,', 24),
#  ('개작권을', 24),
#  ('요청이', 23),
#  ('등(이하', 23),
#  ('수급사업자에게', 23),
#  ('지식재산권등을', 23),
#  ('우려가', 23),
#  ('통지하여야', 23),
#  ('단,', 23),
#  ('갖는다.', 23),
#  ('라이센스', 23),
#  ('을', 22),
#  ('지식재산권등의', 22),
#  ('손해를', 22),
#  ('사전에', 22),
#  ('관련', 22),
#  ('특별한', 21),
#  ('책임이', 21),
#  ('요청할', 21),
#  ('허락', 21),
#  ('범위', 21),
#  ('목적물에', 21),
#  ('지적재산권을', 21),
#  ('대해서는', 21),
#  ('는', 21),
#  ('2009.9.21.>', 21),
#  ('계약목적물을', 21),
#  ('계약목', 21),
#  ('상표권,', 20),
#  ('못하며,', 20),
#  ('사이에', 20),
#  ('발생하거나', 20),
#  ('자가', 20),
#  ('해지', 20),
#  ('목적물을', 20),
#  ('제3자와의', 20),
#  ('을이', 20),
#  ('“위탁자”는', 20),
#  ('계약을', 20),
#  ('“위탁자”가', 20),
#  ('부담한다.', 20),
#  ('"을"에게', 20),
#  ('"을"이', 20),
#  ('"갑"이', 20),
#  ('승인을', 20),
#  ('공급자의', 20),
#  ('수행함에', 20),
#  ('개정', 20),
#  ('경우를', 19),
#  ('교부를', 19),
#  ('복제,', 19),
#  ('결과물의', 19),
#  ('소유권은', 19),
#  ('대여', 18),
#  ('허락받은', 18),
#  ('상대방의', 18),
#  ('만료', 18),
#  ('해제', 18),
#  ('후에도', 18),
#  ('을의', 18),
#  ('목적으로', 18),
#  ('발생하는', 18),
#  ('제', 18),
#  ('어떠한', 18),
#  ('계약당사자간', 18),
#  ('<개정', 18),
#  ('임치기관은', 18),
#  ('하지', 17),
#  ('도면,', 17),
#  ('등”이라', 17),
#  ('계약기간', 17),
#  ('지적재산권', 17),
#  ('등은', 17),
#  ('"갑"의', 17),
#  ('“위탁자”에게', 17),
#  ('소유로', 17),
#  ('하는', 17),
#  ('하여야', 17),
#  ('양도할', 17),
#  ('진다.', 17),
#  ('용역을', 17),
#  ('개발된', 17),
#  ('"갑"은', 17),
#  ('계약상', 17),
#  ('수요자의', 17),
#  ('제공․알선하거나', 17),
#  ('대', 17),
#  ('권리', 17),
#  ('2015.1.1.]', 17),
#  ('방위계획', 17),
#  ('대금의', 16),
#  ('기술을', 16),
#  ('취득한', 16),
#  ('조건으로', 16),
#  ('제조방법이', 16),
#  ('즉시', 16),
#  ('또한', 16),
#  ('갑이', 16),
#  ('별도로', 16),
#  ('달리', 16),
#  ('있을', 16),
#  ('귀속된다.', 16),
#  ('용역', 16),
#  ('하고', 16),
#  ('받아야', 16),
#  ('계약이', 15),
#  ('지도내용', 15),
#  ('외에', 15),
#  ('추가하여', 15),
#  ('“개량기술”이라', 15),
#  ('원천기술의', 15),
#  ('기여분과', 15),
#  ('개량기술의', 15),
#  ('가치를', 15),
#  ('합리적인', 15),
#  ('통상실시권을', 15),
#  ('허여한다.', 15),
#  ('원사업자가', 15),
#  ('서면으로', 15),
#  ('하며', 15),
#  ('이때', 15),
#  ('배포,', 15),
#  ('“을”에게', 15),
#  ('소유권,', 15),
#  ('제1항', 15),
#  ('것을', 15),
#  ('등록된', 15),
#  ('지', 15),
#  ('당공사는', 15),
#  ('디자인권,', 14),
#  ('양도,', 14),
#  ('지체없이', 14),
#  ('제조와', 14),
#  ('이외에는', 14),
#  ('승낙을', 14),
#  ('얻지', 14),
#  ('수급사업자', 14),
#  ('배상한다.', 14),
#  ('제작하는', 14),
#  ('노하우(이하', 14),
#  ('통보하여야', 14),
#  ('변경사항이', 14),
#  ('등)', 14),
#  ('사유가', 14),
#  ('정하지', 14),
#  ('지적재산권에', 14),
#  ('권리는', 14),
#  ('개작,', 14),
#  ('제2항에도', 14),
#  ('불구하고,', 14),
#  ('정보', 14),
#  ('편의를', 14),
#  ('귀속되며,', 14),
#  ('행위를', 14),
#  ('준하는', 14),
#  ('소유하고', 14),
#  ('수요자에게', 14),
#  ('반드시', 14),
#  ('활용할', 14),
#  ('제2항에', 14),
#  ('활용을', 14),
#  ('활용', 14),
#  ('외교관계,', 14),
#  ('출원하거나', 14),
#  ('등록하는', 14),
#  ('등록신청서와', 14),
#  ('증명할', 14),
#  ('서류를', 14),
#  ('포기로', 14),
#  ('소멸되는', 14),
#  ('소멸일', 14),
#  ('전에', 14),
#  ('계약서에', 14),
#  ('2009.9.21,', 14),
#  ('있으며,', 13),
#  ('물론', 13),
#  ('배상하여야', 13),
#  ('정한다.', 13),
#  ('침해', 13),
#  ('제작', 13),
#  ('갑과', 13),
#  ('갑', 13),
#  ('제3의', 13),
#  ('소스코드', 13),
#  ('그에', 13),
#  ('따른다.', 13),
#  ('이외의', 13),
#  ('비용과', 13),
#  ('동시에', 13),
#  ('우선적으로', 13),
#  ('전송', 13),
#  ('목적', 13),
#  ('설계도서를', 13),
#  ('지적재산권의', 13),
#  ('받을', 13),
#  ('같다)은', 13),
#  ('목적,', 13),
#  ('등),', 13),
#  ('기술개발', 13),
#  ('귀속주체,', 13),
#  ('정보보안,', 13),
#  ('소유하거나', 13),
#  ('공동수급체인', 13),
#  ('공동수급체', 13),
#  ('구성원간의', 13),
#  ('등록', 13),
#  ('제출할', 13),
#  ('통보할', 13),
#  ('소유하며,', 13),
#  ('균등한', 13),
#  ('기여도', 13),
#  ('공동소유와', 13),
#  ('사유에', 13),
#  ('상업적', 13),
#  ('일방은', 13),
#  ('이익은', 13),
#  ('행사한', 13),
#  ('당사자에게', 13),
#  ('귀속하는', 13),
#  ('소프트웨어를', 13),
#  ('대상기관의', 13),
#  ('2012.1.1.>', 13),
#  ('일방이', 13),
#  ('지분을', 13),
#  ('양도하는', 13),
#  ('타공유자의', 13),
#  ('경우로서', 13),
#  ('국가기관의', 13),
#  ('비밀리에', 13),
#  ('개작할', 13),
#  ('부여받은', 13),
#  ('경우라', 13),
#  ('하더라도', 13),
#  ('계약목적과', 13),
#  ('관련되어', 13),
#  ('재개발,', 13),
#  ('있어서는', 13),
#  ('하여서도', 13),
#  ('적물의', 13),
#  ('임치하여야', 13),
#  ('알선하거나', 13),
#  ('노하우,', 12),
#  ('이용을', 12),
#  ('얻어', 12),
#  ('원사업자에', 12),
#  ('사유로', 12),
#  ('보증한다.', 12),
#  ('보호하기', 12),
#  ('중요한', 12),
#  ('추가', 12),
#  ('오브젝트', 12),
#  ('코드의', 12),
#  ('복제물', 12),
#  ('기술정보(매뉴얼,', 12),
#  ('설계서,', 12),
#  ('플로우차트,', 12),
#  ('유지보수자료', 12),
#  ('"을"의', 12),
#  ('“갑”', 12),
#  ('발주자가', 12),
#  ('각호의', 12),
#  ('제출한', 12),
#  ('산업재산권을', 12),
#  ('설계도서의', 12),
#  ('소유한다', 12),
#  ('계약과', 12),
#  ('사용하여', 12),
#  ('완료한', 12),
#  ('보장하고,', 12),
#  ('최종인도물의', 12),
#  ('디자인권(이하', 12),
#  ('“특허권', 12),
#  ('당사자간에', 12),
#  ('타기관과', 12),
#  ('입찰', 12),
#  ('공고에', 12),
#  ('발주기관은', 12),
#  ('필요가', 12),
#  ('부여하여야', 12),
#  ('사용(기능개선,', 12),
#  ('"계약목적물의', 12),
#  ('사용“이라', 12),
#  ('한다)함에', 12),
#  ('6개월', 12),
#  ('귀속주체', 12),
#  ('상업적으로', 12),
#  ('받아', 12),
#  ('당공사에', 12),
#  ('대금을', 11),
#  ('제공', 11),
#  ('수급사업자와', 11),
#  ('부득이한', 11),
#  ('통지', 11),
#  ('않는다.', 11),
#  ('문서에', 11),
#  ('납품한', 11),
#  ('얻은', 11),
#  ('약정이', 11),
#  ('정하는', 11),
#  ('제작과', 11),
#  ('한다)에', 11),
#  ('하여', 11),
#  ('책임으로', 11),
#  ('의', 11),
#  ('계약상대자에', 11),
#  ('지식재산', 11),
#  ('제1항의', 11),
#  ('기관(이하', 11),
#  ('제1항에서', 11),
#  ('함은', 11),
#  ('산출물에', 11),
#  ('있어서', 11),
#  ('곳에', 11),
#  ('제출을', 11),
#  ('자료', 11),
#  ('소유한다.', 11),
#  ('있', 11),
#  ('사업화를', 11),
#  ('제한할', 11),
#  ('계약담당공무원은', 11),
#  ('제한을', 11),
#  ('관리자의', 10),
#  ('제공하거나', 10),
#  ('해지된', 10),
#  ('보증하며,', 10),
#  ('획득할', 10),
#  ('보증하여야', 10),
#  ('사양에', 10),
#  ('위해서', 10),
#  ('기능수행에', 10),
#  ('발생일로부터', 10),
#  ('기관', 10),
#  ('파산선고를', 10),
#  ('받거나', 10),
#  ('해산결의를', 10),
#  ('민법', 10),
#  ('법률에', 10),
#  ('소멸된', 10),
#  ('종료', 10),
#  ('2014.1.10.]', 10),
#  ('보고서', 10),
#  ('포함한', 10),
#  ('시', 10),
#  ('최종인도물에', 10),
#  ('30일', 10),
#  ('계', 10),
#  ('사용되는', 9),
#  ('영업비밀', 9),
#  ('선량한', 9),
#  ('사용하거나', 9),
#  ('대여,', 9),
#  ('담보로', 9),
#  ('제조방법(이하', 9),
#  ('시공과', 9),
#  ('의장권,', 9),
#  ('도중은', 9),
#  ('없으며,', 9),
#  ('정보,', 9),
#  ('자신이', 9),
#  ('정보에', 9),
#  ('이는', 9),
#  ('통지를', 9),
#  ('관련된', 9),
#  ('가지며,', 9),
#  ('제3자와', 9),
#  ('결과물에', 9),
#  ('비용은', 9),
#  ('사용하여서는', 9),
#  ('부담으로', 9),
#  ('조치를', 9),
#  ('홈페이지의', 9),
#  ('협의', 9),
#  ('타', 9),
#  ('이행과', 9),
#  ('“을”에', 9),
#  ('자료를', 9),
#  ('"갑"과', 9),
#  ('지분은', 9),
#  ('발주기관', 9),
#  ('수익을', 9),
#  ('로', 9),
#  ('활용하는', 9),
#  ('반영하여야', 9),
#  ('사업수행에', 9),
#  ('”기술자료“를', 9),
#  ('“임치기관”이라', 9),
#  ('야', 9),
#  ('“기술자료”라', 9),
#  ('아래의', 9),
#  ('의미하고,', 9),
#  ('「저작권법시행령」', 9),
#  ('제39조의2', 9),
#  ('「대중소기업', 9),
#  ('상생협력', 9),
#  ('촉진에', 9),
#  ('법률', 9),
#  ('중에서', 9),
#  ('선정하며,', 9),
#  ('사유를', 9),
#  ('명시하여', 9),
#  ('임치기관에', 9),
#  ('통지없이', 9),
#  ('계약당사자가', 9),
#  ('다르게', 9),
#  ('사항이', 9),
#  ('제공,', 9),
#  ('상대자가', 9),
#  ('서', 9),
#  ('른', 9),
#  ('신설,', 9),
#  ('당', 9),
#  ('‘09.12.29>', 9),
#  ('대여받은', 8),
#  ('주의의무로', 8),
#  ('계약에서', 8),
#  ('용도', 8),
#  ('이외로', 8),
#  ('사용수익하게', 8),
#  ('해제,', 8),
#  ('유상으로', 8),
#  ('구입', 8),
#  ('지급은', 8),
#  ('지급시기', 8),
#  ('이후로', 8),
#  ('대금에서', 8),
#  ('상계할', 8),
#  ('제조', 8),
#  ('통지한다.', 8),
#  ('제조한', 8),
#  ('제조하는', 8),
#  ('사항', 8),
#  ('양도', 8),
#  ('“지식재산권', 8),
#  ('서면', 8),
#  ('기술자료', 8),
#  ('갑으로부터', 8),
#  ('아니하는', 8),
#  ('이라', 8),
#  ('제작과정에서', 8),
#  ('저작권,', 8),
#  ('소유권', 8),
#  ('새로운', 8),
#  ('승인', 8),
#  ('일부', 8),
#  ('중에', 8),
#  ('제공하는', 8),
#  ('동의', 8),
#  ('온라인', 8),
#  ('서비스를', 8),
#  ('“OOO원”은', 8),
#  ('1개월', 8),
#  ('특허출원에', 8),
#  ('특허출원비용은', 8),
#  ('“갑”과', 8),
#  ('된다.', 8),
#  ('유사한', 8),
#  ('프로그램에', 8),
#  ('지불이', 8),
#  ('중간인도물,', 8),
#  ('사전작업물,', 8),
#  ('용역수행과', 8),
#  ('수행을', 8),
#  ('소재지', 8),
#  ('수익', 8),
#  ('명시하고', 8),
#  ('용역결과물을', 8),
#  ('특', 8),
#  ('허권', 8),
#  ('적물에', 8),
#  ('식재산권은', 8),
#  ('당공', 8),
#  ('사가', 8),
#  ('설비,', 7),
#  ('관리하여야', 7),
#  ('기간이', 7),
#  ('종료하거나', 7),
#  ('보관상태를', 7),
#  ('조사할', 7),
#  ('사정이', 7),
#  ('거부하지', 7),
#  ('대여한', 7),
#  ('통보한다.', 7),
#  ('유지', 7),
#  ('합의하여', 7),
#  ('의거', 7),
#  ('있으며', 7),
#  ('소프트웨어', 7),
#  ('동', 7),
#  ('제3자로부터', 7),
#  ('개발제품의', 7),
#  ('납품과', 7),
#  ('양도한다.', 7),
#  ('인하여', 7),
#  ('제공·알선하거나', 7),
#  ('금액의', 7),
#  ('지불에', 7),
#  ('더', 7),
#  ('당사자가', 7),
#  ('요구한', 7),
#  ('문서의', 7),
#  ('광고,', 7),
#  ('판매촉진,', 7),
#  ('선전의', 7),
#  ('자료로', 7),
#  ('명칭을', 7),
#  ('경우에도', 7),
#  ('비용으로', 7),
#  ('지적', 7),
#  ('프로그램', 7),
#  ('문제가', 7),
#  ('속한다.', 7),
#  ('디자인', 7),
#  ('불이행', 7),
#  ('손해배상을', 7),
#  ('청구할', 7),
#  ('복사,', 7),
#  ('자료의', 7),
#  ('귀속한다.', 7),
#  ('건축을', 7),
#  ('일체는', 7),
#  ('소요되는', 7),
#  ('협력단이', 7),
#  ('규정에', 7),
#  ('제출하는', 7),
#  ('전부', 7),
#  ('용역결과물의', 7),
#  ('유지보수를', 7),
#  ('공동으', 7),
#  ('2015.1.1.>', 7),
#  ('발주기관의', 7),
#  ('져야한다.', 7),
#  ('“발주자”에게', 7),
#  ('하', 7),
#  ('소유할', 7),
#  ('당공사와', 7),
#  ('기구류', 6),
#  ('‘설비등’이라', 6),
#  ('허락할', 6),
#  ('반환하며,', 6),
#  ('계약기간,', 6),
#  ('취득할', 6),
#  ('보수를', 6),
#  ('서면승낙', 6),
#  ('하되,', 6),
#  ('획득한', 6),
#  ('목적물과', 6),
#  ('통지하여', 6),
#  ('출원한다.', 6),
#  ('연구하여', 6),
#  ('대하여는', 6),
#  ('위', 6),
#  ('부품의', 6),
#  ('어느', 6),
#  ('해당하는', 6),
#  ('아니하다.', 6),
#  ('을과', 6),
#  ('유지보수', 6),
#  ('갑은', 6),
#  ('아울러', 6),
#  ('침해,', 6),
#  ('“을”', 6),
#  ('있도록', 6),
#  ('비용', 6),
#  ('연구결과에', 6),
#  ('실시할', 6),
#  ('통상', 6),
#  ('로얄티를', 6),
#  ('지불하여야', 6),
#  ('로얄티', 6),
#  ('대하여서는', 6),
#  ('신의', 6),
#  ('아래', 6),
#  ('맺는다.', 6),
#  ('아닌', 6),
#  ('원하는', 6),
#  ('계약체결을', 6),
#  ('제안하여야', 6),
#  ('그러한', 6),
#  ('제안을', 6),
#  ('수락하지', 6),
#  ('체결할', 6),
#  ('조건은', 6),
#  ('제시한', 6),
#  ('조건보다', 6),
#  ('유리한', 6),
#  ('조건을', 6),
#  ('제시할', 6),
#  ('양', 6),
#  ('귀속', 6),
#  ('‘기술자료’를', 6),
#  ('임치를', 6),
#  ('라이선스', 6),
#  ('보고서나', 6),
#  ('전부에', 6),
#  ('쟁송상의', 6),
#  ('상기의', 6),
#  ('그러나,', 6),
#  ('건', 6),
#  ('물품의', 6),
#  ('귀책사유로', 6),
#  ('획득하고자', 6),
#  ('제작된', 6),
#  ('분쟁을', 6),
#  ('“을”과', 6),
#  ('협의없이', 6),
#  ('책임', 6),
#  ('3자의', 6),
#  ('인한', 6),
#  ('“위탁자”의', 6),
#  ('브랜드', 6),
#  ('결과로', 6),
#  ('소유이며,', 6),
#  ('저작물', 6),
#  ('보수', 6),
#  ('용역에', 6),
#  ('사이트의', 6),
#  ('소스코드의', 6),
#  ('"을"과', 6),
#  ('보유된다.', 6),
#  ('타인의', 6),
#  ('완료된', 6),
#  ('수요자가', 6),
#  ('일부를', 6),
#  ('대자가', 6),
#  ('조치', 6),
#  ('처분・배포하고자', 6),
#  ('시행령」제15조의2에', 6),
#  ('2010.1.4.>', 6),
#  ('권', 6),
#  ('제35조의3을', 6),
#  ('‘15.02.25>', 6),
#  ('‘09.12.29,', 6),
#  ('사업수행자는', 6),
#  ('제조에', 5),
#  ('금형,', 5),
#  ('\U000f0850지식재산권등\U000f0851이라', 5),
#  ('원사업자으로부터', 5),
#  ('시공', 5),
#  ('외에는', 5),
#  ('처리하기로', 5),
#  ('시공한', 5),
#  ('침해하는', 5),
#  ('공유로', 5),
#  ('손해에', 5),
#  ('그러하지', 5),
#  ('인정되는', 5),
#  ('제시하는', 5),
#  ('제외하고는', 5),
#  ('저작권법에', 5),
#  ('내에서', 5),
#  ('원칙적으로', 5),
#  ('위한', 5),
#  ('제작방법이', 5),
#  ('2항에', 5),
#  ('서비스', 5),
#  ('수행하는', 5),
#  ('수행방법', 5),
#  ('개발제품에', 5),
#  ('적용한', 5),
#  ('기술이', 5),
#  ('보증함과', 5),
#  ('산업재산권과', 5),
#  ('제기되는', 5),
#  ('주장에', 5),
#  ('해결하기로', 5),
#  ('않도록', 5),
#  ('기술용역의', 5),
#  ('등이', 5),
#  ('이행에', 5),
#  ('부담하여야', 5),
#  ('용도로', 5),
#  ('복사물을', 5),
#  ('표시하거나', 5),
#  ('특허', 5),
#  ('‘을’에게', 5),
#  ('공사', 5),
#  ('해결하여야', 5),
#  ('이후', 5),
#  ('지급하지', 5),
#  ('내용', 5),
#  ('동의하는', 5),
#  ('공동명의로', 5),
#  ('전액', 5),
#  ('공급된', 5),
#  ('시점에서', 5),
#  ('소유이며', 5),
#  ('관련파일', 5),
#  ('출력물을', 5),
#  ('공유한다.', 5),
#  ('이외에', 5),
#  ('안', 5),
#  ('여하한', 5),
#  ('산출물의', 5),
#  ('면책시켜야', 5),
#  ('프로그램을', 5),
#  ('업체', 5),
#  ('판매', 5),
#  ('별도', 5),
#  ('일체를', 5),
#  ('포함하여', 5),
#  ('방송권', 5),
#  ('복제·배포권', 5),
#  ('본다.', 5),
#  ('위반하여', 5),
#  ('협력단에', 5),
#  ('수요자에', 5),
#  ('인수된', 5),
#  ('양도되며,', 5),
#  ('등록에', 5),
#  ('수행과정', 5),
#  ('제시된', 5),
#  ('공급자에게', 5),
#  ('이용하게', 5),
#  ('되는', 5),
#  ('불구하고', 5),
#  ('창작물에', 5),
#  ('공급자는', 5),
#  ('제56조제3항에', 5),
#  ('임치하여', 5),
#  ('발주기관에게', 5),
#  ('제4항과', 5),
#  ('비롯하여', 5),
#  ('사용하는', 5),
#  ('명시되지', 5),
#  ('아니한', 5),
#  ('발주자는', 5),
#  ('소요비용을', 5),
#  ('지급하여야', 5),
#  ('지식재', 5),
#  ('기', 5),
#  ('여도(발주기관과', 5),
#  ('소', 5),
#  ('재지', 5),
#  ('내에', 5),
#  ('분은', 5),
#  ('방', 5),
#  ('위계획', 5),
#  ('권의', 5),
#  ('명시하', 5),
#  ('고', 5),
#  ('약목적물을', 5),
#  ('계약상대자', 5),
#  ('계약서상의', 5),
#  ('이용', 5),
#  ('따', 5),
#  ('임치수수료는', 5),
#  ('권을', 5),
#  ('사업수행자에게', 5),
#  ('제작에', 4),
#  ('대여할', 4),
#  ('귀속은', 4),
#  ('정하되,', 4),
#  ('귀속,', 4),
#  ('분쟁의', 4),
#  ('사항은', 4),
#  ('침해할', 4),
#  ('하나에', 4),
#  ('계약물품의', 4),
#  ('발주부품을', 4),
#  ('제품의', 4),
#  ('지식재산권,', 4),
#  ('설비·계측기', 4),
#  ('"산업재산권"', 4),
#  ('소유로하며', 4),
#  ('분쟁에', 4),
#  ('라이센스계약을', 4),
#  ('판권', 4),
#  ('저작권을', 4),
#  ('임치한', 4),
#  ('30일이내에', 4),
#  ('연구로', 4),
#  ('원본,', 4),
#  ('이행함에', 4),
#  ('"을"로부터', 4),
#  ('산업재산권', 4),
#  ('발생하였을', 4),
#  ('입은', 4),
#  ('손해가', 4),
#  ('분쟁으로', 4),
#  ('계약목적물', 4),
#  ('귀속되며', 4),
#  ('용역과', 4),
#  ('침해하여서는', 4),
#  ('기여한', 4),
#  ('협의가', 4),
#  ('않은', 4),
#  ('사업수행결과물에', 4),
#  ('인터넷을', 4),
#  ('실시함에', 4),
#  ('저작권에', 4),
#  ('연구결과가', 4),
#  ('특허가능성이', 4),
#  ('통지하고', 4),
#  ('출원여부를', 4),
#  ('특허출원하며', 4),
#  ('회신이', 4),
#  ('단독명의로', 4),
#  ('특허출원을', 4),
#  ('“OOO원”의', 4),
#  ('상기', 4),
#  ...]

# %%
show_freq_by_option(df, '필수조항11')
# Out:
# 5527
# [('또는', 2785),
#  ('경우', 2711),
#  ('수', 1785),
#  ('계약을', 1482),
#  ('있다.', 1192),
#  ('본', 1134),
#  ('해제', 1054),
#  ('경우에는', 949),
#  ('계약의', 909),
#  ('한다.', 825),
#  ('이', 807),
#  ('해지할', 801),
#  ('및', 723),
#  ('의하여', 692),
#  ('그', 686),
#  ('때', 682),
#  ('규정에', 627),
#  ('다음', 607),
#  ('때에는', 588),
#  ('“을”이', 485),
#  ('해당하는', 461),
#  ('없다고', 456),
#  ('의한', 454),
#  ('사유가', 450),
#  ('할', 432),
#  ('계약', 430),
#  ('인하여', 429),
#  ('각', 416),
#  ('계약이', 376),
#  ('정당한', 369),
#  ('대한', 369),
#  ('발생한', 364),
#  ('없이', 361),
#  ('제1항의', 347),
#  ('있는', 332),
#  ('사유로', 323),
#  ('해지', 315),
#  ('“갑”은', 310),
#  ('인정될', 299),
#  ('기타', 298),
#  ('이를', 298),
#  ('전부', 297),
#  ('각호의', 291),
#  ('경우에', 285),
#  ('일부를', 277),
#  ('“을”은', 262),
#  ('호의', 258),
#  ('받은', 239),
#  ('“을”의', 238),
#  ('원사업자', 231),
#  ('"을"이', 230),
#  ('대하여', 228),
#  ('중', 223),
#  ('해지한', 221),
#  ('어느', 215),
#  ('등', 212),
#  ('이행하지', 208),
#  ('따라', 208),
#  ('당해', 208),
#  ('이내에', 204),
#  ('아니한', 203),
#  ('서면으로', 202),
#  ('의무를', 201),
#  ('제1항', 196),
#  ('“갑”이', 196),
#  ('수급사업자는', 181),
#  ('등의', 180),
#  ('“갑”의', 178),
#  ('즉시', 171),
#  ('시', 167),
#  ('수급사업자가', 160),
#  ('경우,', 159),
#  ('귀책사유로', 157),
#  ('1에', 156),
#  ('제1항에', 156),
#  ('상대방에게', 155),
#  ('내에', 155),
#  ('가능성이', 153),
#  ('“갑”에게', 152),
#  ('계약상의', 152),
#  ('인정되는', 152),
#  ('다만,', 151),
#  ('“을”에게', 150),
#  ('없는', 150),
#  ('후', 149),
#  ('을이', 142),
#  ('사유', 140),
#  ('해당', 140),
#  ('이행을', 139),
#  ('않을', 138),
#  ('것으로', 136),
#  ('대가를', 136),
#  ('"을"의', 133),
#  ('계약이행이', 133),
#  ('갑', 132),
#  ('목적을', 129),
#  ('기간을', 127),
#  ('아니할', 126),
#  ('아니한다.', 125),
#  ('손해를', 125),
#  ('달성할', 124),
#  ('통지하여야', 122),
#  ('"을"은', 122),
#  ('하는', 121),
#  ('발생할', 120),
#  ('착수하지', 120),
#  ('100분의', 120),
#  ('기간', 119),
#  ('날로부터', 118),
#  ('금액을', 118),
#  ('하나에', 117),
#  ('된', 115),
#  ('“갑”', 113),
#  ('한', 112),
#  ('약정한', 110),
#  ('지급하여야', 110),
#  ('일방이', 110),
#  ('이행할', 109),
#  ('"갑"은', 109),
#  ('부분에', 108),
#  ('객관적으로', 106),
#  ('14일', 106),
#  ('그러하지', 104),
#  ('상대방의', 104),
#  ('준용한다.', 104),
#  ('경우.', 103),
#  ('수행할', 103),
#  ('통지한다.', 103),
#  ('"갑"이', 103),
#  ('완료할', 103),
#  ('계약기간', 102),
#  ('정상적인', 102),
#  ('경과하고도', 101),
#  ('계약은', 101),
#  ('정하여', 100),
#  ('필요한', 100),
#  ('등을', 100),
#  ('중대한', 100),
#  ('계약조건을', 100),
#  ('해지된', 99),
#  ('사유없이', 98),
#  ('부득이한', 98),
#  ('“갑”과', 98),
#  ('계약상대자가', 98),
#  ('계약상대자는', 98),
#  ('용역을', 97),
#  ('상대방이', 96),
#  ('지체없이', 96),
#  ('1개월', 96),
#  ('위반하여', 96),
#  ('수급사업자의', 95),
#  ('상당하는', 94),
#  ('위반으로', 94),
#  ('이유없이', 93),
#  ('계약에', 93),
#  ('불가피한', 92),
#  ('명백한', 92),
#  ('처분을', 91),
#  ('“발주자”는', 91),
#  ('곤란하다고', 90),
#  ('상대방에', 90),
#  ('당사자', 90),
#  ('모든', 89),
#  ('이전에', 89),
#  ('시정을', 88),
#  ('을은', 87),
#  ('계약보증금을', 87),
#  ('제2항', 87),
#  ('위하여', 86),
#  ('대해', 85),
#  ('능력이', 85),
#  ('사실을', 85),
#  ('이상', 84),
#  ('전에', 84),
#  ('완료하지', 84),
#  ('상환하여야', 83),
#  ('불가능한', 83),
#  ('반환하여야', 82),
#  ('협의하여', 81),
#  ('파산,', 81),
#  ('해지를', 80),
#  ('내용을', 80),
#  ('가압류,', 80),
#  ('상대방은', 80),
#  ('계약상대자의', 80),
#  ('자료를', 79),
#  ('계약내용을', 79),
#  ('미정산잔액이', 79),
#  ('동시에', 78),
#  ('청구할', 78),
#  ('이상의', 78),
#  ('"갑"에게', 78),
#  ('용역수행에', 78),
#  ('이행이', 77),
#  ('아니하는', 77),
#  ('서면', 77),
#  ('위반하고', 77),
#  ('계약상대자에게', 77),
#  ('따른', 76),
#  ('을', 76),
#  ('호에', 76),
#  ('없을', 76),
#  ('위반한', 75),
#  ('못하거나', 75),
#  ('판단될', 75),
#  ('부도,', 74),
#  ('방해하는', 74),
#  ('선금에', 74),
#  ('계약기간의', 73),
#  ('권리', 72),
#  ('자동', 72),
#  ('있을', 72),
#  ('"을"에게', 72),
#  ('단,', 72),
#  ('계약관리를', 72),
#  ('해지되었을', 72),
#  ('“을”', 72),
#  ('있으며,', 72),
#  ('곤란하게', 72),
#  ('해제·해지할', 72),
#  ('천재지변', 71),
#  ('착수기일을', 71),
#  ('정한', 70),
#  ('원사업자가', 69),
#  ('당사자는', 69),
#  ('사정이', 69),
#  ('업무를', 69),
#  ('인한', 68),
#  ('등으로', 68),
#  ('발생하였을', 68),
#  ('"갑"', 68),
#  ('"갑"의', 68),
#  ('쌍방이', 67),
#  ('지장을', 67),
#  ('않는', 67),
#  ('배상하여야', 67),
#  ('최저임금법', 67),
#  ('개별계약의', 66),
#  ('관련하여', 66),
#  ('하였을', 66),
#  ('제2항에', 65),
#  ('수행', 65),
#  ('전까지', 64),
#  ('갑은', 64),
#  ('지체상금이', 64),
#  ('규정은', 64),
#  ('지체', 63),
#  ('이유', 63),
#  ('위반하였을', 63),
#  ('해지일', 63),
#  ('투입된', 63),
#  ('있어서', 62),
#  ('해지하고자', 61),
#  ('이에', 61),
#  ('달한', 61),
#  ('각호에', 61),
#  ('계약금액이', 61),
#  ('경우로서', 60),
#  ('잔액에', 60),
#  ('금액', 60),
#  ('때.', 59),
#  ('뇌물수수', 59),
#  ('인수한', 59),
#  ('필요가', 59),
#  ('의', 59),
#  ('용역', 59),
#  ('하며,', 58),
#  ('제2항의', 58),
#  ('상호', 58),
#  ('요구할', 58),
#  ('사유를', 58),
#  ('해지되는', 58),
#  ('가산하지', 58),
#  ('지연하여', 57),
#  ('제3자에', 57),
#  ('동', 57),
#  ('지급하지', 57),
#  ('내지', 57),
#  ('이자는', 57),
#  ('영업의', 56),
#  ('해지의', 56),
#  ('양도한', 56),
#  ('계속', 56),
#  ('불구하고', 56),
#  ('장비의', 56),
#  ('이로', 55),
#  ('신청', 55),
#  ('만료', 55),
#  ('완성을', 55),
#  ('근로기준법', 55),
#  ('해약할', 54),
#  ('지급한다.', 53),
#  ('제', 53),
#  ('어음', 53),
#  ('외에', 53),
#  ('에게', 53),
#  ('“계약상대자”는', 53),
#  ('해제할', 52),
#  ('용역수행기한까지', 52),
#  ('전체용역의', 52),
#  ('50을', 52),
#  ('목적물의', 51),
#  ('시정', 51),
#  ('가처분,', 51),
#  ('제3호의', 51),
#  ('검사하여', 51),
#  ('철수비용', 51),
#  ('"을"', 51),
#  ('때는', 50),
#  ('관한', 50),
#  ('하지', 50),
#  ('해지하는', 50),
#  ('40이상', 50),
#  ('상당한', 49),
#  ('않는다.', 49),
#  ('일방의', 49),
#  ('인수하는', 49),
#  ('30일', 49),
#  ('않은', 48),
#  ('발생하여', 48),
#  ('이익을', 48),
#  ('날부터', 48),
#  ('은', 48),
#  ('계약담당공무원은', 48),
#  ('금융기관', 48),
#  ('통보하여야', 47),
#  ('일방적으로', 47),
#  ('지급받은', 47),
#  ('을의', 47),
#  ('파산', 47),
#  ('유지할', 47),
#  ('있다고', 47),
#  ('실종,', 47),
#  ('[날짜]', 46),
#  ('해산,', 46),
#  ('지급', 46),
#  ('금액과', 46),
#  ('초과하였을', 46),
#  ('사망,', 46),
#  ('기한의', 45),
#  ('귀책사유가', 45),
#  ('동일한', 45),
#  ('사업의', 45),
#  ('기성부분을', 45),
#  ('기성부분의', 45),
#  ('는', 45),
#  ('질병,', 45),
#  ('시에는', 44),
#  ('고의', 44),
#  ('일체의', 44),
#  ('사항을', 44),
#  ('하여', 44),
#  ('해약', 44),
#  ('되었을', 44),
#  ('일방에', 44),
#  ('체결하지', 44),
#  ('보증기관이', 44),
#  ('보증이행을', 44),
#  ('것이', 44),
#  ('"갑"과', 44),
#  ('있고', 43),
#  ('반환한다.', 43),
#  ('변경함으로써', 43),
#  ('불가능하다고', 43),
#  ('제2호에', 43),
#  ('상대방과', 43),
#  ('용역의', 43),
#  ('당사자의', 42),
#  ('판단되는', 42),
#  ('조건으로', 42),
#  ('시정하지', 42),
#  ('기', 42),
#  ('수표의', 42),
#  ('원사업자는', 41),
#  ('갑이', 41),
#  ('에', 41),
#  ('곤란한', 41),
#  ('제2차', 41),
#  ('3개월', 41),
#  ('계약이행과', 41),
#  ('처벌을', 41),
#  ('시정된', 41),
#  ('의해', 40),
#  ('손해배상을', 40),
#  ('않거나', 40),
#  ('있으며', 40),
#  ('협약을', 40),
#  ('압류,', 40),
#  ('제6조제1항', 40),
#  ('경우(다만,', 40),
#  ('아니하다.', 39),
#  ('사정으로', 39),
#  ('이루어지지', 39),
#  ('없다.', 39),
#  ('연대보증인', 39),
#  ('감소되었을', 39),
#  ('불법․부정행위가', 39),
#  ('가처분', 38),
#  ('현저히', 38),
#  ('의거', 38),
#  ('공사를', 38),
#  ('해제,', 38),
#  ('해지될', 38),
#  ('계약보증금상당액에', 38),
#  ('가산하여', 38),
#  ('상계할', 38),
#  ('장기계속용역의', 38),
#  ('뜻을', 38),
#  ('금융기관으로부터', 37),
#  ('이행하기', 37),
#  ('거래정지', 37),
#  ('책임', 37),
#  ('해약을', 37),
#  ('상환할', 37),
#  ('발주자는', 37),
#  ('미정산잔액에', 37),
#  ('계약이행', 37),
#  ('계약내용의', 36),
#  ('반환하며,', 36),
#  ('최고', 36),
#  ('기본계약', 36),
#  ('의사를', 36),
#  ('갑에게', 36),
#  ('용역수행정지기간이', 36),
#  ('제공하지', 36),
#  ('경', 36),
#  ('미리', 36),
#  ('취소,', 35),
#  ('인정한', 35),
#  ('최고하고,', 35),
#  ('초래한', 35),
#  ('대금을', 35),
#  ('될', 35),
#  ('영향을', 35),
#  ('사전', 35),
#  ('업무', 35),
#  ('아니하여', 34),
#  ('양도', 34),
#  ('이미', 34),
#  ('판정된', 34),
#  ('일부', 34),
#  ('특별한', 34),
#  ('최고하고', 34),
#  ('하고,', 34),
#  ('쌍방의', 34),
#  ('시정되지', 34),
#  ('해지는', 34),
#  ('금융기관의', 34),
#  ('완료되지', 34),
#  ('제28조', 34),
#  ('재해', 33),
#  ('사항의', 33),
#  ('자가', 33),
#  ('수행에', 33),
#  ('양', 33),
#  ('수표가', 33),
#  ('시정이', 33),
#  ('제4항의', 33),
#  ('계', 33),
#  ('감독관청으로부터', 32),
#  ('원사업자와', 32),
#  ('제공받은', 32),
#  ('갑과', 32),
#  ('현금으로', 32),
#  ('통지를', 32),
#  ('방법으로', 32),
#  ('미치지', 32),
#  ('하며', 32),
#  ('성실히', 32),
#  ('행위를', 32),
#  ('경매', 32),
#  ('관할', 32),
#  ('있어', 32),
#  ('하여야', 32),
#  ('배상한다.', 31),
#  ('연장되는', 31),
#  ('서면에', 31),
#  ('과실로', 31),
#  ('불가능', 31),
#  ('명시하여', 31),
#  ('사정에', 31),
#  ('다음의', 31),
#  ('하거나', 31),
#  ('부정한', 31),
#  ('업무가', 31),
#  ('위', 31),
#  ('불이행', 30),
#  ('못한', 30),
#  ('중요한', 30),
#  ('전부를', 30),
#  ('부분', 30),
#  ('갑의', 30),
#  ('업무수행이', 30),
#  ('거래정지처분을', 29),
#  ('더하여', 29),
#  ('검사를', 29),
#  ('계약해지', 29),
#  ('회사정리의', 29),
#  ('어렵다고', 29),
#  ('두고', 29),
#  ('그럼에도', 29),
#  ('제8조의', 29),
#  ('위반하거나', 29),
#  ('해지로', 29),
#  ('당사자가', 29),
#  ('같은', 29),
#  ('해제·해지하고자', 29),
#  ('“계약상대자”의', 29),
#  ('책임을', 28),
#  ('타', 28),
#  ('현저한', 28),
#  ('활용하지', 28),
#  ('채무는', 28),
#  ('계약상', 28),
#  ('협의', 28),
#  ('발생하는', 28),
#  ('불투명', 28),
#  ('계속할', 28),
#  ('처분,', 28),
#  ('중도', 28),
#  ('정산', 28),
#  ('제43조를', 28),
#  ('아니한다)', 28),
#  ('발주기관에', 28),
#  ('해제·해지', 28),
#  ('대가', 28),
#  ('더', 27),
#  ('회사로의', 27),
#  ('합병을', 27),
#  ('파산선고를', 27),
#  ('정산한다.', 27),
#  ('자신의', 27),
#  ('발행한', 27),
#  ('인정할', 27),
#  ('수행부분의', 27),
#  ('제8조에', 27),
#  ('아니하고', 27),
#  ('제출하여', 27),
#  ('“계약상대자”가', 27),
#  ('우', 27),
#  ('협력단은', 27),
#  ('제3항에', 26),
#  ('거부하거나', 26),
#  ('금액의', 26),
#  ('귀책사유', 26),
#  ('산출한', 26),
#  ('연장된다.', 26),
#  ('전항의', 26),
#  ('위반', 26),
#  ('통보할', 26),
#  ('정지기간이', 26),
#  ('지불을', 26),
#  ('태만히', 26),
#  ('용역수행', 26),
#  ('유지한다.', 26),
#  ('인력․자재', 26),
#  ('재개할', 26),
#  ('현저하게', 26),
#  ('판단된', 26),
#  ('받았을', 25),
#  ('제작에', 25),
#  ('원사업자에게', 25),
#  ('영업상의', 25),
#  ('사전에', 25),
#  ('신청을', 25),
#  ('회사', 25),
#  ('받았거나', 25),
#  ('이의를', 25),
#  ('회사정리,', 25),
#  ('시행령', 25),
#  ('연장하여도', 25),
#  ('없음이', 25),
#  ('발생', 25),
#  ('인해', 25),
#  ('부도', 25),
#  ('판단한', 25),
#  ('승낙없이', 25),
#  ('원사업자로부터', 24),
#  ('불합격으로', 24),
#  ('1년간', 24),
#  ('을에게', 24),
#  ('제시한', 24),
#  ('자동적으로', 24),
#  ('등이', 24),
#  ('귀책', 24),
#  ('수행이', 24),
#  ('효력이', 24),
#  ('계약보증금', 24),
#  ('다음과', 24),
#  ('“위탁자”가', 24),
#  ('추가납부하는', 24),
#  ('금액]을', 24),
#  ('방해하거나', 24),
#  ('“을”에', 24),
#  ('아래', 24),
#  ('합의한', 24),
#  ('“발주자”에게', 24),
#  ('해제하거나', 23),
#  ('받아', 23),
#  ('공사의', 23),
#  ('계약서', 23),
#  ('수행중', 23),
#  ('원활한', 23),
#  ('발생한다.', 23),
#  ('전', 23),
#  ('규정을', 23),
#  ('상', 23),
#  ('손해배상의', 23),
#  ('내용에', 23),
#  ('발주자가', 23),
#  ('서류', 23),
#  ('지연시켜', 23),
#  ('7일', 23),
#  ('완료', 23),
#  ('제3항', 22),
#  ('대금', 22),
#  ('[백분율])를', 22),
#  ('다른', 22),
#  ('기간내에', 22),
#  ('본다.', 22),
#  ('경우는', 22),
#  ('수행한', 22),
#  ('기성부분에', 22),
#  ('고의로', 22),
#  ('않았을', 22),
#  ('계약기간을', 22),
#  ('이의', 22),
#  ('요구를', 22),
#  ('각호', 22),
#  ('미', 22),
#  ('통보', 22),
#  ('용역이후의', 22),
#  ('입찰에', 22),
#  ('허위', 22),
#  ('대출평균금리(한국은행', 22),
#  ('통계월보상의', 22),
#  ('다.', 22),
#  ('등록의', 22),
#  ('승낙', 22),
#  ('받을', 22),
#  ('천재지변,', 22),
#  ('아니', 22),
#  ('이행한다.', 21),
#  ('원인이', 21),
#  ('제4항', 21),
#  ('제3자에게', 21),
#  ('업무수행에', 21),
#  ('일부가', 21),
#  ('별도의', 21),
#  ('손해배상', 21),
#  ('상대방', 21),
#  ('사업', 21),
#  ('손해가', 21),
#  ('손해에', 21),
#  ('비용을', 21),
#  ('극히', 21),
#  ('청구에', 21),
#  ('인정하는', 21),
#  ('잔액이', 21),
#  ('중단되고', 21),
#  ('불가항력적', 21),
#  ('공급자는', 21),
#  ('공급자의', 21),
#  ('“발주자”의', 21),
#  ('결의한', 20),
#  ('해제․해지할', 20),
#  ('지급한', 20),
#  ('공사에', 20),
#  ('동안', 20),
#  ('자동으로', 20),
#  ('작업을', 20),
#  ('경과하여도', 20),
#  ('위반하는', 20),
#  ('업무수행', 20),
#  ('제1호', 20),
#  ('차수별', 20),
#  ('계약)의', 20),
#  ('당해계약의', 20),
#  ('전쟁,', 20),
#  ('단위로', 20),
#  ('자', 20),
#  ('수요자와', 20),
#  ('대출평균금리를', 20),
#  ('14일이내에', 20),
#  ('“갑”에', 19),
#  ('받거나', 19),
#  ('이행하여야', 19),
#  ('수급사업자에게', 19),
#  ('경우를', 19),
#  ('관련한', 19),
#  ('변경', 19),
#  ('아닌', 19),
#  ('이의가', 19),
#  ('해지에', 19),
#  ('중지하고', 19),
#  ('납품', 19),
#  ('하에', 19),
#  ('시정기간을', 19),
#  ('규정', 19),
#  ('명예를', 19),
#  ('일정한', 19),
#  ('지급하고', 19),
#  ('계약담당자는', 19),
#  ('해당할', 19),
#  ('명백하다고', 19),
#  ('그때까지', 19),
#  ('위배하여', 19),
#  ('합의에', 19),
#  ('2개월', 19),
#  ('신청이', 19),
#  ('계약담당직원은', 19),
#  ('계약이행을', 19),
#  ('발주자에', 19),
#  ('시점의', 19),
#  ('제29조제2항을', 19),
#  ('변경으로', 19),
#  ('업무정지', 19),
#  ('면허', 19),
#  ('제15조', 19),
#  ('사업을', 19),
#  ('당해용역을', 19),
#  ('지지', 18),
#  ('목적물에', 18),
#  ('상대방으로부터', 18),
#  ('목적물과', 18),
#  ('강제집행(가압류', 18),
#  ('착수를', 18),
#  ('포함),', 18),
#  ('승인', 18),
#  ('최고한', 18),
#  ('계약해지를', 18),
#  ('개발의', 18),
#  ('화의신청', 18),
#  ('최고하며,', 18),
#  ('해지하여야', 18),
#  ('단', 18),
#  ('수령한', 18),
#  ('상당액에', 18),
#  ('때,', 18),
#  ('제109조에', 18),
#  ('제30조제3항', 18),
#  ('보상하여야', 18),
#  ('상기', 18),
#  ('1년', 18),
#  ('체결된', 18),
#  ('“계약상대자”', 18),
#  ('권리와', 17),
#  ('해제된', 17),
#  ('수급사업자로부터', 17),
#  ('반환하고,', 17),
#  ('지급해야', 17),
#  ('계약상대방이', 17),
#  ('동의', 17),
#  ('부족하여', 17),
#  ('강제집행,', 17),
#  ('공사', 17),
#  ('철거한다.', 17),
#  ('없으면', 17),
#  ('당한', 17),
#  ('시점까지', 17),
#  ('이행치', 17),
#  ('수행하지', 17),
#  ('위한', 17),
#  ('조치를', 17),
#  ('등에', 17),
#  ('의무', 17),
#  ('제16조의', 17),
#  ('“갑”으로부터', 17),
#  ('이유로', 17),
#  ('사유에', 17),
#  ('효력은', 17),
#  ('행정관청으로부터', 17),
#  ('사실이', 17),
#  ('이후', 17),
#  ('이후의', 17),
#  ('요구하는', 17),
#  ('지', 17),
#  ('변경하여', 17),
#  ('진다.', 17),
#  ('발생된', 17),
#  ('판단할', 17),
#  ('위반할', 17),
#  ('재산에', 17),
#  ('20일', 17),
#  ('쌍방', 17),
#  ('입은', 17),
#  ('미정산', 17),
#  ('곤란할', 16),
#  ('청구를', 16),
#  ('영업취소․영업정지', 16),
#  ('양수인', 16),
#  ('목적', 16),
#  ('목적물', 16),
#  ('손해배상금을', 16),
#  ('이행', 16),
#  ('원만히', 16),
#  ('변제하여야', 16),
#  ('부당한', 16),
#  ('책임이', 16),
#  ('발주기관의', 16),
#  ('부터', 16),
#  ('계약에서', 16),
#  ('상태가', 16),
#  ('당하거나', 16),
#  ('경우에도', 16),
#  ('한,', 16),
#  ('연장된', 16),
#  ('명시된', 16),
#  ('본문의', 16),
#  ('계약서상의', 16),
#  ('그에', 16),
#  ('문서로', 16),
#  ('상실하고', 16),
#  ('어음이나', 16),
#  ('연구비', 16),
#  ('전액을', 16),
#  ('조항을', 16),
#  ('계약대상2는', 16),
#  ('보수의', 16),
#  ('의사가', 16),
#  ('말한다)에', 16),
#  ('배상책임을', 16),
#  ('총', 16),
#  ('하거나,', 16),
#  ('또', 16),
#  ('‘을’이', 16),
#  ('일방에게', 16),
#  ('화의,', 16),
#  ('되지', 16),
#  ('진행', 16),
#  ('4항을', 16),
#  ('“발주자”와', 16),
#  ('해', 16),
#  ('해당될', 15),
#  ('동의한', 15),
#  ('거절하거나', 15),
#  ('최고없이', 15),
#  ('저장된', 15),
#  ('삭제한다.', 15),
#  ('대금과', 15),
#  ('지식재산', 15),
#  ('제4항에', 15),
#  ('정한다.', 15),
#  ('기성부분', 15),
#  ('필한', 15),
#  ('아니하였을', 15),
#  ('선고를', 15),
#  ('이외에', 15),
#  ('종료되는', 15),
#  ('제24조제2항제1호', 15),
#  ('당해계약을', 15),
#  ('정지', 15),
#  ('요구한', 15),
#  ('통보하여', 15),
#  ('“위탁자”에게', 15),
#  ('해지시까지의', 15),
#  ('의한다.', 15),
#  ('받지', 15),
#  ('제30조', 15),
#  ('행정청으로부터', 15),
#  ('명백할', 15),
#  ('항에', 15),
#  ('일방', 15),
#  ('1항의', 15),
#  ('지연', 15),
#  ('관련된', 15),
#  ('추가', 15),
#  ('계약과', 15),
#  ('“공급자”가', 15),
#  ('“공급자”의', 15),
#  ('거절하였을', 14),
#  ('합병된', 14),
#  ('회사가', 14),
#  ('승계함에', 14),
#  ('호에서', 14),
#  ('납품받은', 14),
#  ('지연한', 14),
#  ('지연기간에', 14),
#  ('지연이자(연', 14),
#  ('영업정지', 14),
#  ('미지급', 14),
#  ('지불하지', 14),
#  ('품질관리능력이', 14),
#  ('관련', 14),
#  ('기간의', 14),
#  ('사항은', 14),
#  ('표시하지', 14),
#  ('있고,', 14),
#  ('대여품이', 14),
#  ('기준으로', 14),
#  ('해지의사를', 14),
#  ('발생하거나', 14),
#  ('인정', 14),
#  ('주요', 14),
#  ('해산', 14),
#  ('과', 14),
#  ('있다', 14),
#  ('약정이자상당액을', 14),
#  ('상의', 14),
#  ('불이행하여', 14),
#  ('요구하고,', 14),
#  ('부득이', 14),
#  ('조', 14),
#  ('시정요구를', 14),
#  ('의사표시가', 14),
#  ('완성할', 14),
#  ('되거나', 14),
#  ('제공했던', 14),
#  ('이때', 14),
#  ('도저히', 14),
#  ('소홀히', 14),
#  ('제33조의', 14),
#  ('계약금액의', 14),
#  ('업무에', 14),
#  ('행위가', 14),
#  ('야', 14),
#  ('제16조에', 14),
#  ('설계요구조건을', 14),
#  ('물품을', 14),
#  ('14일전까지', 14),
#  ('발행,', 14),
#  ('회사정리', 14),
#  ('용역비', 14),
#  ('상황이', 14),
#  ('2회', 14),
#  ('별도', 14),
#  ('판단하는', 14),
#  ('수요자는', 14),
#  ('간', 14),
#  ('계약상대자', 14),
#  ('여야', 14),
#  ('있', 14),
#  ('제19조의', 14),
#  ('｢최저임금법｣', 14),
#  ('사업이', 13),
#  ('미이행', 13),
#  ('부분이', 13),
#  ('사소하고,', 13),
#  ('달성과', 13),
#  ('관계없는', 13),
#  ('비율에', 13),
#  ('차액이', 13),
#  ('부족할', 13),
#  ('미지급액을', 13),
#  ('정산함에', 13),
#  ('검사결과가', 13),
#  ('제외하고,', 13),
#  ('증명한', 13),
#  ('제3호,', 13),
#  ('후문', 13),
#  ('제6항에', 13),
#  ('어음․수표의', 13),
#  ('납품이', 13),
#  ('완료된', 13),
#  ('채무를', 13),
#  ('동일하다.', 13),
#  ('원사업자의', 13),
#  ('이후에도', 13),
#  ('관계없이', 13),
#  ('거래가', 13),
#  ('착수', 13),
#  ('피해를', 13),
#  ('통지함으로써', 13),
#  ('계약사항을', 13),
#  ('진행이', 13),
#  ('어려울', 13),
#  ('종료', 13),
#  ('반환을', 13),
#  ('가망이', 13),
#  ('용역업무의', 13),
#  ('또한', 13),
#  ('“위탁자”는', 13),
#  ('지불한다.', 13),
#  ('아니하거나', 13),
#  ('용역수행을', 13),
#  ('용역업무를', 13),
#  ('제18조제1항에', 13),
#  ('제32조에', 13),
#  ('손해는', 13),
#  ('위반에', 13),
#  ('경우가', 13),
#  ('를', 13),
#  ('1년씩', 13),
#  ('1', 13),
#  ('부정', 13),
#  ('조에', 13),
#  ('월', 13),
#  ('○일', 13),
#  ('제33조에', 13),
#  ('인ㆍ허가의', 12),
#  ('납품한', 12),
#  ('과실없음을', 12),
#  ('납기', 12),
#  ('상실하며', 12),
#  ('변제한다.', 12),
#  ('위탁', 12),
#  ('장비', 12),
#  ('해약의', 12),
#  ('멸실', 12),
#  ('것을', 12),
#  ...]

# %%
df
# Out:
#               항목                                                 원본     수정본  \
# 0            NaN                          음식물류폐기물  처리  위․수탁  계약서(안)  _GOOD_
# 1            NaN  [회사명1](이하 “갑”이라 한다)와 [회사명2](이하 “을”이라 한다)은 음식물류...  _GOOD_
# 2             1조                                            목적 및 대상  _GOOD_
# 3          1조 1항  본 계약은 음식물류 폐기물의 자원화를 효율적으로 추진하기 위하여 필요한 사항을 약정...  _GOOD_
# 4          1조 2항              위탁처리대상은 [지역명1]군에서 분리 수거한 음식물류폐기물로 한다.  _GOOD_
# ...          ...                                                ...     ...
# 74175     2장 10조                                                 해석  _GOOD_
# 74176  2장 10조 1항  본 계약에 명기하지 아니한 사항 및 본 계약의 해석상의 이의가 있을 때에는 쌍방의 ...  _GOOD_
# 74177     2장 11조                                               소송관할  _GOOD_
# 74178  2장 11조 1항                 본 계약으로 발생되는 분쟁은 서울지방법원을 관할법원으로 한다.  _GOOD_
# 74179        NaN  본 계약을 증명하기 위하여 계약서 2통을 작성하여 쌍방이 서명 날인하고 각각 1통씩...  _GOOD_
#
#         사유   조항구분                                           파일명
# 0      NaN    nan  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 1      NaN    nan  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 2      NaN    nan  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 3      NaN    nan  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 4      NaN    nan  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# ...    ...    ...                                           ...
# 74175  NaN    nan                     체크735. 프리랜서와기업간업무계약서.xlsx
# 74176  NaN    nan                     체크735. 프리랜서와기업간업무계약서.xlsx
# 74177  NaN    nan                     체크735. 프리랜서와기업간업무계약서.xlsx
# 74178  NaN  옵션조항8                     체크735. 프리랜서와기업간업무계약서.xlsx
# 74179  NaN    nan                     체크735. 프리랜서와기업간업무계약서.xlsx
#
# [74180 rows x 6 columns]

# %%
def use_keyword_for_classify(df, keyword):
    counter = Counter()
    for i in range(len(df)):
        try:
            if keyword in str(df.iloc[i]['원본']):
                counter.update({str(df.iloc[i]['조항구분']): 1})
        except:
            pass
    return counter.most_common(), sum(counter.values())

# %%
use_keyword_for_classify(df, '[기간]')
# Out:
# ([('필수조항1', 707),
#   ('필수조항8', 34),
#   ('nan', 23),
#   ('필수조항2', 16),
#   ('필수조항7', 7),
#   ('필수조항3', 2),
#   ('필수조항11', 1)],
#  790)

# %%
find_by_option(df, '필수조항1')
# Out:
#                항목                               원본     수정본   사유   조항구분  \
# 9           3조 1항                 위수탁기간은 [기간]로 한다.  _GOOD_  NaN  필수조항1
# 43          3조 1항                계약기간은 [기간]까지로 한다.  _GOOD_  NaN  필수조항1
# 121      1장 2조 1항                             [기간]  _GOOD_  NaN  필수조항1
# 546      7장 8조 1항     이 계약은 체결일로부터 [날짜] 그 효력을 가진다.  _GOOD_  NaN  필수조항1
# 565      1장 2조 1항                             [기간]  _GOOD_  NaN  필수조항1
# ...           ...                              ...     ...  ...    ...
# 74023       3조 1항         본 계약에 의한 용역기간은 [기간]로 한다.  _GOOD_  NaN  필수조항1
# 74074     8조 1항-1              본 계약기간은 [기간]까지로 하며   _GOOD_  NaN  필수조항1
# 74111    11조 1항-1  본 계약의 유효기간은 계약체결일부터 [기간]으로 하고,   _GOOD_  NaN  필수조항1
# 74144     5조 1항-1         이 계약은 본  계약 체결일로부터 [기간]   _GOOD_  NaN  필수조항1
# 74157  2장 3조 1항-1               본 계약은 [기간]까지로 하며,   _GOOD_  NaN  필수조항1
#
#                                                   파일명
# 9        체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 43                           체크10. PC유지보수계약서_ID3.xlsx
# 121               체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# 546               체크100. 기계업종 표준하도급계약서(16.12.30).xlsx
# 565    체크101. 디자인업종(디지털) 표준하도급계약서(2017.12.27.개정).xlsx
# ...                                               ...
# 74023                            체크731. 창업컨설팅계약서.xlsx
# 74074                             체크732. 청소용역계약서.xlsx
# 74111                              체크733. 컨설팅계약서.xlsx
# 74144                            체크734. 컨설팅업무계약서.xlsx
# 74157                       체크735. 프리랜서와기업간업무계약서.xlsx
#
# [881 rows x 6 columns]

# %% [markdown]
# ###### use_keyword_for_classify(df, '[금액]')

# %%
use_keyword_for_classify(df, '[날짜]')
# Out:
# ([('필수조항8', 539),
#   ('nan', 470),
#   ('옵션조항3', 145),
#   ('필수조항1', 113),
#   ('필수조항2', 109),
#   ('필수조항7', 64),
#   ('필수조항9', 61),
#   ('필수조항11', 58),
#   ('필수조항10.1', 54),
#   ('필수조항4', 29),
#   ('옵션조항1', 26),
#   ('필수조항6', 19),
#   ('필수조항12', 12),
#   ('필수조항3', 8),
#   ('필수조항13', 6),
#   ('필수조항5', 4),
#   ('옵션조항8', 4),
#   ('옵션조항5', 3),
#   ('필수조항10.1 유사조항', 1),
#   ('필수조항10', 1),
#   ('옵션조항6', 1)],
#  1727)

# %%
find_by_option(df, '필수조항10')
# Out:
#                항목                                                 원본     수정본  \
# 3157       11조 8항  원사업자는 조사결과 제1항부터 제5항까지의 규정을 위반한 사실이 있는 경우에는 그에...  _GOOD_
# 4014    2장 19조 8항  수급사업자가 계약상 의무를 이행하지 아니하여 원사업자가 제33조 제1항 및 제2항에...  _GOOD_
# 8013        5조 4항   “을” 은 본 계약의 개발과 관련하여 관계법령을 위반하거나 제 3 자의 권리(지적...  _GOOD_
# 8206       13조 1항  “갑”은 계약금액 결정상 명백한 하자로 인하여 부당이득을 취한 사실이 발견될 경우,...  _GOOD_
# 8207       13조 2항  계약종결 후에 전항의 규정에 의한 환수사유가 발생하였을 때에는 “을”에게 지급할 다...  _GOOD_
# ...           ...                                                ...     ...
# 73215    2장 9조 1항  계약상대자가 정당한 이유없이 계약상의 의무를 이행하지 아니한 때에는 계약보증금을 당...  _GOOD_
# 73676  8조 1항 1호-2  2) 이런 문제로 발생한 모든 비용(각종 소송을 위한 조사비용 및 변호비용을 포함합...  _GOOD_
# 73838   2장 22조 3항  “을”의 귀책사유로 인하여 공사감리용역의 전부 또는 일부가 중단된 경우에는 “갑”이...  _GOOD_
# 74044     9조 3항-2      이 경우 을은 갑으로부터 지급 받은 착수금 및 용역대행 수수료를 갑에게 반환한다.  _GOOD_
# 74070       6조 1항  제5조에 대한 변상은 "을"이 신속히 이행하지 아니할 경우에는 용역대금 중에서 동 ...  _GOOD_
#
#         사유    조항구분                                      파일명
# 3157   NaN  필수조항10    체크107. 전자업종표준하도급계약서(14.12.31.개정).xlsx
# 4014   NaN  필수조항10  체크109. 전기공사업종표준하도급계약서(14.12.31.개정).xlsx
# 8013   NaN  필수조항10            체크18. 광학엔진 개발 계약서 샘플_ID8.xlsx
# 8206   NaN  필수조항10        체크2. (붙임4) 계약특수조건 1부(160314).xlsx
# 8207   NaN  필수조항10        체크2. (붙임4) 계약특수조건 1부(160314).xlsx
# ...    ...     ...                                      ...
# 73215  NaN  필수조항10                      체크719. 용역도급계약서.xlsx
# 73676  NaN  필수조항10                    체크725. 재무용역자문계약서.xlsx
# 73838  NaN  필수조항10            체크726. 전력시설물의공사감리용역표준계약서.xlsx
# 74044  NaN  필수조항10                     체크731. 창업컨설팅계약서.xlsx
# 74070  NaN  필수조항10                      체크732. 청소용역계약서.xlsx
#
# [219 rows x 6 columns]

# %%
find_by_option(df, '필수조항10 유사조항')
# Out:
#               항목                                                 원본     수정본  \
# 24         8조 1항  “을”은 음식물류폐기물 수탁처리업무 수행 중 발생하는 모든 사고에 대하여 민,형사상...  _GOOD_
# 98        12조 4항                “을”은 전항의 위반으로 인한 민·형사상의 모든 책임을 진다.   _GOOD_
# 7839    16조 1항-2  “계약대상2”는 공사 중 발생한 재해 및 인사 사고에 대하여도 민형사상의 모든 책임...  _GOOD_
# 7843    17조 1항-2                         더불어 공사 전반에 대한 감리의 책임을 진다.   _GOOD_
# 7990       7조 1항  "을"이 작업 중 발생한 모든 안전사고 (대기실 등의 부주의로 인한 화재 등 포함)...  _GOOD_
# ...          ...                                                ...     ...
# 68199      7조 4항  계약상대자”는 제1항의 모든 자료를 “공단”의 이익에 반하는 일체의 영업 행위에 사...  _GOOD_
# 71601  5장 17조 2항  1항의 경우 “계약상대자”는 선량한 괸리자의 의무를 지며, 이를 위반하여 하자가 발...  _GOOD_
# 71608  5장 19조 1항  “계약상대자”의 소유재산은 “계약상대자”의 책임 하에 관리하여야 하며, 담당 구역 ...  _GOOD_
# 71631  5장 25조 1항  “계약상대자”는 종업원의 생명, 신체 또는 재산상에 발생한 사고와 근로기준법 등 일...  _GOOD_
# 73100    4조 1항-2  계약기간중 발생하는 일체의 사고에 대한 민  형사상의 일체의 문제는 을이 책임지고 ...  _GOOD_
#
#         사유         조항구분                                           파일명
# 24     NaN  필수조항10 유사조항  체크1. (과업지시서)2018년 음식물폐기물 민간위탁처리(용역)_계약서.xlsx
# 98     NaN  필수조항10 유사조항                      체크10. PC유지보수계약서_ID3.xlsx
# 7839   NaN  필수조항10 유사조항                     체크14. 건물관리_건물도장공사계약서.xlsx
# 7843   NaN  필수조항10 유사조항                     체크14. 건물관리_건물도장공사계약서.xlsx
# 7990   NaN  필수조항10 유사조항                       체크17. 건물관리_청소용역계약서.xlsx
# ...    ...          ...                                           ...
# 68199  NaN  필수조항10 유사조항                        체크665. 용역계약서 (31).xlsx
# 71601  NaN  필수조항10 유사조항              체크689. [첨부2]사옥종합시설관리용역계약서_2.xlsx
# 71608  NaN  필수조항10 유사조항              체크689. [첨부2]사옥종합시설관리용역계약서_2.xlsx
# 71631  NaN  필수조항10 유사조항              체크689. [첨부2]사옥종합시설관리용역계약서_2.xlsx
# 73100  NaN  필수조항10 유사조항                       체크717. 용역계약서(배달사원).xlsx
#
# [226 rows x 6 columns]
